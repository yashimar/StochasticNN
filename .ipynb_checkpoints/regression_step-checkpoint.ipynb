# %% [markdown]
# # Imports

# %%
import random
import math
import time
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import special

import torch 
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms
from torchsummary import summary

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = torch.device('cuda') 
print('device : ', device)
print('num gpu : ', torch.cuda.device_count())
# Out:
# device :  cuda
# num gpu :  4

# %%
# torch.manual_seed(1234)
# np.random.seed(1234)
# random.seed(1234)

# %% [markdown]
# # Generate Data

# %%
class StepDataset(data.Dataset):
    
    def __init__(self, upper=3, lower=-3, length=100, error_range=0.1, ymax=1., x_var=None, y_var=None, model_mean=None):
        self.upper = upper
        self.lower = lower
        self.length = length
        self.error_range = error_range
        self.y_var = y_var
        if self.y_var != None:
            self.noise = np.array([np.random.normal(0,self.y_var) for i in range(self.length)]).reshape(-1,1).astype(np.float32)
        else:
            self.noise = np.array([2 * self.error_range * np. random.rand() - self.error_range for i in range(self.length)]).reshape(-1,1).astype(np.float32)
            self.y_var = (2*self.error_range)**2/12
        
        if x_var != None:
            self.input = np.array([[(self.upper - self.lower) * np. random.rand() + self.lower, x_var] for i in range(self.length)]).astype(np.float32)
            self.output = np.array([[x.item()*ymax,self.y_var] for x in (self.input[:,0]>0)]).astype(np.float32)
            self.output[:,0] += self.noise.reshape(-1)
        else:    
            self.input = np.array([(self.upper - self.lower) * np. random.rand() + self.lower for i in range(self.length)]).reshape(-1,1).astype(np.float32)
            self.output = (ymax * (self.input > 0) + self.noise).astype(np.float32)
            if model_mean!=None:
                pred = model_mean(torch.tensor(self.input)).to("cpu")
                self.output = torch.abs(torch.tensor(self.output) - pred)


    def __len__(self):
        return self.length
    
    def __getitem__(self, index):
        x = self.input[index]
        y = self.output[index]
        
        return x, y

# %%
dataset = StepDataset(ymax=4.)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=100,shuffle=True)
x, y = next(iter(dataloader))
x.shape
# Out:
# torch.Size([100, 1])

# %%
# dataset = StepDataset(ymax=4.)
dataset = StepDataset(3,-3,100,0.1,ymax=4.)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=100,shuffle=True)
x, y = next(iter(dataloader))
x = x[:,0]
y = y[:,0]


plt.scatter(x, y)
plt.xlim(-3, 3)
plt.ylim(-1.5, 6.)
plt.grid()
plt.show()

# %% [markdown]
# # Basic Regression Model

# %% [markdown]
# ## Modeling

# %%
class BasicRegressor(nn.Module):
    
    def __init__(self):
        super(BasicRegressor, self).__init__()
        self.layer1 = nn.Linear(1, 200)
        self.layer2 = nn.Linear(200, 200)
        self.last = nn.Linear(200, 1)
        self.dropout = nn.Dropout(p=0.01)
        
    def forward(self, x):
        out = self.layer1(x)
        out = F.relu(out)
        out = self.dropout(out)
        out = self.layer2(out)
        out = F.relu(out)
        out = self.dropout(out)
        out = self.last(out)
        
        return out

# %%
net = BasicRegressor().to(device)
print(net)
summary(net,(1,))
# Out:
# BasicRegressor(
#   (layer1): Linear(in_features=1, out_features=200, bias=True)
#   (layer2): Linear(in_features=200, out_features=200, bias=True)
#   (last): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.01, inplace=False)
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 200]             400
#            Dropout-2                  [-1, 200]               0
#             Linear-3                  [-1, 200]          40,200
#            Dropout-4                  [-1, 200]               0
#             Linear-5                    [-1, 1]             201
# ================================================================
# Total params: 40,801
# Trainable params: 40,801
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.16
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------

# %%
net = BasicRegressor()
net(torch.tensor([[0.]]))
# Out:
# tensor([[0.0152]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ## Train

# %% [markdown]
# ### Mean Model

# %%
def train_mean(model, dataloader, num_epochs):   
    model = nn.DataParallel(model)
    model.to(device)
    model.train()
    
    optimizer = torch.optim.Adam(model.parameters())
    criterion = nn.MSELoss()
    
    for epoch in range(num_epochs):      
        t_epoch_start = time.time()
        epoch_loss = 0.0
        
        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')
        
        for data in dataloader:       
            batch_size = len(data[0])
            x = data[0].to(device)
            y = data[1].to(device)
            out = model(x)
            
            loss = criterion(out, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Loss:{:.4f} '.format(epoch, epoch_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        
    model.eval()        
    return model

# %%
dataset = StepDataset(3,-3,100,0.1,ymax=4.)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=16,shuffle=True)

model_mean = BasicRegressor()

model_mean = train_mean(model_mean, dataloader, 100)
# Out:
# -------------
# Epoch 1/100
# -------------
# -------------
# epoch 0 || Loss:9.7928
# timer:  0.0988 sec.
# -------------
# Epoch 2/100
# -------------
# -------------
# epoch 1 || Loss:3.1260
# timer:  0.0569 sec.
# -------------
# Epoch 3/100
# -------------
# -------------
# epoch 2 || Loss:1.9445
# timer:  0.0804 sec.
# -------------
# Epoch 4/100
# -------------
# -------------
# epoch 3 || Loss:1.9998
# timer:  0.0547 sec.
# -------------
# Epoch 5/100
# -------------
# -------------
# epoch 4 || Loss:1.3405
# timer:  0.0494 sec.
# -------------
# Epoch 6/100
# -------------
# -------------
# epoch 5 || Loss:1.3712
# timer:  0.0700 sec.
# -------------
# Epoch 7/100
# -------------
# -------------
# epoch 6 || Loss:1.0678
# timer:  0.0497 sec.
# -------------
# Epoch 8/100
# -------------
# -------------
# epoch 7 || Loss:0.8762
# timer:  0.0412 sec.
# -------------
# Epoch 9/100
# -------------
# -------------
# epoch 8 || Loss:0.8824
# timer:  0.0458 sec.
# -------------
# Epoch 10/100
# -------------
# -------------
# epoch 9 || Loss:0.6866
# timer:  0.0548 sec.
# -------------
# Epoch 11/100
# -------------
# -------------
# epoch 10 || Loss:0.7116
# timer:  0.0458 sec.
# -------------
# Epoch 12/100
# -------------
# -------------
# epoch 11 || Loss:0.6139
# timer:  0.0485 sec.
# -------------
# Epoch 13/100
# -------------
# -------------
# epoch 12 || Loss:0.5552
# timer:  0.0694 sec.
# -------------
# Epoch 14/100
# -------------
# -------------
# epoch 13 || Loss:0.5501
# timer:  0.0698 sec.
# -------------
# Epoch 15/100
# -------------
# -------------
# epoch 14 || Loss:0.6286
# timer:  0.0532 sec.
# -------------
# Epoch 16/100
# -------------
# -------------
# epoch 15 || Loss:0.5628
# timer:  0.0501 sec.
# -------------
# Epoch 17/100
# -------------
# -------------
# epoch 16 || Loss:0.4491
# timer:  0.0531 sec.
# -------------
# Epoch 18/100
# -------------
# -------------
# epoch 17 || Loss:0.4168
# timer:  0.0500 sec.
# -------------
# Epoch 19/100
# -------------
# -------------
# epoch 18 || Loss:0.5258
# timer:  0.0846 sec.
# -------------
# Epoch 20/100
# -------------
# -------------
# epoch 19 || Loss:0.4282
# timer:  0.0419 sec.
# -------------
# Epoch 21/100
# -------------
# -------------
# epoch 20 || Loss:0.4122
# timer:  0.0428 sec.
# -------------
# Epoch 22/100
# -------------
# -------------
# epoch 21 || Loss:0.4584
# timer:  0.0683 sec.
# -------------
# Epoch 23/100
# -------------
# -------------
# epoch 22 || Loss:0.4311
# timer:  0.0422 sec.
# -------------
# Epoch 24/100
# -------------
# -------------
# epoch 23 || Loss:0.4068
# timer:  0.0549 sec.
# -------------
# Epoch 25/100
# -------------
# -------------
# epoch 24 || Loss:0.3572
# timer:  0.0701 sec.
# -------------
# Epoch 26/100
# -------------
# -------------
# epoch 25 || Loss:0.4044
# timer:  0.0470 sec.
# -------------
# Epoch 27/100
# -------------
# -------------
# epoch 26 || Loss:0.4317
# timer:  0.0698 sec.
# -------------
# Epoch 28/100
# -------------
# -------------
# epoch 27 || Loss:0.3327
# timer:  0.0835 sec.
# -------------
# Epoch 29/100
# -------------
# -------------
# epoch 28 || Loss:0.4442
# timer:  0.0542 sec.
# -------------
# Epoch 30/100
# -------------
# -------------
# epoch 29 || Loss:0.3936
# timer:  0.0630 sec.
# -------------
# Epoch 31/100
# -------------
# -------------
# epoch 30 || Loss:0.3590
# timer:  0.0433 sec.
# -------------
# Epoch 32/100
# -------------
# -------------
# epoch 31 || Loss:0.4474
# timer:  0.0545 sec.
# -------------
# Epoch 33/100
# -------------
# -------------
# epoch 32 || Loss:0.3048
# timer:  0.0502 sec.
# -------------
# Epoch 34/100
# -------------
# -------------
# epoch 33 || Loss:0.3423
# timer:  0.0492 sec.
# -------------
# Epoch 35/100
# -------------
# -------------
# epoch 34 || Loss:0.2918
# timer:  0.0699 sec.
# -------------
# Epoch 36/100
# -------------
# -------------
# epoch 35 || Loss:0.3252
# timer:  0.0510 sec.
# -------------
# Epoch 37/100
# -------------
# -------------
# epoch 36 || Loss:0.3190
# timer:  0.0648 sec.
# -------------
# Epoch 38/100
# -------------
# -------------
# epoch 37 || Loss:0.2487
# timer:  0.0455 sec.
# -------------
# Epoch 39/100
# -------------
# -------------
# epoch 38 || Loss:0.3230
# timer:  0.0592 sec.
# -------------
# Epoch 40/100
# -------------
# -------------
# epoch 39 || Loss:0.3043
# timer:  0.0735 sec.
# -------------
# Epoch 41/100
# -------------
# -------------
# epoch 40 || Loss:0.3688
# timer:  0.0553 sec.
# -------------
# Epoch 42/100
# -------------
# -------------
# epoch 41 || Loss:0.2517
# timer:  0.0516 sec.
# -------------
# Epoch 43/100
# -------------
# -------------
# epoch 42 || Loss:0.2798
# timer:  0.0398 sec.
# -------------
# Epoch 44/100
# -------------
# -------------
# epoch 43 || Loss:0.3094
# timer:  0.0446 sec.
# -------------
# Epoch 45/100
# -------------
# -------------
# epoch 44 || Loss:0.2619
# timer:  0.0497 sec.
# -------------
# Epoch 46/100
# -------------
# -------------
# epoch 45 || Loss:0.4007
# timer:  0.0454 sec.
# -------------
# Epoch 47/100
# -------------
# -------------
# epoch 46 || Loss:0.3647
# timer:  0.0326 sec.
# -------------
# Epoch 48/100
# -------------
# -------------
# epoch 47 || Loss:0.2626
# timer:  0.0614 sec.
# -------------
# Epoch 49/100
# -------------
# -------------
# epoch 48 || Loss:0.2427
# timer:  0.0635 sec.
# -------------
# Epoch 50/100
# -------------
# -------------
# epoch 49 || Loss:0.1978
# timer:  0.0538 sec.
# -------------
# Epoch 51/100
# -------------
# -------------
# epoch 50 || Loss:0.2016
# timer:  0.0495 sec.
# -------------
# Epoch 52/100
# -------------
# -------------
# epoch 51 || Loss:0.2182
# timer:  0.0499 sec.
# -------------
# Epoch 53/100
# -------------
# -------------
# epoch 52 || Loss:0.2044
# timer:  0.0691 sec.
# -------------
# Epoch 54/100
# -------------
# -------------
# epoch 53 || Loss:0.2739
# timer:  0.0613 sec.
# -------------
# Epoch 55/100
# -------------
# -------------
# epoch 54 || Loss:0.2052
# timer:  0.0541 sec.
# -------------
# Epoch 56/100
# -------------
# -------------
# epoch 55 || Loss:0.1828
# timer:  0.0624 sec.
# -------------
# Epoch 57/100
# -------------
# -------------
# epoch 56 || Loss:0.3008
# timer:  0.0407 sec.
# -------------
# Epoch 58/100
# -------------
# -------------
# epoch 57 || Loss:0.1921
# timer:  0.0386 sec.
# -------------
# Epoch 59/100
# -------------
# -------------
# epoch 58 || Loss:0.1949
# timer:  0.0527 sec.
# -------------
# Epoch 60/100
# -------------
# -------------
# epoch 59 || Loss:0.2182
# timer:  0.0605 sec.
# -------------
# Epoch 61/100
# -------------
# -------------
# epoch 60 || Loss:0.2222
# timer:  0.0537 sec.
# -------------
# Epoch 62/100
# -------------
# -------------
# epoch 61 || Loss:0.2211
# timer:  0.0641 sec.
# -------------
# Epoch 63/100
# -------------
# -------------
# epoch 62 || Loss:0.2083
# timer:  0.0534 sec.
# -------------
# Epoch 64/100
# -------------
# -------------
# epoch 63 || Loss:0.1798
# timer:  0.0561 sec.
# -------------
# Epoch 65/100
# -------------
# -------------
# epoch 64 || Loss:0.1738
# timer:  0.0518 sec.
# -------------
# Epoch 66/100
# -------------
# -------------
# epoch 65 || Loss:0.1811
# timer:  0.0465 sec.
# -------------
# Epoch 67/100
# -------------
# -------------
# epoch 66 || Loss:0.1959
# timer:  0.0661 sec.
# -------------
# Epoch 68/100
# -------------
# -------------
# epoch 67 || Loss:0.1399
# timer:  0.0713 sec.
# -------------
# Epoch 69/100
# -------------
# -------------
# epoch 68 || Loss:0.2297
# timer:  0.0498 sec.
# -------------
# Epoch 70/100
# -------------
# -------------
# epoch 69 || Loss:0.1967
# timer:  0.0532 sec.
# -------------
# Epoch 71/100
# -------------
# -------------
# epoch 70 || Loss:0.1465
# timer:  0.0545 sec.
# -------------
# Epoch 72/100
# -------------
# -------------
# epoch 71 || Loss:0.1477
# timer:  0.0530 sec.
# -------------
# Epoch 73/100
# -------------
# -------------
# epoch 72 || Loss:0.1455
# timer:  0.0808 sec.
# -------------
# Epoch 74/100
# -------------
# -------------
# epoch 73 || Loss:0.1615
# timer:  0.0617 sec.
# -------------
# Epoch 75/100
# -------------
# -------------
# epoch 74 || Loss:0.2872
# timer:  0.0619 sec.
# -------------
# Epoch 76/100
# -------------
# -------------
# epoch 75 || Loss:0.1420
# timer:  0.0519 sec.
# -------------
# Epoch 77/100
# -------------
# -------------
# epoch 76 || Loss:0.1696
# timer:  0.0605 sec.
# -------------
# Epoch 78/100
# -------------
# -------------
# epoch 77 || Loss:0.1545
# timer:  0.0537 sec.
# -------------
# Epoch 79/100
# -------------
# -------------
# epoch 78 || Loss:0.1298
# timer:  0.0818 sec.
# -------------
# Epoch 80/100
# -------------
# -------------
# epoch 79 || Loss:0.1374
# timer:  0.0620 sec.
# -------------
# Epoch 81/100
# -------------
# -------------
# epoch 80 || Loss:0.1193
# timer:  0.0546 sec.
# -------------
# Epoch 82/100
# -------------
# -------------
# epoch 81 || Loss:0.1339
# timer:  0.0570 sec.
# -------------
# Epoch 83/100
# -------------
# -------------
# epoch 82 || Loss:0.3139
# timer:  0.0448 sec.
# -------------
# Epoch 84/100
# -------------
# -------------
# epoch 83 || Loss:0.1452
# timer:  0.0415 sec.
# -------------
# Epoch 85/100
# -------------
# -------------
# epoch 84 || Loss:0.1403
# timer:  0.0398 sec.
# -------------
# Epoch 86/100
# -------------
# -------------
# epoch 85 || Loss:0.1296
# timer:  0.0620 sec.
# -------------
# Epoch 87/100
# -------------
# -------------
# epoch 86 || Loss:0.1416
# timer:  0.0393 sec.
# -------------
# Epoch 88/100
# -------------
# -------------
# epoch 87 || Loss:0.1859
# timer:  0.0599 sec.
# -------------
# Epoch 89/100
# -------------
# -------------
# epoch 88 || Loss:0.1734
# timer:  0.0582 sec.
# -------------
# Epoch 90/100
# -------------
# -------------
# epoch 89 || Loss:0.2182
# timer:  0.0724 sec.
# -------------
# Epoch 91/100
# -------------
# -------------
# epoch 90 || Loss:0.1280
# timer:  0.0486 sec.
# -------------
# Epoch 92/100
# -------------
# -------------
# epoch 91 || Loss:0.1315
# timer:  0.0494 sec.
# -------------
# Epoch 93/100
# -------------
# -------------
# epoch 92 || Loss:0.1233
# timer:  0.0605 sec.
# -------------
# Epoch 94/100
# -------------
# -------------
# epoch 93 || Loss:0.1147
# timer:  0.0572 sec.
# -------------
# Epoch 95/100
# -------------
# -------------
# epoch 94 || Loss:0.1239
# timer:  0.0618 sec.
# -------------
# Epoch 96/100
# -------------
# -------------
# epoch 95 || Loss:0.1477
# timer:  0.0569 sec.
# -------------
# Epoch 97/100
# -------------
# -------------
# epoch 96 || Loss:0.1650
# timer:  0.0644 sec.
# -------------
# Epoch 98/100
# -------------
# -------------
# epoch 97 || Loss:0.1156
# timer:  0.0399 sec.
# -------------
# Epoch 99/100
# -------------
# -------------
# epoch 98 || Loss:0.1381
# timer:  0.0416 sec.
# -------------
# Epoch 100/100
# -------------
# -------------
# epoch 99 || Loss:0.1404
# timer:  0.0360 sec.

# %% [markdown]
# ### Error Model

# %%
# dataset = StepDataset(ymax=4., model_mean=model_mean)
# dataloader = torch.utils.data.DataLoader(dataset,batch_size=100,shuffle=True)
# x, y = next(iter(dataloader))
# y

# %%
class CustomLoss(nn.Module):
    
    def __init__(self, beta=0.1):
        super(CustomLoss, self).__init__()
        self.beta = beta
        
    def forward(self, x, y):
        dist = torch.sum(
            torch.pow((y - x).clamp(min=0.),2) + self.beta*torch.pow((y - x).clamp(max=0.),2)
            )
        loss = dist/(x.shape[0]*x.shape[1])
        return loss

# %%
def train_error(model, dataloader, num_epochs):   
    model = nn.DataParallel(model)
    model.to(device)
    model.train()
    
    optimizer = torch.optim.Adam(model.parameters())
    criterion = CustomLoss(beta=0.1)
    
    for epoch in range(num_epochs):      
        t_epoch_start = time.time()
        epoch_loss = 0.0
        
        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')
        
        for data in dataloader:       
            batch_size = len(data[0])
            x = data[0].to(device)
            y = data[1].to(device)
            out = model(x)
            
            loss = criterion(out, y)
            optimizer.zero_grad()
            loss.backward(retain_graph=True)
            optimizer.step()
            
            epoch_loss += loss.item()
            
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Loss:{:.4f} '.format(epoch, epoch_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        
    model.eval()        
    return model

# %%
dataset = StepDataset(3,-3,100,0.1,ymax=4.,model_mean=model_mean)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=16,shuffle=True)

model_error = BasicRegressor()

model_error = train_error(model_error, dataloader, 100)
# Out:
# -------------
# Epoch 1/100
# -------------
# -------------
# epoch 0 || Loss:0.1686
# timer:  0.0603 sec.
# -------------
# Epoch 2/100
# -------------
# -------------
# epoch 1 || Loss:0.1008
# timer:  0.0585 sec.
# -------------
# Epoch 3/100
# -------------
# -------------
# epoch 2 || Loss:0.0917
# timer:  0.0769 sec.
# -------------
# Epoch 4/100
# -------------
# -------------
# epoch 3 || Loss:0.0852
# timer:  0.0889 sec.
# -------------
# Epoch 5/100
# -------------
# -------------
# epoch 4 || Loss:0.0805
# timer:  0.0624 sec.
# -------------
# Epoch 6/100
# -------------
# -------------
# epoch 5 || Loss:0.0833
# timer:  0.0641 sec.
# -------------
# Epoch 7/100
# -------------
# -------------
# epoch 6 || Loss:0.0806
# timer:  0.0595 sec.
# -------------
# Epoch 8/100
# -------------
# -------------
# epoch 7 || Loss:0.0759
# timer:  0.0766 sec.
# -------------
# Epoch 9/100
# -------------
# -------------
# epoch 8 || Loss:0.2516
# timer:  0.0765 sec.
# -------------
# Epoch 10/100
# -------------
# -------------
# epoch 9 || Loss:0.1034
# timer:  0.0982 sec.
# -------------
# Epoch 11/100
# -------------
# -------------
# epoch 10 || Loss:0.0869
# timer:  0.0727 sec.
# -------------
# Epoch 12/100
# -------------
# -------------
# epoch 11 || Loss:0.0793
# timer:  0.0787 sec.
# -------------
# Epoch 13/100
# -------------
# -------------
# epoch 12 || Loss:0.0733
# timer:  0.0635 sec.
# -------------
# Epoch 14/100
# -------------
# -------------
# epoch 13 || Loss:0.0706
# timer:  0.0735 sec.
# -------------
# Epoch 15/100
# -------------
# -------------
# epoch 14 || Loss:0.0665
# timer:  0.0654 sec.
# -------------
# Epoch 16/100
# -------------
# -------------
# epoch 15 || Loss:0.0647
# timer:  0.0652 sec.
# -------------
# Epoch 17/100
# -------------
# -------------
# epoch 16 || Loss:0.0673
# timer:  0.0651 sec.
# -------------
# Epoch 18/100
# -------------
# -------------
# epoch 17 || Loss:0.0609
# timer:  0.0765 sec.
# -------------
# Epoch 19/100
# -------------
# -------------
# epoch 18 || Loss:0.0609
# timer:  0.0973 sec.
# -------------
# Epoch 20/100
# -------------
# -------------
# epoch 19 || Loss:0.0641
# timer:  0.0900 sec.
# -------------
# Epoch 21/100
# -------------
# -------------
# epoch 20 || Loss:0.0725
# timer:  0.0820 sec.
# -------------
# Epoch 22/100
# -------------
# -------------
# epoch 21 || Loss:0.1873
# timer:  0.1284 sec.
# -------------
# Epoch 23/100
# -------------
# -------------
# epoch 22 || Loss:0.0850
# timer:  0.0721 sec.
# -------------
# Epoch 24/100
# -------------
# -------------
# epoch 23 || Loss:0.0794
# timer:  0.0602 sec.
# -------------
# Epoch 25/100
# -------------
# -------------
# epoch 24 || Loss:0.0721
# timer:  0.0729 sec.
# -------------
# Epoch 26/100
# -------------
# -------------
# epoch 25 || Loss:0.0637
# timer:  0.0873 sec.
# -------------
# Epoch 27/100
# -------------
# -------------
# epoch 26 || Loss:0.0642
# timer:  0.1043 sec.
# -------------
# Epoch 28/100
# -------------
# -------------
# epoch 27 || Loss:0.0576
# timer:  0.0726 sec.
# -------------
# Epoch 29/100
# -------------
# -------------
# epoch 28 || Loss:0.0601
# timer:  0.0737 sec.
# -------------
# Epoch 30/100
# -------------
# -------------
# epoch 29 || Loss:0.0571
# timer:  0.0829 sec.
# -------------
# Epoch 31/100
# -------------
# -------------
# epoch 30 || Loss:0.0535
# timer:  0.0566 sec.
# -------------
# Epoch 32/100
# -------------
# -------------
# epoch 31 || Loss:0.0567
# timer:  0.0622 sec.
# -------------
# Epoch 33/100
# -------------
# -------------
# epoch 32 || Loss:0.0610
# timer:  0.0724 sec.
# -------------
# Epoch 34/100
# -------------
# -------------
# epoch 33 || Loss:0.0595
# timer:  0.0651 sec.
# -------------
# Epoch 35/100
# -------------
# -------------
# epoch 34 || Loss:0.0546
# timer:  0.0913 sec.
# -------------
# Epoch 36/100
# -------------
# -------------
# epoch 35 || Loss:0.0521
# timer:  0.0711 sec.
# -------------
# Epoch 37/100
# -------------
# -------------
# epoch 36 || Loss:0.0513
# timer:  0.0701 sec.
# -------------
# Epoch 38/100
# -------------
# -------------
# epoch 37 || Loss:0.0515
# timer:  0.0743 sec.
# -------------
# Epoch 39/100
# -------------
# -------------
# epoch 38 || Loss:0.0494
# timer:  0.0969 sec.
# -------------
# Epoch 40/100
# -------------
# -------------
# epoch 39 || Loss:0.1452
# timer:  0.0637 sec.
# -------------
# Epoch 41/100
# -------------
# -------------
# epoch 40 || Loss:0.0700
# timer:  0.0710 sec.
# -------------
# Epoch 42/100
# -------------
# -------------
# epoch 41 || Loss:0.0747
# timer:  0.0572 sec.
# -------------
# Epoch 43/100
# -------------
# -------------
# epoch 42 || Loss:0.0522
# timer:  0.0573 sec.
# -------------
# Epoch 44/100
# -------------
# -------------
# epoch 43 || Loss:0.0534
# timer:  0.0655 sec.
# -------------
# Epoch 45/100
# -------------
# -------------
# epoch 44 || Loss:0.0496
# timer:  0.0549 sec.
# -------------
# Epoch 46/100
# -------------
# -------------
# epoch 45 || Loss:0.0517
# timer:  0.0665 sec.
# -------------
# Epoch 47/100
# -------------
# -------------
# epoch 46 || Loss:0.0465
# timer:  0.0678 sec.
# -------------
# Epoch 48/100
# -------------
# -------------
# epoch 47 || Loss:0.0433
# timer:  0.0825 sec.
# -------------
# Epoch 49/100
# -------------
# -------------
# epoch 48 || Loss:0.0449
# timer:  0.0659 sec.
# -------------
# Epoch 50/100
# -------------
# -------------
# epoch 49 || Loss:0.0492
# timer:  0.0816 sec.
# -------------
# Epoch 51/100
# -------------
# -------------
# epoch 50 || Loss:0.0416
# timer:  0.0865 sec.
# -------------
# Epoch 52/100
# -------------
# -------------
# epoch 51 || Loss:0.0430
# timer:  0.0725 sec.
# -------------
# Epoch 53/100
# -------------
# -------------
# epoch 52 || Loss:0.0423
# timer:  0.0801 sec.
# -------------
# Epoch 54/100
# -------------
# -------------
# epoch 53 || Loss:0.0446
# timer:  0.0606 sec.
# -------------
# Epoch 55/100
# -------------
# -------------
# epoch 54 || Loss:0.0479
# timer:  0.0550 sec.
# -------------
# Epoch 56/100
# -------------
# -------------
# epoch 55 || Loss:0.0416
# timer:  0.0870 sec.
# -------------
# Epoch 57/100
# -------------
# -------------
# epoch 56 || Loss:0.0460
# timer:  0.0820 sec.
# -------------
# Epoch 58/100
# -------------
# -------------
# epoch 57 || Loss:0.0429
# timer:  0.0709 sec.
# -------------
# Epoch 59/100
# -------------
# -------------
# epoch 58 || Loss:0.0383
# timer:  0.0642 sec.
# -------------
# Epoch 60/100
# -------------
# -------------
# epoch 59 || Loss:0.0383
# timer:  0.0619 sec.
# -------------
# Epoch 61/100
# -------------
# -------------
# epoch 60 || Loss:0.0407
# timer:  0.0786 sec.
# -------------
# Epoch 62/100
# -------------
# -------------
# epoch 61 || Loss:0.0388
# timer:  0.0699 sec.
# -------------
# Epoch 63/100
# -------------
# -------------
# epoch 62 || Loss:0.0342
# timer:  0.0682 sec.
# -------------
# Epoch 64/100
# -------------
# -------------
# epoch 63 || Loss:0.0404
# timer:  0.0838 sec.
# -------------
# Epoch 65/100
# -------------
# -------------
# epoch 64 || Loss:0.0339
# timer:  0.0706 sec.
# -------------
# Epoch 66/100
# -------------
# -------------
# epoch 65 || Loss:0.0335
# timer:  0.0678 sec.
# -------------
# Epoch 67/100
# -------------
# -------------
# epoch 66 || Loss:0.0397
# timer:  0.0786 sec.
# -------------
# Epoch 68/100
# -------------
# -------------
# epoch 67 || Loss:0.0370
# timer:  0.0978 sec.
# -------------
# Epoch 69/100
# -------------
# -------------
# epoch 68 || Loss:0.0320
# timer:  0.0737 sec.
# -------------
# Epoch 70/100
# -------------
# -------------
# epoch 69 || Loss:0.0324
# timer:  0.0707 sec.
# -------------
# Epoch 71/100
# -------------
# -------------
# epoch 70 || Loss:0.0322
# timer:  0.0826 sec.
# -------------
# Epoch 72/100
# -------------
# -------------
# epoch 71 || Loss:0.0331
# timer:  0.0802 sec.
# -------------
# Epoch 73/100
# -------------
# -------------
# epoch 72 || Loss:0.0313
# timer:  0.0942 sec.
# -------------
# Epoch 74/100
# -------------
# -------------
# epoch 73 || Loss:0.0358
# timer:  0.0846 sec.
# -------------
# Epoch 75/100
# -------------
# -------------
# epoch 74 || Loss:0.0391
# timer:  0.0638 sec.
# -------------
# Epoch 76/100
# -------------
# -------------
# epoch 75 || Loss:0.0292
# timer:  0.0690 sec.
# -------------
# Epoch 77/100
# -------------
# -------------
# epoch 76 || Loss:0.0276
# timer:  0.0907 sec.
# -------------
# Epoch 78/100
# -------------
# -------------
# epoch 77 || Loss:0.0298
# timer:  0.0857 sec.
# -------------
# Epoch 79/100
# -------------
# -------------
# epoch 78 || Loss:0.0321
# timer:  0.0859 sec.
# -------------
# Epoch 80/100
# -------------
# -------------
# epoch 79 || Loss:0.0345
# timer:  0.0744 sec.
# -------------
# Epoch 81/100
# -------------
# -------------
# epoch 80 || Loss:0.0281
# timer:  0.0817 sec.
# -------------
# Epoch 82/100
# -------------
# -------------
# epoch 81 || Loss:0.0333
# timer:  0.0796 sec.
# -------------
# Epoch 83/100
# -------------
# -------------
# epoch 82 || Loss:0.0341
# timer:  0.0964 sec.
# -------------
# Epoch 84/100
# -------------
# -------------
# epoch 83 || Loss:0.0355
# timer:  0.1124 sec.
# -------------
# Epoch 85/100
# -------------
# -------------
# epoch 84 || Loss:0.0312
# timer:  0.0559 sec.
# -------------
# Epoch 86/100
# -------------
# -------------
# epoch 85 || Loss:0.0326
# timer:  0.0601 sec.
# -------------
# Epoch 87/100
# -------------
# -------------
# epoch 86 || Loss:0.0291
# timer:  0.0612 sec.
# -------------
# Epoch 88/100
# -------------
# -------------
# epoch 87 || Loss:0.0248
# timer:  0.0822 sec.
# -------------
# Epoch 89/100
# -------------
# -------------
# epoch 88 || Loss:0.0629
# timer:  0.0665 sec.
# -------------
# Epoch 90/100
# -------------
# -------------
# epoch 89 || Loss:0.0357
# timer:  0.0720 sec.
# -------------
# Epoch 91/100
# -------------
# -------------
# epoch 90 || Loss:0.0423
# timer:  0.0733 sec.
# -------------
# Epoch 92/100
# -------------
# -------------
# epoch 91 || Loss:0.0251
# timer:  0.0870 sec.
# -------------
# Epoch 93/100
# -------------
# -------------
# epoch 92 || Loss:0.0336
# timer:  0.1013 sec.
# -------------
# Epoch 94/100
# -------------
# -------------
# epoch 93 || Loss:0.0268
# timer:  0.1063 sec.
# -------------
# Epoch 95/100
# -------------
# -------------
# epoch 94 || Loss:0.0258
# timer:  0.0817 sec.
# -------------
# Epoch 96/100
# -------------
# -------------
# epoch 95 || Loss:0.0279
# timer:  0.1004 sec.
# -------------
# Epoch 97/100
# -------------
# -------------
# epoch 96 || Loss:0.0216
# timer:  0.0765 sec.
# -------------
# Epoch 98/100
# -------------
# -------------
# epoch 97 || Loss:0.0206
# timer:  0.0645 sec.
# -------------
# Epoch 99/100
# -------------
# -------------
# epoch 98 || Loss:0.0249
# timer:  0.0618 sec.
# -------------
# Epoch 100/100
# -------------
# -------------
# epoch 99 || Loss:0.0184
# timer:  0.0757 sec.

# %% [markdown]
# ## Validation

# %%
length = 100
start = -3
end = 3
waith = end - start
val_x = torch.tensor([[i] for i in np.arange(start,end,waith/length)])
val_y = (val_x>0)*4
pred_y = model_mean(val_x).detach().cpu()
pred_std = torch.sqrt(model_error(val_x).detach().cpu())


fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.errorbar(val_x, pred_y, pred_std, label="predict")
ax.plot(val_x, val_y, label="true",c="red")
ax.grid()
ax.legend(loc='upper left')
plt.xlim(-3, 3)
plt.ylim(-1.5, 6)
fig.show()
# Out:
# /home/yashima/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   del sys.path[0]

# %% [markdown]
# # Stochastic Reression

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Modified ReLU

# %%
def ReLUGauss(mu_in, var_in, epsilon=1.0e-6, cut_sd=4.0):
    mu_out = torch.zeros(mu_in.shape[0], mu_in.shape[1])
    var_out = torch.zeros(var_in.shape[0], var_in.shape[1])
    mu = mu_in
    var = var_in
    sigma = torch.sqrt(var+1e-16)

    if (var < 0).any().item(): raise Exception(f"ERROR in ReLUGauss: 'var_in' should be all positive value, but it has negative value.")
    idx_SmallSigma = (sigma < epsilon)
    if cut_sd != None:
        idx_LargeMu = (mu > cut_sd*sigma)
        idx_SmallMU = (mu < -cut_sd*sigma)

    sqrt2 = math.sqrt(2.0)
    sqrt2pi = math.sqrt(2.0*math.pi)    
    z = mu / (sqrt2*sigma+1e-16)
    E = torch.erf(z)
    X = torch.exp(-z*z)
    mu_out = sigma/sqrt2pi*X + mu/2.0*(1.0+E)
    var_out = (1.0+E)/4.0*(mu*mu*(1.0-E)+2.0*var) - sigma*X/sqrt2pi*(sigma*X/sqrt2pi+mu*E)
    
    idx_SmallVarOut = (var_out<0.0)*(var_out>-epsilon)
#     isError = ((var_out<0.0)*(var_out<=-epsilon)).any().item()
#     if isError:
#         msg= f'ERROR in ReLUGauss: (mu: {mu}\n, sigma: {sigma}\n, mu_out: {mu_out}\n, var_out: {var_out}\n)'
#         print(msg)
#         raise Exception(msg)


    mu_out = mu_out*~idx_SmallSigma + idx_SmallSigma*torch.relu(mu)
    var_out *= ~idx_SmallSigma
    if cut_sd != None:
        mu_out = mu_out*~(idx_LargeMu*~idx_SmallSigma) + (idx_LargeMu*~idx_SmallSigma)*mu
        var_out = var_out*~(idx_LargeMu*~idx_SmallSigma) + (idx_LargeMu*~idx_SmallSigma)*var
        mu_out = mu_out*~(idx_SmallMU*~(idx_LargeMu|idx_SmallSigma))
        var_out = var_out*~(idx_SmallMU*~(idx_LargeMu|idx_SmallSigma))
        var_out = var_out*~(idx_SmallVarOut*~((idx_LargeMu|idx_SmallSigma)|idx_SmallMU))
    else:
        var_out = var_out*~(idx_SmallVarOut*~idx_SmallSigma)
            
    var_out = torch.diag_embed(var_out)
    
    return mu_out, var_out

# %%
length = 100
start = -5
end = 5
waith = end - start
x = torch.arange(start, end, waith/length).view(-1, 1)
in_var = torch.ones(length, 1)
y, out_var = ReLUGauss(x, in_var)
out_var = out_var.reshape(-1, 1)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.errorbar(x, y, torch.sqrt(out_var), label="E[ReLU] +/- sd[ReLU]")
ax.plot(x, torch.relu(x), label="ReLU")
ax.grid()
ax.legend(loc='upper left')
plt.xlim(start, end)
plt.ylim(-0.5, end+0.5)
fig.show()
# Out:
# /home/yashima/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   if sys.path[0] == '':

# %% [markdown]
# ### Custom DropOut

# %%
class CustomDropout(nn.Module):
    
    __constants__ = ['p', 'inplace']

    def __init__(self, p=0.5, inplace=False):
        super(CustomDropout, self).__init__()
        if p < 0 or p > 1:
            raise ValueError("dropout probability has to be between 0 and 1, "
                             "but got {}".format(p))
        self.p = p
        self.inplace = inplace
        self.flag = torch.zeros(1,1)
    
    def forward(self, input):
        mu_in = input[0]
        var_in = input[1]    
        self.flag = F.dropout(torch.ones(mu_in.shape[0], mu_in.shape[1]), self.p, self.training, self.inplace)
        self.flag = self.flag.to(device)
        try:           
            mu_out = mu_in*self.flag
            var_out = var_in*(torch.diag_embed(self.flag))
        except:     
            self.flag = self.flag.to("cpu")
            mu_out = mu_in*self.flag
            var_out = var_in*(torch.diag_embed(self.flag))
        
        return mu_out, var_out
    
    def extra_repr(self):
        return 'p={}, inplace={}'.format(self.p, self.inplace)
    
    def to(self, *args, **kwargs):
        self.b = self.flag.to(*args, **kwargs) 
        return self

# %% [markdown]
# ### Modeling

# %%
def ModifyInput(input):
    if input.dim() == 2:
        mu = input[:, 0].unsqueeze(-1)
        var = input[:, 1].unsqueeze(-1).unsqueeze(-1)
    else:
        raise Exception("Input shape should be (BATCH x 2).")
    return mu, var

def ModifyOutput(input):
    mu = input[0]
    var = input[1]
    out = torch.cat([mu, var], dim=1)
        
    return out


class StochasticLinear(nn.Module):
    
    def __init__(self, in_features, out_features):
        super(StochasticLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(torch.Tensor(out_features, in_features))
        self.bias = nn.Parameter(torch.Tensor(out_features))
        self.reset_parameters()
        
    def reset_parameters(self):
        nn.init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        fan_in, _ = nn.init._calculate_fan_in_and_fan_out(self.weight)
        bound = 1 / math.sqrt(fan_in)
        nn.init.uniform_(self.bias, -bound, bound)
        
    def forward(self, input):
        mu_in = input[0]
        var_in = input[1]
        mu_out = mu_in @ self.weight.T + self.bias
        var_out = torch.diagonal(self.weight @ var_in @ self.weight.T, dim1=-2, dim2=-1)
                
        return mu_out, var_out
    
    def extra_repr(self):
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias
        )
    
    
class StochasticReLU(nn.Module):
    def __init__(self, inplace=False):
        super(StochasticReLU, self).__init__()
        self.inplace = inplace
        
    def forward(self, input):
        mu_in = input[0]
        var_in = input[1]
        mu_out, var_out = ReLUGauss(mu_in, var_in)
        return mu_out, var_out
        
    def extra_repr(self):
        inplace_str = 'inplace=True' if self.inplace else ''
        return inplace_str

# %%
class StochasticRegressor(nn.Module):
    
    def __init__(self):
        super(StochasticRegressor, self).__init__()
        self.layer1 = StochasticLinear(1, 200)
        self.layer2 = StochasticLinear(200, 200)
        self.last = StochasticLinear(200, 1)
        self.dropout = CustomDropout(p=0.01)
        
    def forward(self, x):
        out = ModifyInput(x)
        out = self.layer1(out)
        out = StochasticReLU()(out)
        out = self.dropout(out)
        out = self.layer2(out)
        out = StochasticReLU()(out)
        out = self.dropout(out)
        out = self.last(out)
        out = ModifyOutput(out)
        
        return out

# %% [markdown]
# ## Get Weigts

# %%
def LoadMeanWeight(model_mean, model_stochastic):
    length = len(model_mean.state_dict().keys())
    keys_mean = iter(model_mean.state_dict().keys())
    keys_stochastic = iter(model_stochastic.state_dict().keys())
    for i in range(length):
        model_stochastic.state_dict()[next(keys_stochastic)][:] = model_mean.state_dict()[next(keys_mean)]
    
    model_stochastic.eval()
    return model_stochastic

# %%
model_stochastic = StochasticRegressor()
model_stochastic = LoadMeanWeight(model_mean, model_stochastic)

# %% [markdown]
# ## Prediction

# %%
length = 100
start = -3
end = 3
waith = end - start
in_var = 0.25
val_x = torch.tensor([[i, in_var] for i in np.arange(start,end,waith/length)])
val_y = (val_x[:,0]>0)*4

pred_y1 = model_stochastic(val_x).detach().cpu()
mu1 = pred_y1[:,0]
var1 = pred_y1[:,1]
std1 = torch.sqrt(var1)

# pred_y2 = model2(val_x).detach().cpu()
# mu2 = pred_y2[:,0]
# var2 = pred_y2[:,1]
# std2 = torch.sqrt(var2)


fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(1,2,1)
ax1.errorbar(val_x[:,0], mu1, std1, label="NN (mean+std, x_sd=0)")
ax1.plot(val_x[:,0], val_y, label="true")
ax1.grid()
ax1.legend(loc='upper left')
plt.xlim(-3, 3)
plt.ylim(-1.5, 6.5)

# ax2 = fig.add_subplot(1,2,2)
# ax2.errorbar(val_x[:,0], mu2, std2, label="NN (mean+std, x_sd=0.5)")
# ax2.plot(val_x[:,0], val_y, label="true")
# ax2.grid()
# ax2.legend(loc='upper left')
# plt.xlim(-3, 3)
# plt.ylim(-1.5, 6.5)

fig.show()
