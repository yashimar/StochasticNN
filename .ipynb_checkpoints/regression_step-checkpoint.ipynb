# %% [markdown]
# # Imports

# %%
import random
import math
import time
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import special

import torch 
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms
from torchsummary import summary

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = torch.device('cuda') 
print('device : ', device)
print('num gpu : ', torch.cuda.device_count())
# Out:
# device :  cuda
# num gpu :  4

# %%
# torch.manual_seed(1234)
# np.random.seed(1234)
# random.seed(1234)

# %% [markdown]
# # Generate Data

# %%
np.array([[1, 1] for i in range(10)]).shape
# Out:
# (10, 2)

# %%
class StepDataset(data.Dataset):
    
    def __init__(self, upper=3, lower=-3, length=100, error_range=0.1, ymax=1., x_var=False):
        self.upper = upper
        self.lower = lower
        self.length = length
        self.error_range = error_range
        self.noise = np.array([2 * self.error_range * np. random.rand() - self.error_range for i in range(self.length)]).reshape(-1,1).astype(np.float32)

        if x_var != None:
            self.var = (2*self.error_range)**2/12
            self.input = np.array([[(self.upper - self.lower) * np. random.rand() + self.lower, x_var] for i in range(self.length)]).astype(np.float32)
            self.output = np.array([[x.item()*ymax,self.var] for x in (self.input[:,0]>0)]).astype(np.float32)
            self.output[:,0] += self.noise.reshape(-1)
        else:
            self.input = np.array([(self.upper - self.lower) * np. random.rand() + self.lower for i in range(self.length)]).reshape(-1,1).astype(np.float32)
            self.output = (ymax * (self.input > 0) + self.noise).astype(np.float32)

    def __len__(self):
        return self.length
    
    def __getitem__(self, index):
        x = self.input[index]
        y = self.output[index]
        
        return x, y

# %%
sample_dataset = StepDataset(x_var=0)
sample_dataloader = torch.utils.data.DataLoader(sample_dataset,batch_size=32,shuffle=True)
sample_dataloader = iter(sample_dataloader)
x, y = next(sample_dataloader)

# %%
# sample_dataset = StepDataset(3,-3,100,0.1)
# sample_dataloader = torch.utils.data.DataLoader(sample_dataset,batch_size=100,shuffle=True)
# sample_dataloader = iter(sample_dataloader)
# x, y = next(sample_dataloader)

dataset = StepDataset(ymax=4., x_var=0.25)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=100,shuffle=True)
x, y = next(iter(dataloader))
x = x[:,0]
y = y[:,0]


plt.scatter(x, y)
plt.xlim(-3, 3)
plt.ylim(-0.5, 5.5)
plt.grid()
plt.show()

# %% [markdown]
# # Basic Regression

# %% [markdown]
# ## Modeling

# %%
class BasicRegressor(nn.Module):
    
    def __init__(self):
        super(BasicRegressor, self).__init__()
        self.layer1 = nn.Linear(1, 200)
        self.layer2 = nn.Linear(200, 200)
        self.last = nn.Linear(200, 1)
        self.dropout = nn.Dropout(p=0.01)
        
    def forward(self, x):
        out = self.layer1(x)
        out = F.relu(out)
        out = self.dropout(out)
        out = self.layer2(out)
        out = F.relu(out)
        out = self.dropout(out)
        out = self.last(out)
        
        return out

# %%
net = BasicRegressor().to(device)
print(net)
summary(net,(1,))
# Out:
# BasicRegressor(
#   (layer1): Linear(in_features=1, out_features=200, bias=True)
#   (layer2): Linear(in_features=200, out_features=200, bias=True)
#   (last): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.01, inplace=False)
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 200]             400
#            Dropout-2                  [-1, 200]               0
#             Linear-3                  [-1, 200]          40,200
#            Dropout-4                  [-1, 200]               0
#             Linear-5                    [-1, 1]             201
# ================================================================
# Total params: 40,801
# Trainable params: 40,801
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.16
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------

# %%
net = BasicRegressor()
net(torch.tensor([[0.]]))
# Out:
# tensor([[-0.0963]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ## Train

# %%
def train(model, dataloader, num_epochs):   
    model = nn.DataParallel(model)
    model.to(device)
    model.train()
    
    optimizer = torch.optim.Adam(model.parameters())
    criterion = nn.MSELoss()
    
    for epoch in range(num_epochs):      
        t_epoch_start = time.time()
        epoch_loss = 0.0
        
        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')
        
        for data in dataloader:       
            batch_size = len(data[0])
            x = data[0].to(device)
            y = data[1].to(device)
            out = model(x)
            
            loss = criterion(out, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Loss:{:.4f} '.format(epoch, epoch_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        
    return model

# %%
dataset = StepDataset(3,-3,100,0.1)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=16,shuffle=True)

model = BasicRegressor().to(device)

model = train(model, dataloader, 100)
# Out:
# -------------
# Epoch 1/100
# -------------
# -------------
# epoch 0 || Loss:0.5503
# timer:  0.1091 sec.
# -------------
# Epoch 2/100
# -------------
# -------------
# epoch 1 || Loss:0.1114
# timer:  0.0609 sec.
# -------------
# Epoch 3/100
# -------------
# -------------
# epoch 2 || Loss:0.1206
# timer:  0.0592 sec.
# -------------
# Epoch 4/100
# -------------
# -------------
# epoch 3 || Loss:0.0680
# timer:  0.0624 sec.
# -------------
# Epoch 5/100
# -------------
# -------------
# epoch 4 || Loss:0.0569
# timer:  0.1109 sec.
# -------------
# Epoch 6/100
# -------------
# -------------
# epoch 5 || Loss:0.0413
# timer:  0.0440 sec.
# -------------
# Epoch 7/100
# -------------
# -------------
# epoch 6 || Loss:0.0362
# timer:  0.0560 sec.
# -------------
# Epoch 8/100
# -------------
# -------------
# epoch 7 || Loss:0.0272
# timer:  0.0529 sec.
# -------------
# Epoch 9/100
# -------------
# -------------
# epoch 8 || Loss:0.0246
# timer:  0.0414 sec.
# -------------
# Epoch 10/100
# -------------
# -------------
# epoch 9 || Loss:0.0438
# timer:  0.0458 sec.
# -------------
# Epoch 11/100
# -------------
# -------------
# epoch 10 || Loss:0.0259
# timer:  0.0737 sec.
# -------------
# Epoch 12/100
# -------------
# -------------
# epoch 11 || Loss:0.0213
# timer:  0.0619 sec.
# -------------
# Epoch 13/100
# -------------
# -------------
# epoch 12 || Loss:0.0191
# timer:  0.0544 sec.
# -------------
# Epoch 14/100
# -------------
# -------------
# epoch 13 || Loss:0.0200
# timer:  0.0567 sec.
# -------------
# Epoch 15/100
# -------------
# -------------
# epoch 14 || Loss:0.0237
# timer:  0.0710 sec.
# -------------
# Epoch 16/100
# -------------
# -------------
# epoch 15 || Loss:0.0210
# timer:  0.0497 sec.
# -------------
# Epoch 17/100
# -------------
# -------------
# epoch 16 || Loss:0.0203
# timer:  0.0803 sec.
# -------------
# Epoch 18/100
# -------------
# -------------
# epoch 17 || Loss:0.0185
# timer:  0.0673 sec.
# -------------
# Epoch 19/100
# -------------
# -------------
# epoch 18 || Loss:0.0195
# timer:  0.0517 sec.
# -------------
# Epoch 20/100
# -------------
# -------------
# epoch 19 || Loss:0.0189
# timer:  0.0534 sec.
# -------------
# Epoch 21/100
# -------------
# -------------
# epoch 20 || Loss:0.0230
# timer:  0.0589 sec.
# -------------
# Epoch 22/100
# -------------
# -------------
# epoch 21 || Loss:0.0183
# timer:  0.0530 sec.
# -------------
# Epoch 23/100
# -------------
# -------------
# epoch 22 || Loss:0.0224
# timer:  0.0741 sec.
# -------------
# Epoch 24/100
# -------------
# -------------
# epoch 23 || Loss:0.0200
# timer:  0.0616 sec.
# -------------
# Epoch 25/100
# -------------
# -------------
# epoch 24 || Loss:0.0191
# timer:  0.1011 sec.
# -------------
# Epoch 26/100
# -------------
# -------------
# epoch 25 || Loss:0.0165
# timer:  0.0641 sec.
# -------------
# Epoch 27/100
# -------------
# -------------
# epoch 26 || Loss:0.0326
# timer:  0.0478 sec.
# -------------
# Epoch 28/100
# -------------
# -------------
# epoch 27 || Loss:0.0219
# timer:  0.0499 sec.
# -------------
# Epoch 29/100
# -------------
# -------------
# epoch 28 || Loss:0.0277
# timer:  0.0517 sec.
# -------------
# Epoch 30/100
# -------------
# -------------
# epoch 29 || Loss:0.0210
# timer:  0.0527 sec.
# -------------
# Epoch 31/100
# -------------
# -------------
# epoch 30 || Loss:0.0331
# timer:  0.1021 sec.
# -------------
# Epoch 32/100
# -------------
# -------------
# epoch 31 || Loss:0.0450
# timer:  0.0615 sec.
# -------------
# Epoch 33/100
# -------------
# -------------
# epoch 32 || Loss:0.0252
# timer:  0.0442 sec.
# -------------
# Epoch 34/100
# -------------
# -------------
# epoch 33 || Loss:0.0297
# timer:  0.0519 sec.
# -------------
# Epoch 35/100
# -------------
# -------------
# epoch 34 || Loss:0.0344
# timer:  0.0773 sec.
# -------------
# Epoch 36/100
# -------------
# -------------
# epoch 35 || Loss:0.0285
# timer:  0.0948 sec.
# -------------
# Epoch 37/100
# -------------
# -------------
# epoch 36 || Loss:0.0265
# timer:  0.0717 sec.
# -------------
# Epoch 38/100
# -------------
# -------------
# epoch 37 || Loss:0.0217
# timer:  0.0459 sec.
# -------------
# Epoch 39/100
# -------------
# -------------
# epoch 38 || Loss:0.0346
# timer:  0.0466 sec.
# -------------
# Epoch 40/100
# -------------
# -------------
# epoch 39 || Loss:0.0248
# timer:  0.0482 sec.
# -------------
# Epoch 41/100
# -------------
# -------------
# epoch 40 || Loss:0.0186
# timer:  0.0603 sec.
# -------------
# Epoch 42/100
# -------------
# -------------
# epoch 41 || Loss:0.0167
# timer:  0.0832 sec.
# -------------
# Epoch 43/100
# -------------
# -------------
# epoch 42 || Loss:0.0164
# timer:  0.0586 sec.
# -------------
# Epoch 44/100
# -------------
# -------------
# epoch 43 || Loss:0.0179
# timer:  0.0379 sec.
# -------------
# Epoch 45/100
# -------------
# -------------
# epoch 44 || Loss:0.0162
# timer:  0.0513 sec.
# -------------
# Epoch 46/100
# -------------
# -------------
# epoch 45 || Loss:0.0157
# timer:  0.0459 sec.
# -------------
# Epoch 47/100
# -------------
# -------------
# epoch 46 || Loss:0.0213
# timer:  0.0609 sec.
# -------------
# Epoch 48/100
# -------------
# -------------
# epoch 47 || Loss:0.0167
# timer:  0.0505 sec.
# -------------
# Epoch 49/100
# -------------
# -------------
# epoch 48 || Loss:0.0173
# timer:  0.0481 sec.
# -------------
# Epoch 50/100
# -------------
# -------------
# epoch 49 || Loss:0.0167
# timer:  0.0666 sec.
# -------------
# Epoch 51/100
# -------------
# -------------
# epoch 50 || Loss:0.0158
# timer:  0.0624 sec.
# -------------
# Epoch 52/100
# -------------
# -------------
# epoch 51 || Loss:0.0181
# timer:  0.0477 sec.
# -------------
# Epoch 53/100
# -------------
# -------------
# epoch 52 || Loss:0.0197
# timer:  0.0463 sec.
# -------------
# Epoch 54/100
# -------------
# -------------
# epoch 53 || Loss:0.0160
# timer:  0.0403 sec.
# -------------
# Epoch 55/100
# -------------
# -------------
# epoch 54 || Loss:0.0183
# timer:  0.0448 sec.
# -------------
# Epoch 56/100
# -------------
# -------------
# epoch 55 || Loss:0.0164
# timer:  0.0564 sec.
# -------------
# Epoch 57/100
# -------------
# -------------
# epoch 56 || Loss:0.0194
# timer:  0.0641 sec.
# -------------
# Epoch 58/100
# -------------
# -------------
# epoch 57 || Loss:0.0173
# timer:  0.0803 sec.
# -------------
# Epoch 59/100
# -------------
# -------------
# epoch 58 || Loss:0.0179
# timer:  0.0472 sec.
# -------------
# Epoch 60/100
# -------------
# -------------
# epoch 59 || Loss:0.0187
# timer:  0.0683 sec.
# -------------
# Epoch 61/100
# -------------
# -------------
# epoch 60 || Loss:0.0232
# timer:  0.0702 sec.
# -------------
# Epoch 62/100
# -------------
# -------------
# epoch 61 || Loss:0.0180
# timer:  0.0422 sec.
# -------------
# Epoch 63/100
# -------------
# -------------
# epoch 62 || Loss:0.0155
# timer:  0.0615 sec.
# -------------
# Epoch 64/100
# -------------
# -------------
# epoch 63 || Loss:0.0166
# timer:  0.0829 sec.
# -------------
# Epoch 65/100
# -------------
# -------------
# epoch 64 || Loss:0.0136
# timer:  0.0514 sec.
# -------------
# Epoch 66/100
# -------------
# -------------
# epoch 65 || Loss:0.0177
# timer:  0.0599 sec.
# -------------
# Epoch 67/100
# -------------
# -------------
# epoch 66 || Loss:0.0137
# timer:  0.0475 sec.
# -------------
# Epoch 68/100
# -------------
# -------------
# epoch 67 || Loss:0.0271
# timer:  0.0589 sec.
# -------------
# Epoch 69/100
# -------------
# -------------
# epoch 68 || Loss:0.0208
# timer:  0.0530 sec.
# -------------
# Epoch 70/100
# -------------
# -------------
# epoch 69 || Loss:0.0175
# timer:  0.0793 sec.
# -------------
# Epoch 71/100
# -------------
# -------------
# epoch 70 || Loss:0.0153
# timer:  0.0498 sec.
# -------------
# Epoch 72/100
# -------------
# -------------
# epoch 71 || Loss:0.0205
# timer:  0.0589 sec.
# -------------
# Epoch 73/100
# -------------
# -------------
# epoch 72 || Loss:0.0166
# timer:  0.0565 sec.
# -------------
# Epoch 74/100
# -------------
# -------------
# epoch 73 || Loss:0.0184
# timer:  0.0690 sec.
# -------------
# Epoch 75/100
# -------------
# -------------
# epoch 74 || Loss:0.0188
# timer:  0.0775 sec.
# -------------
# Epoch 76/100
# -------------
# -------------
# epoch 75 || Loss:0.0184
# timer:  0.0584 sec.
# -------------
# Epoch 77/100
# -------------
# -------------
# epoch 76 || Loss:0.0166
# timer:  0.0681 sec.
# -------------
# Epoch 78/100
# -------------
# -------------
# epoch 77 || Loss:0.0315
# timer:  0.0472 sec.
# -------------
# Epoch 79/100
# -------------
# -------------
# epoch 78 || Loss:0.0249
# timer:  0.0568 sec.
# -------------
# Epoch 80/100
# -------------
# -------------
# epoch 79 || Loss:0.0300
# timer:  0.0706 sec.
# -------------
# Epoch 81/100
# -------------
# -------------
# epoch 80 || Loss:0.0264
# timer:  0.0698 sec.
# -------------
# Epoch 82/100
# -------------
# -------------
# epoch 81 || Loss:0.0391
# timer:  0.0792 sec.
# -------------
# Epoch 83/100
# -------------
# -------------
# epoch 82 || Loss:0.0200
# timer:  0.0426 sec.
# -------------
# Epoch 84/100
# -------------
# -------------
# epoch 83 || Loss:0.0277
# timer:  0.0441 sec.
# -------------
# Epoch 85/100
# -------------
# -------------
# epoch 84 || Loss:0.0170
# timer:  0.0645 sec.
# -------------
# Epoch 86/100
# -------------
# -------------
# epoch 85 || Loss:0.0166
# timer:  0.0624 sec.
# -------------
# Epoch 87/100
# -------------
# -------------
# epoch 86 || Loss:0.0215
# timer:  0.0901 sec.
# -------------
# Epoch 88/100
# -------------
# -------------
# epoch 87 || Loss:0.0157
# timer:  0.0856 sec.
# -------------
# Epoch 89/100
# -------------
# -------------
# epoch 88 || Loss:0.0126
# timer:  0.0535 sec.
# -------------
# Epoch 90/100
# -------------
# -------------
# epoch 89 || Loss:0.0154
# timer:  0.0680 sec.
# -------------
# Epoch 91/100
# -------------
# -------------
# epoch 90 || Loss:0.0131
# timer:  0.0680 sec.
# -------------
# Epoch 92/100
# -------------
# -------------
# epoch 91 || Loss:0.0160
# timer:  0.0911 sec.
# -------------
# Epoch 93/100
# -------------
# -------------
# epoch 92 || Loss:0.0176
# timer:  0.0795 sec.
# -------------
# Epoch 94/100
# -------------
# -------------
# epoch 93 || Loss:0.0193
# timer:  0.0385 sec.
# -------------
# Epoch 95/100
# -------------
# -------------
# epoch 94 || Loss:0.0304
# timer:  0.0362 sec.
# -------------
# Epoch 96/100
# -------------
# -------------
# epoch 95 || Loss:0.0182
# timer:  0.0486 sec.
# -------------
# Epoch 97/100
# -------------
# -------------
# epoch 96 || Loss:0.0184
# timer:  0.0632 sec.
# -------------
# Epoch 98/100
# -------------
# -------------
# epoch 97 || Loss:0.0217
# timer:  0.0804 sec.
# -------------
# Epoch 99/100
# -------------
# -------------
# epoch 98 || Loss:0.0155
# timer:  0.0768 sec.
# -------------
# Epoch 100/100
# -------------
# -------------
# epoch 99 || Loss:0.0127
# timer:  0.0504 sec.

# %% [markdown]
# ## Validation

# %%
val_dataset = StepDataset(3,-3,100,0.1)
val_dataloader = iter(torch.utils.data.DataLoader(val_dataset,batch_size=100,shuffle=True))
val_data = next(val_dataloader)
val_x = val_data[0]
val_y = val_data[1]
pred_y = model(val_x).detach().cpu()


fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(val_x, pred_y, label="predict")
ax.scatter(val_x, val_y, label="true")
ax.grid()
ax.legend(loc='upper left')
plt.xlim(-3, 3)
plt.ylim(-0.5, 1.5)
fig.show()

# %% [markdown]
# # Stochastic Reression

# %% [markdown]
# ## Modified ReLU

# %%
def ReLUGauss(mu_in, var_in, epsilon=1.0e-6, cut_sd=4.0):
    mu_out = torch.zeros(mu_in.shape[0], mu_in.shape[1])
    var_out = torch.zeros(var_in.shape[0], var_in.shape[1])
    mu = mu_in
    var = var_in
    sigma = torch.sqrt(var+1e-16)

    if (var < 0).any().item(): raise Exception(f"ERROR in ReLUGauss: 'var_in' should be all positive value, but it has negative value.")
    idx_SmallSigma = (sigma < epsilon)
    if cut_sd != None:
        idx_LargeMu = (mu > cut_sd*sigma)
        idx_SmallMU = (mu < -cut_sd*sigma)

    sqrt2 = math.sqrt(2.0)
    sqrt2pi = math.sqrt(2.0*math.pi)    
    z = mu / (sqrt2*sigma+1e-16)
    E = torch.erf(z)
    X = torch.exp(-z*z)
    mu_out = sigma/sqrt2pi*X + mu/2.0*(1.0+E)
    var_out = (1.0+E)/4.0*(mu*mu*(1.0-E)+2.0*var) - sigma*X/sqrt2pi*(sigma*X/sqrt2pi+mu*E)
    
    idx_SmallVarOut = (var_out<0.0)*(var_out>-epsilon)
    isError = ((var_out<0.0)*(var_out<=-epsilon)).any().item()
    if isError:
        msg= f'ERROR in ReLUGauss: (mu: {mu}\n, sigma: {sigma}\n, mu_out: {mu_out}\n, var_out: {var_out}\n)'
        print(msg)
        raise Exception(msg)


    mu_out = mu_out*~idx_SmallSigma + idx_SmallSigma*torch.relu(mu)
    var_out *= ~idx_SmallSigma
    if cut_sd != None:
        mu_out = mu_out*~(idx_LargeMu*~idx_SmallSigma) + (idx_LargeMu*~idx_SmallSigma)*mu
        var_out = var_out*~(idx_LargeMu*~idx_SmallSigma) + (idx_LargeMu*~idx_SmallSigma)*var
        mu_out = mu_out*~(idx_SmallMU*~(idx_LargeMu|idx_SmallSigma))
        var_out = var_out*~(idx_SmallMU*~(idx_LargeMu|idx_SmallSigma))
        var_out = var_out*~(idx_SmallVarOut*~((idx_LargeMu|idx_SmallSigma)|idx_SmallMU))
    else:
        var_out = var_out*~(idx_SmallVarOut*~idx_SmallSigma)
            
    var_out = torch.diag_embed(var_out)
    
    return mu_out, var_out

# %%
length = 100
start = -5
end = 5
waith = end - start
x = torch.arange(start, end, waith/length).view(-1, 1)
in_var = torch.ones(length, 1)
y, out_var = ReLUGauss(x, in_var)
out_var = out_var.reshape(-1, 1)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.errorbar(x, y, torch.sqrt(out_var), label="E[ReLU] +/- sd[ReLU]")
ax.plot(x, torch.relu(x), label="ReLU")
ax.grid()
ax.legend(loc='upper left')
plt.xlim(start, end)
plt.ylim(-0.5, end+0.5)
fig.show()
# Out:
# /home/yashima/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   if sys.path[0] == '':

# %% [markdown]
# ## Custom DropOut

# %%
class CustomDropout(nn.Module):
    
    __constants__ = ['p', 'inplace']

    def __init__(self, p=0.5, inplace=False):
        super(CustomDropout, self).__init__()
        if p < 0 or p > 1:
            raise ValueError("dropout probability has to be between 0 and 1, "
                             "but got {}".format(p))
        self.p = p
        self.inplace = inplace
        self.flag = torch.zeros(1,1)
    
    def forward(self, input):
        mu_in = input[0]
        var_in = input[1]    
        self.flag = F.dropout(torch.ones(mu_in.shape[0], mu_in.shape[1]), self.p, self.training, self.inplace)
        self.flag = self.flag.to(device)
        try:           
            mu_out = mu_in*self.flag
            var_out = var_in*(torch.diag_embed(self.flag))
        except:     
            self.flag = self.flag.to("cpu")
            mu_out = mu_in*self.flag
            var_out = var_in*(torch.diag_embed(self.flag))
        
        return mu_out, var_out
    
    def extra_repr(self):
        return 'p={}, inplace={}'.format(self.p, self.inplace)
    
    def to(self, *args, **kwargs):
        self.b = self.flag.to(*args, **kwargs) 
        return self

# %% [markdown]
# ## Modeling

# %%
def ModifyInput(input):
    if input.dim() == 2:
        mu = input[:, 0].unsqueeze(-1)
        var = input[:, 1].unsqueeze(-1).unsqueeze(-1)
    else:
        raise Exception("Input shape should be (BATCH x 2).")
    return mu, var

def ModifyOutput(input):
    mu = input[0]
    var = input[1]
    out = torch.cat([mu, var], dim=1)
        
    return out


class StochasticLinear(nn.Module):
    
    def __init__(self, in_features, out_features):
        super(StochasticLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(torch.Tensor(out_features, in_features))
        self.bias = nn.Parameter(torch.Tensor(out_features))
        self.reset_parameters()
        
    def reset_parameters(self):
        nn.init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        fan_in, _ = nn.init._calculate_fan_in_and_fan_out(self.weight)
        bound = 1 / math.sqrt(fan_in)
        nn.init.uniform_(self.bias, -bound, bound)
        
    def forward(self, input):
        mu_in = input[0]
        var_in = input[1]
        mu_out = mu_in @ self.weight.T + self.bias
        var_out = torch.diagonal(self.weight @ var_in @ self.weight.T, dim1=-2, dim2=-1)
                
        return mu_out, var_out
    
    def extra_repr(self):
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias
        )
    
    
class StochasticReLU(nn.Module):
    def __init__(self, inplace=False):
        super(StochasticReLU, self).__init__()
        self.inplace = inplace
        
    def forward(self, input):
        mu_in = input[0]
        var_in = input[1]
        mu_out, var_out = ReLUGauss(mu_in, var_in)
        return mu_out, var_out
        
    def extra_repr(self):
        inplace_str = 'inplace=True' if self.inplace else ''
        return inplace_str

# %%
class StochasticRegressor(nn.Module):
    
    def __init__(self):
        super(StochasticRegressor, self).__init__()
        self.layer1 = StochasticLinear(1, 200)
        self.layer2 = StochasticLinear(200, 200)
        self.last = StochasticLinear(200, 1)
        self.dropout = CustomDropout(p=0.01)
        
    def forward(self, x):
        out = ModifyInput(x)
        out = self.layer1(out)
        out = StochasticReLU()(out)
        out = self.dropout(out)
        out = self.layer2(out)
        out = StochasticReLU()(out)
        out = self.dropout(out)
        out = self.last(out)
        out = ModifyOutput(out)
        
        return out

# %%
from torch.autograd import detect_anomaly
with detect_anomaly():
    dataset = StepDataset(length=2, ymax=4., x_var=0)
    dataloader = torch.utils.data.DataLoader(dataset,batch_size=1,shuffle=True)

    model = StochasticRegressor()

    model = train(model, dataloader, 1)
# Out:
# -------------
# Epoch 1/1
# epoch 0 || Loss:0.0587
# timer:  0.4670 sec.

# %% [markdown]
# ## Train

# %%
def train(model, dataloader, num_epochs):   
    model = nn.DataParallel(model)
    model.to(device)
    model.train()
    
    optimizer = torch.optim.Adam(model.parameters())
    criterion = nn.MSELoss()
    
    for epoch in range(num_epochs):      
        t_epoch_start = time.time()
        epoch_loss = 0.0
        
        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        
        for data in dataloader:       
            batch_size = len(data[0])
            x = data[0].to(device)
            y = data[1].to(device)
            
            optimizer.zero_grad()
            out = model(x)      
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            
        t_epoch_finish = time.time()
        print('epoch {} || Loss:{:.4f} '.format(epoch, epoch_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        
    return model

# %%
dataset = StepDataset(ymax=4., x_var=0.25)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=32,shuffle=True)

model = StochasticRegressor()

model = train(model, dataloader, 500)
# Out:
# -------------
# Epoch 1/500
# epoch 0 || Loss:2.0605
# timer:  0.2292 sec.
# -------------
# Epoch 2/500
# epoch 1 || Loss:0.9236
# timer:  0.1479 sec.
# -------------
# Epoch 3/500
# epoch 2 || Loss:0.5456
# timer:  0.1780 sec.
# -------------
# Epoch 4/500
# epoch 3 || Loss:0.6382
# timer:  0.1814 sec.
# -------------
# Epoch 5/500
# epoch 4 || Loss:0.4698
# timer:  0.1411 sec.
# -------------
# Epoch 6/500
# epoch 5 || Loss:0.5971
# timer:  0.1485 sec.
# -------------
# Epoch 7/500
# epoch 6 || Loss:0.3949
# timer:  0.2089 sec.
# -------------
# Epoch 8/500
# epoch 7 || Loss:0.4334
# timer:  0.1987 sec.
# -------------
# Epoch 9/500
# epoch 8 || Loss:0.2839
# timer:  0.1210 sec.
# -------------
# Epoch 10/500
# epoch 9 || Loss:0.2291
# timer:  0.1754 sec.
# -------------
# Epoch 11/500
# epoch 10 || Loss:0.2491
# timer:  0.1744 sec.
# -------------
# Epoch 12/500
# epoch 11 || Loss:0.2688
# timer:  0.1595 sec.
# -------------
# Epoch 13/500
# epoch 12 || Loss:0.1551
# timer:  0.1578 sec.
# -------------
# Epoch 14/500
# epoch 13 || Loss:0.2071
# timer:  0.1882 sec.
# -------------
# Epoch 15/500
# epoch 14 || Loss:0.1157
# timer:  0.1469 sec.
# -------------
# Epoch 16/500
# epoch 15 || Loss:0.1713
# timer:  0.1687 sec.
# -------------
# Epoch 17/500
# epoch 16 || Loss:0.2068
# timer:  0.1793 sec.
# -------------
# Epoch 18/500
# epoch 17 || Loss:0.1026
# timer:  0.1789 sec.
# -------------
# Epoch 19/500
# epoch 18 || Loss:0.0991
# timer:  0.1449 sec.
# -------------
# Epoch 20/500
# epoch 19 || Loss:0.1170
# timer:  0.1824 sec.
# -------------
# Epoch 21/500
# epoch 20 || Loss:0.1074
# timer:  0.1589 sec.
# -------------
# Epoch 22/500
# epoch 21 || Loss:0.0950
# timer:  0.1674 sec.
# -------------
# Epoch 23/500
# epoch 22 || Loss:0.0928
# timer:  0.1585 sec.
# -------------
# Epoch 24/500
# epoch 23 || Loss:0.0959
# timer:  0.1568 sec.
# -------------
# Epoch 25/500
# epoch 24 || Loss:0.0985
# timer:  0.1266 sec.
# -------------
# Epoch 26/500
# epoch 25 || Loss:0.1195
# timer:  0.1959 sec.
# -------------
# Epoch 27/500
# epoch 26 || Loss:0.1365
# timer:  0.1612 sec.
# -------------
# Epoch 28/500
# epoch 27 || Loss:0.0908
# timer:  0.1427 sec.
# -------------
# Epoch 29/500
# epoch 28 || Loss:0.0876
# timer:  0.1495 sec.
# -------------
# Epoch 30/500
# epoch 29 || Loss:0.0814
# timer:  0.1536 sec.
# -------------
# Epoch 31/500
# epoch 30 || Loss:0.0834
# timer:  0.1841 sec.
# -------------
# Epoch 32/500
# epoch 31 || Loss:0.0897
# timer:  0.1389 sec.
# -------------
# Epoch 33/500
# epoch 32 || Loss:0.0829
# timer:  0.1357 sec.
# -------------
# Epoch 34/500
# epoch 33 || Loss:0.0918
# timer:  0.1821 sec.
# -------------
# Epoch 35/500
# epoch 34 || Loss:0.0857
# timer:  0.1615 sec.
# -------------
# Epoch 36/500
# epoch 35 || Loss:0.1096
# timer:  0.1415 sec.
# -------------
# Epoch 37/500
# epoch 36 || Loss:0.1150
# timer:  0.1379 sec.
# -------------
# Epoch 38/500
# epoch 37 || Loss:0.1175
# timer:  0.1807 sec.
# -------------
# Epoch 39/500
# epoch 38 || Loss:0.0829
# timer:  0.1576 sec.
# -------------
# Epoch 40/500
# epoch 39 || Loss:0.0939
# timer:  0.1845 sec.
# -------------
# Epoch 41/500
# epoch 40 || Loss:0.1053
# timer:  0.1763 sec.
# -------------
# Epoch 42/500
# epoch 41 || Loss:0.1141
# timer:  0.1589 sec.
# -------------
# Epoch 43/500
# epoch 42 || Loss:0.0817
# timer:  0.1222 sec.
# -------------
# Epoch 44/500
# epoch 43 || Loss:0.0808
# timer:  0.1797 sec.
# -------------
# Epoch 45/500
# epoch 44 || Loss:0.0770
# timer:  0.1596 sec.
# -------------
# Epoch 46/500
# epoch 45 || Loss:0.0906
# timer:  0.1837 sec.
# -------------
# Epoch 47/500
# epoch 46 || Loss:0.2628
# timer:  0.1438 sec.
# -------------
# Epoch 48/500
# epoch 47 || Loss:0.1002
# timer:  0.1682 sec.
# -------------
# Epoch 49/500
# epoch 48 || Loss:0.0995
# timer:  0.1771 sec.
# -------------
# Epoch 50/500
# epoch 49 || Loss:0.1062
# timer:  0.1413 sec.
# -------------
# Epoch 51/500
# epoch 50 || Loss:0.1121
# timer:  0.1923 sec.
# -------------
# Epoch 52/500
# epoch 51 || Loss:0.0886
# timer:  0.1456 sec.
# -------------
# Epoch 53/500
# epoch 52 || Loss:0.1175
# timer:  0.1146 sec.
# -------------
# Epoch 54/500
# epoch 53 || Loss:0.0693
# timer:  0.1645 sec.
# -------------
# Epoch 55/500
# epoch 54 || Loss:0.0913
# timer:  0.1761 sec.
# -------------
# Epoch 56/500
# epoch 55 || Loss:0.0816
# timer:  0.1673 sec.
# -------------
# Epoch 57/500
# epoch 56 || Loss:0.1400
# timer:  0.1747 sec.
# -------------
# Epoch 58/500
# epoch 57 || Loss:0.0806
# timer:  0.2132 sec.
# -------------
# Epoch 59/500
# epoch 58 || Loss:0.1902
# timer:  0.1557 sec.
# -------------
# Epoch 60/500
# epoch 59 || Loss:0.0976
# timer:  0.1167 sec.
# -------------
# Epoch 61/500
# epoch 60 || Loss:0.0977
# timer:  0.1889 sec.
# -------------
# Epoch 62/500
# epoch 61 || Loss:0.1260
# timer:  0.1730 sec.
# -------------
# Epoch 63/500
# epoch 62 || Loss:0.0877
# timer:  0.1512 sec.
# -------------
# Epoch 64/500
# epoch 63 || Loss:0.0842
# timer:  0.1449 sec.
# -------------
# Epoch 65/500
# epoch 64 || Loss:0.0892
# timer:  0.1659 sec.
# -------------
# Epoch 66/500
# epoch 65 || Loss:0.1606
# timer:  0.1924 sec.
# -------------
# Epoch 67/500
# epoch 66 || Loss:0.0857
# timer:  0.1277 sec.
# -------------
# Epoch 68/500
# epoch 67 || Loss:0.0732
# timer:  0.1567 sec.
# -------------
# Epoch 69/500
# epoch 68 || Loss:0.0829
# timer:  0.1889 sec.
# -------------
# Epoch 70/500
# epoch 69 || Loss:0.1443
# timer:  0.1409 sec.
# -------------
# Epoch 71/500
# epoch 70 || Loss:0.0800
# timer:  0.1638 sec.
# -------------
# Epoch 72/500
# epoch 71 || Loss:0.0753
# timer:  0.1878 sec.
# -------------
# Epoch 73/500
# epoch 72 || Loss:0.0742
# timer:  0.1137 sec.
# -------------
# Epoch 74/500
# epoch 73 || Loss:0.0717
# timer:  0.1934 sec.
# -------------
# Epoch 75/500
# epoch 74 || Loss:0.0680
# timer:  0.1757 sec.
# -------------
# Epoch 76/500
# epoch 75 || Loss:0.0692
# timer:  0.1806 sec.
# -------------
# Epoch 77/500
# epoch 76 || Loss:0.0678
# timer:  0.1394 sec.
# -------------
# Epoch 78/500
# epoch 77 || Loss:0.0736
# timer:  0.1897 sec.
# -------------
# Epoch 79/500
# epoch 78 || Loss:0.0707
# timer:  0.1529 sec.
# -------------
# Epoch 80/500
# epoch 79 || Loss:0.1000
# timer:  0.1645 sec.
# -------------
# Epoch 81/500
# epoch 80 || Loss:0.0796
# timer:  0.1068 sec.
# -------------
# Epoch 82/500
# epoch 81 || Loss:0.0792
# timer:  0.1490 sec.
# -------------
# Epoch 83/500
# epoch 82 || Loss:0.0652
# timer:  0.2271 sec.
# -------------
# Epoch 84/500
# epoch 83 || Loss:0.0932
# timer:  0.1461 sec.
# -------------
# Epoch 85/500
# epoch 84 || Loss:0.0683
# timer:  0.1590 sec.
# -------------
# Epoch 86/500
# epoch 85 || Loss:0.1577
# timer:  0.1766 sec.
# -------------
# Epoch 87/500
# epoch 86 || Loss:0.0882
# timer:  0.1511 sec.
# -------------
# Epoch 88/500
# epoch 87 || Loss:0.0780
# timer:  0.1341 sec.
# -------------
# Epoch 89/500
# epoch 88 || Loss:0.2811
# timer:  0.2000 sec.
# -------------
# Epoch 90/500
# epoch 89 || Loss:0.0767
# timer:  0.2018 sec.
# -------------
# Epoch 91/500
# epoch 90 || Loss:0.0980
# timer:  0.1250 sec.
# -------------
# Epoch 92/500
# epoch 91 || Loss:0.0908
# timer:  0.1797 sec.
# -------------
# Epoch 93/500
# epoch 92 || Loss:0.0875
# timer:  0.1859 sec.
# -------------
# Epoch 94/500
# epoch 93 || Loss:0.0701
# timer:  0.1480 sec.
# -------------
# Epoch 95/500
# epoch 94 || Loss:0.0718
# timer:  0.1351 sec.
# -------------
# Epoch 96/500
# epoch 95 || Loss:0.0708
# timer:  0.1468 sec.
# -------------
# Epoch 97/500
# epoch 96 || Loss:0.0821
# timer:  0.1603 sec.
# -------------
# Epoch 98/500
# epoch 97 || Loss:0.0692
# timer:  0.1298 sec.
# -------------
# Epoch 99/500
# epoch 98 || Loss:0.0624
# timer:  0.1367 sec.
# -------------
# Epoch 100/500
# epoch 99 || Loss:0.0718
# timer:  0.1939 sec.
# -------------
# Epoch 101/500
# epoch 100 || Loss:0.1194
# timer:  0.1335 sec.
# -------------
# Epoch 102/500
# epoch 101 || Loss:0.2307
# timer:  0.1379 sec.
# -------------
# Epoch 103/500
# epoch 102 || Loss:0.0791
# timer:  0.1309 sec.
# -------------
# Epoch 104/500
# epoch 103 || Loss:0.0702
# timer:  0.2355 sec.
# -------------
# Epoch 105/500
# epoch 104 || Loss:0.0883
# timer:  0.1839 sec.
# -------------
# Epoch 106/500
# epoch 105 || Loss:0.0671
# timer:  0.1709 sec.
# -------------
# Epoch 107/500
# epoch 106 || Loss:0.0636
# timer:  0.1620 sec.
# -------------
# Epoch 108/500
# epoch 107 || Loss:0.0629
# timer:  0.1322 sec.
# -------------
# Epoch 109/500
# epoch 108 || Loss:0.1250
# timer:  0.1177 sec.
# -------------
# Epoch 110/500
# epoch 109 || Loss:0.0743
# timer:  0.1999 sec.
# -------------
# Epoch 111/500
# epoch 110 || Loss:0.1585
# timer:  0.1357 sec.
# -------------
# Epoch 112/500
# epoch 111 || Loss:0.0726
# timer:  0.1420 sec.
# -------------
# Epoch 113/500
# epoch 112 || Loss:0.0837
# timer:  0.1658 sec.
# -------------
# Epoch 114/500
# epoch 113 || Loss:0.0805
# timer:  0.1637 sec.
# -------------
# Epoch 115/500
# epoch 114 || Loss:0.0662
# timer:  0.1690 sec.
# -------------
# Epoch 116/500
# epoch 115 || Loss:0.0832
# timer:  0.1905 sec.
# -------------
# Epoch 117/500
# epoch 116 || Loss:0.1253
# timer:  0.1503 sec.
# -------------
# Epoch 118/500
# epoch 117 || Loss:0.0821
# timer:  0.1849 sec.
# -------------
# Epoch 119/500
# epoch 118 || Loss:0.0797
# timer:  0.1191 sec.
# -------------
# Epoch 120/500
# epoch 119 || Loss:0.0820
# timer:  0.1026 sec.
# -------------
# Epoch 121/500
# epoch 120 || Loss:0.0669
# timer:  0.2198 sec.
# -------------
# Epoch 122/500
# epoch 121 || Loss:0.1195
# timer:  0.1251 sec.
# -------------
# Epoch 123/500
# epoch 122 || Loss:0.0669
# timer:  0.1443 sec.
# -------------
# Epoch 124/500
# epoch 123 || Loss:0.0672
# timer:  0.1855 sec.
# -------------
# Epoch 125/500
# epoch 124 || Loss:0.1218
# timer:  0.1715 sec.
# -------------
# Epoch 126/500
# epoch 125 || Loss:0.0668
# timer:  0.1688 sec.
# -------------
# Epoch 127/500
# epoch 126 || Loss:0.0681
# timer:  0.1961 sec.
# -------------
# Epoch 128/500
# epoch 127 || Loss:0.0687
# timer:  0.1280 sec.
# -------------
# Epoch 129/500
# epoch 128 || Loss:0.0621
# timer:  0.1343 sec.
# -------------
# Epoch 130/500
# epoch 129 || Loss:0.0864
# timer:  0.2271 sec.
# -------------
# Epoch 131/500
# epoch 130 || Loss:0.0605
# timer:  0.1608 sec.
# -------------
# Epoch 132/500
# epoch 131 || Loss:0.0647
# timer:  0.1237 sec.
# -------------
# Epoch 133/500
# epoch 132 || Loss:0.0638
# timer:  0.1593 sec.
# -------------
# Epoch 134/500
# epoch 133 || Loss:0.1220
# timer:  0.1573 sec.
# -------------
# Epoch 135/500
# epoch 134 || Loss:0.0816
# timer:  0.1582 sec.
# -------------
# Epoch 136/500
# epoch 135 || Loss:0.0786
# timer:  0.1409 sec.
# -------------
# Epoch 137/500
# epoch 136 || Loss:0.0822
# timer:  0.1672 sec.
# -------------
# Epoch 138/500
# epoch 137 || Loss:0.1708
# timer:  0.1893 sec.
# -------------
# Epoch 139/500
# epoch 138 || Loss:0.0866
# timer:  0.1706 sec.
# -------------
# Epoch 140/500
# epoch 139 || Loss:0.1689
# timer:  0.1578 sec.
# -------------
# Epoch 141/500
# epoch 140 || Loss:0.0741
# timer:  0.1810 sec.
# -------------
# Epoch 142/500
# epoch 141 || Loss:0.0676
# timer:  0.1651 sec.
# -------------
# Epoch 143/500
# epoch 142 || Loss:0.0674
# timer:  0.1458 sec.
# -------------
# Epoch 144/500
# epoch 143 || Loss:0.0611
# timer:  0.1427 sec.
# -------------
# Epoch 145/500
# epoch 144 || Loss:0.0637
# timer:  0.1929 sec.
# -------------
# Epoch 146/500
# epoch 145 || Loss:0.0612
# timer:  0.2014 sec.
# -------------
# Epoch 147/500
# epoch 146 || Loss:0.0941
# timer:  0.1966 sec.
# -------------
# Epoch 148/500
# epoch 147 || Loss:0.1805
# timer:  0.1648 sec.
# -------------
# Epoch 149/500
# epoch 148 || Loss:0.0659
# timer:  0.1965 sec.
# -------------
# Epoch 150/500
# epoch 149 || Loss:0.1544
# timer:  0.1809 sec.
# -------------
# Epoch 151/500
# epoch 150 || Loss:0.0792
# timer:  0.1162 sec.
# -------------
# Epoch 152/500
# epoch 151 || Loss:0.0716
# timer:  0.1448 sec.
# -------------
# Epoch 153/500
# epoch 152 || Loss:0.0729
# timer:  0.1632 sec.
# -------------
# Epoch 154/500
# epoch 153 || Loss:0.0712
# timer:  0.1561 sec.
# -------------
# Epoch 155/500
# epoch 154 || Loss:0.0583
# timer:  0.1841 sec.
# -------------
# Epoch 156/500
# epoch 155 || Loss:0.0702
# timer:  0.1475 sec.
# -------------
# Epoch 157/500
# epoch 156 || Loss:0.0609
# timer:  0.1754 sec.
# -------------
# Epoch 158/500
# epoch 157 || Loss:0.0649
# timer:  0.1917 sec.
# -------------
# Epoch 159/500
# epoch 158 || Loss:0.0637
# timer:  0.1767 sec.
# -------------
# Epoch 160/500
# epoch 159 || Loss:0.0729
# timer:  0.1589 sec.
# -------------
# Epoch 161/500
# epoch 160 || Loss:0.0706
# timer:  0.1862 sec.
# -------------
# Epoch 162/500
# epoch 161 || Loss:0.1457
# timer:  0.1590 sec.
# -------------
# Epoch 163/500
# epoch 162 || Loss:0.0725
# timer:  0.1173 sec.
# -------------
# Epoch 164/500
# epoch 163 || Loss:0.1143
# timer:  0.1362 sec.
# -------------
# Epoch 165/500
# epoch 164 || Loss:0.0841
# timer:  0.2145 sec.
# -------------
# Epoch 166/500
# epoch 165 || Loss:0.0792
# timer:  0.1815 sec.
# -------------
# Epoch 167/500
# epoch 166 || Loss:0.0624
# timer:  0.1472 sec.
# -------------
# Epoch 168/500
# epoch 167 || Loss:0.0610
# timer:  0.2165 sec.
# -------------
# Epoch 169/500
# epoch 168 || Loss:0.0621
# timer:  0.1983 sec.
# -------------
# Epoch 170/500
# epoch 169 || Loss:0.0639
# timer:  0.1394 sec.
# -------------
# Epoch 171/500
# epoch 170 || Loss:0.0610
# timer:  0.1346 sec.
# -------------
# Epoch 172/500
# epoch 171 || Loss:0.0553
# timer:  0.1627 sec.
# -------------
# Epoch 173/500
# epoch 172 || Loss:0.1233
# timer:  0.1941 sec.
# -------------
# Epoch 174/500
# epoch 173 || Loss:0.0660
# timer:  0.1311 sec.
# -------------
# Epoch 175/500
# epoch 174 || Loss:0.0674
# timer:  0.1356 sec.
# -------------
# Epoch 176/500
# epoch 175 || Loss:0.1506
# timer:  0.2054 sec.
# -------------
# Epoch 177/500
# epoch 176 || Loss:0.0590
# timer:  0.1732 sec.
# -------------
# Epoch 178/500
# epoch 177 || Loss:0.0657
# timer:  0.1366 sec.
# -------------
# Epoch 179/500
# epoch 178 || Loss:0.0675
# timer:  0.1577 sec.
# -------------
# Epoch 180/500
# epoch 179 || Loss:0.0594
# timer:  0.1647 sec.
# -------------
# Epoch 181/500
# epoch 180 || Loss:0.0568
# timer:  0.1570 sec.
# -------------
# Epoch 182/500
# epoch 181 || Loss:0.0657
# timer:  0.1357 sec.
# -------------
# Epoch 183/500
# epoch 182 || Loss:0.0604
# timer:  0.1771 sec.
# -------------
# Epoch 184/500
# epoch 183 || Loss:0.1861
# timer:  0.1928 sec.
# -------------
# Epoch 185/500
# epoch 184 || Loss:0.0681
# timer:  0.1512 sec.
# -------------
# Epoch 186/500
# epoch 185 || Loss:0.0675
# timer:  0.1299 sec.
# -------------
# Epoch 187/500
# epoch 186 || Loss:0.0659
# timer:  0.1901 sec.
# -------------
# Epoch 188/500
# epoch 187 || Loss:0.0655
# timer:  0.1464 sec.
# -------------
# Epoch 189/500
# epoch 188 || Loss:0.0565
# timer:  0.1705 sec.
# -------------
# Epoch 190/500
# epoch 189 || Loss:0.0691
# timer:  0.1759 sec.
# -------------
# Epoch 191/500
# epoch 190 || Loss:0.0699
# timer:  0.1140 sec.
# -------------
# Epoch 192/500
# epoch 191 || Loss:0.0956
# timer:  0.1655 sec.
# -------------
# Epoch 193/500
# epoch 192 || Loss:0.0601
# timer:  0.1766 sec.
# -------------
# Epoch 194/500
# epoch 193 || Loss:0.0607
# timer:  0.1361 sec.
# -------------
# Epoch 195/500
# epoch 194 || Loss:0.0576
# timer:  0.1729 sec.
# -------------
# Epoch 196/500
# epoch 195 || Loss:0.0551
# timer:  0.1439 sec.
# -------------
# Epoch 197/500
# epoch 196 || Loss:0.0594
# timer:  0.1713 sec.
# -------------
# Epoch 198/500
# epoch 197 || Loss:0.0552
# timer:  0.1528 sec.
# -------------
# Epoch 199/500
# epoch 198 || Loss:0.0592
# timer:  0.1638 sec.
# -------------
# Epoch 200/500
# epoch 199 || Loss:0.0619
# timer:  0.1230 sec.
# -------------
# Epoch 201/500
# epoch 200 || Loss:0.0582
# timer:  0.1762 sec.
# -------------
# Epoch 202/500
# epoch 201 || Loss:0.0669
# timer:  0.1613 sec.
# -------------
# Epoch 203/500
# epoch 202 || Loss:0.0623
# timer:  0.1424 sec.
# -------------
# Epoch 204/500
# epoch 203 || Loss:0.1629
# timer:  0.2025 sec.
# -------------
# Epoch 205/500
# epoch 204 || Loss:0.0724
# timer:  0.1529 sec.
# -------------
# Epoch 206/500
# epoch 205 || Loss:0.0937
# timer:  0.1847 sec.
# -------------
# Epoch 207/500
# epoch 206 || Loss:0.0678
# timer:  0.1741 sec.
# -------------
# Epoch 208/500
# epoch 207 || Loss:0.0594
# timer:  0.1423 sec.
# -------------
# Epoch 209/500
# epoch 208 || Loss:0.0579
# timer:  0.1810 sec.
# -------------
# Epoch 210/500
# epoch 209 || Loss:0.0639
# timer:  0.1685 sec.
# -------------
# Epoch 211/500
# epoch 210 || Loss:0.1080
# timer:  0.1656 sec.
# -------------
# Epoch 212/500
# epoch 211 || Loss:0.0504
# timer:  0.1387 sec.
# -------------
# Epoch 213/500
# epoch 212 || Loss:0.0615
# timer:  0.1985 sec.
# -------------
# Epoch 214/500
# epoch 213 || Loss:0.0759
# timer:  0.1494 sec.
# -------------
# Epoch 215/500
# epoch 214 || Loss:0.0615
# timer:  0.1533 sec.
# -------------
# Epoch 216/500
# epoch 215 || Loss:0.0615
# timer:  0.1787 sec.
# -------------
# Epoch 217/500
# epoch 216 || Loss:0.0572
# timer:  0.1396 sec.
# -------------
# Epoch 218/500
# epoch 217 || Loss:0.0578
# timer:  0.2006 sec.
# -------------
# Epoch 219/500
# epoch 218 || Loss:0.1091
# timer:  0.1386 sec.
# -------------
# Epoch 220/500
# epoch 219 || Loss:0.0574
# timer:  0.1248 sec.
# -------------
# Epoch 221/500
# epoch 220 || Loss:0.0569
# timer:  0.1033 sec.
# -------------
# Epoch 222/500
# epoch 221 || Loss:0.0558
# timer:  0.1376 sec.
# -------------
# Epoch 223/500
# epoch 222 || Loss:0.0548
# timer:  0.1651 sec.
# -------------
# Epoch 224/500
# epoch 223 || Loss:0.0565
# timer:  0.1751 sec.
# -------------
# Epoch 225/500
# epoch 224 || Loss:0.0626
# timer:  0.1531 sec.
# -------------
# Epoch 226/500
# epoch 225 || Loss:0.0571
# timer:  0.1343 sec.
# -------------
# Epoch 227/500
# epoch 226 || Loss:0.0625
# timer:  0.1749 sec.
# -------------
# Epoch 228/500
# epoch 227 || Loss:0.0607
# timer:  0.1835 sec.
# -------------
# Epoch 229/500
# epoch 228 || Loss:0.1920
# timer:  0.1296 sec.
# -------------
# Epoch 230/500
# epoch 229 || Loss:0.0729
# timer:  0.1486 sec.
# -------------
# Epoch 231/500
# epoch 230 || Loss:0.0651
# timer:  0.1927 sec.
# -------------
# Epoch 232/500
# epoch 231 || Loss:0.0649
# timer:  0.1581 sec.
# -------------
# Epoch 233/500
# epoch 232 || Loss:0.0653
# timer:  0.1618 sec.
# -------------
# Epoch 234/500
# epoch 233 || Loss:0.0573
# timer:  0.1566 sec.
# -------------
# Epoch 235/500
# epoch 234 || Loss:0.0602
# timer:  0.1482 sec.
# -------------
# Epoch 236/500
# epoch 235 || Loss:0.0551
# timer:  0.2039 sec.
# -------------
# Epoch 237/500
# epoch 236 || Loss:0.0624
# timer:  0.1458 sec.
# -------------
# Epoch 238/500
# epoch 237 || Loss:0.0554
# timer:  0.1603 sec.
# -------------
# Epoch 239/500
# epoch 238 || Loss:0.0510
# timer:  0.1884 sec.
# -------------
# Epoch 240/500
# epoch 239 || Loss:0.1255
# timer:  0.1737 sec.
# -------------
# Epoch 241/500
# epoch 240 || Loss:0.1016
# timer:  0.1486 sec.
# -------------
# Epoch 242/500
# epoch 241 || Loss:0.0796
# timer:  0.1647 sec.
# -------------
# Epoch 243/500
# epoch 242 || Loss:0.0767
# timer:  0.1810 sec.
# -------------
# Epoch 244/500
# epoch 243 || Loss:0.1006
# timer:  0.1544 sec.
# -------------
# Epoch 245/500
# epoch 244 || Loss:0.1555
# timer:  0.1698 sec.
# -------------
# Epoch 246/500
# epoch 245 || Loss:0.0763
# timer:  0.1670 sec.
# -------------
# Epoch 247/500
# epoch 246 || Loss:0.0529
# timer:  0.1562 sec.
# -------------
# Epoch 248/500
# epoch 247 || Loss:0.1759
# timer:  0.1548 sec.
# -------------
# Epoch 249/500
# epoch 248 || Loss:0.0858
# timer:  0.1107 sec.
# -------------
# Epoch 250/500
# epoch 249 || Loss:0.1110
# timer:  0.1003 sec.
# -------------
# Epoch 251/500
# epoch 250 || Loss:0.1137
# timer:  0.1604 sec.
# -------------
# Epoch 252/500
# epoch 251 || Loss:0.0605
# timer:  0.1535 sec.
# -------------
# Epoch 253/500
# epoch 252 || Loss:0.0746
# timer:  0.1805 sec.
# -------------
# Epoch 254/500
# epoch 253 || Loss:0.0738
# timer:  0.1673 sec.
# -------------
# Epoch 255/500
# epoch 254 || Loss:0.0650
# timer:  0.1674 sec.
# -------------
# Epoch 256/500
# epoch 255 || Loss:0.0563
# timer:  0.1489 sec.
# -------------
# Epoch 257/500
# epoch 256 || Loss:0.0560
# timer:  0.1485 sec.
# -------------
# Epoch 258/500
# epoch 257 || Loss:0.0510
# timer:  0.1425 sec.
# -------------
# Epoch 259/500
# epoch 258 || Loss:0.0496
# timer:  0.1516 sec.
# -------------
# Epoch 260/500
# epoch 259 || Loss:0.1194
# timer:  0.1484 sec.
# -------------
# Epoch 261/500
# epoch 260 || Loss:0.0681
# timer:  0.1524 sec.
# -------------
# Epoch 262/500
# epoch 261 || Loss:0.0568
# timer:  0.1394 sec.
# -------------
# Epoch 263/500
# epoch 262 || Loss:0.0531
# timer:  0.1572 sec.
# -------------
# Epoch 264/500
# epoch 263 || Loss:0.0566
# timer:  0.1727 sec.
# -------------
# Epoch 265/500
# epoch 264 || Loss:0.0678
# timer:  0.1640 sec.
# -------------
# Epoch 266/500
# epoch 265 || Loss:0.2621
# timer:  0.1643 sec.
# -------------
# Epoch 267/500
# epoch 266 || Loss:0.1306
# timer:  0.1875 sec.
# -------------
# Epoch 268/500
# epoch 267 || Loss:0.0514
# timer:  0.1495 sec.
# -------------
# Epoch 269/500
# epoch 268 || Loss:0.0616
# timer:  0.1110 sec.
# -------------
# Epoch 270/500
# epoch 269 || Loss:0.0559
# timer:  0.1613 sec.
# -------------
# Epoch 271/500
# epoch 270 || Loss:0.1068
# timer:  0.1355 sec.
# -------------
# Epoch 272/500
# epoch 271 || Loss:0.0618
# timer:  0.1594 sec.
# -------------
# Epoch 273/500
# epoch 272 || Loss:0.0736
# timer:  0.1311 sec.
# -------------
# Epoch 274/500
# epoch 273 || Loss:0.0790
# timer:  0.1449 sec.
# -------------
# Epoch 275/500
# epoch 274 || Loss:0.0504
# timer:  0.2225 sec.
# -------------
# Epoch 276/500
# epoch 275 || Loss:0.0665
# timer:  0.1352 sec.
# -------------
# Epoch 277/500
# epoch 276 || Loss:0.0594
# timer:  0.1770 sec.
# -------------
# Epoch 278/500
# epoch 277 || Loss:0.0543
# timer:  0.1398 sec.
# -------------
# Epoch 279/500
# epoch 278 || Loss:0.0683
# timer:  0.1521 sec.
# -------------
# Epoch 280/500
# epoch 279 || Loss:0.0564
# timer:  0.1857 sec.
# -------------
# Epoch 281/500
# epoch 280 || Loss:0.0519
# timer:  0.1752 sec.
# -------------
# Epoch 282/500
# epoch 281 || Loss:0.0510
# timer:  0.1454 sec.
# -------------
# Epoch 283/500
# epoch 282 || Loss:0.0526
# timer:  0.1822 sec.
# -------------
# Epoch 284/500
# epoch 283 || Loss:0.0541
# timer:  0.1577 sec.
# -------------
# Epoch 285/500
# epoch 284 || Loss:0.0471
# timer:  0.1820 sec.
# -------------
# Epoch 286/500
# epoch 285 || Loss:0.1092
# timer:  0.1392 sec.
# -------------
# Epoch 287/500
# epoch 286 || Loss:0.0728
# timer:  0.1670 sec.
# -------------
# Epoch 288/500
# epoch 287 || Loss:0.2224
# timer:  0.1395 sec.
# -------------
# Epoch 289/500
# epoch 288 || Loss:0.0600
# timer:  0.1699 sec.
# -------------
# Epoch 290/500
# epoch 289 || Loss:0.0679
# timer:  0.1290 sec.
# -------------
# Epoch 291/500
# epoch 290 || Loss:0.0615
# timer:  0.1900 sec.
# -------------
# Epoch 292/500
# epoch 291 || Loss:0.0552
# timer:  0.2029 sec.
# -------------
# Epoch 293/500
# epoch 292 || Loss:0.0638
# timer:  0.1580 sec.
# -------------
# Epoch 294/500
# epoch 293 || Loss:0.0635
# timer:  0.1212 sec.
# -------------
# Epoch 295/500
# epoch 294 || Loss:0.0489
# timer:  0.2007 sec.
# -------------
# Epoch 296/500
# epoch 295 || Loss:0.0533
# timer:  0.1294 sec.
# -------------
# Epoch 297/500
# epoch 296 || Loss:0.0563
# timer:  0.1794 sec.
# -------------
# Epoch 298/500
# epoch 297 || Loss:0.0500
# timer:  0.1455 sec.
# -------------
# Epoch 299/500
# epoch 298 || Loss:0.0506
# timer:  0.1562 sec.
# -------------
# Epoch 300/500
# epoch 299 || Loss:0.0468
# timer:  0.1694 sec.
# -------------
# Epoch 301/500
# epoch 300 || Loss:0.0502
# timer:  0.1588 sec.
# -------------
# Epoch 302/500
# epoch 301 || Loss:0.0510
# timer:  0.1505 sec.
# -------------
# Epoch 303/500
# epoch 302 || Loss:0.0541
# timer:  0.2170 sec.
# -------------
# Epoch 304/500
# epoch 303 || Loss:0.0557
# timer:  0.1669 sec.
# -------------
# Epoch 305/500
# epoch 304 || Loss:0.0572
# timer:  0.1789 sec.
# -------------
# Epoch 306/500
# epoch 305 || Loss:0.1015
# timer:  0.1396 sec.
# -------------
# Epoch 307/500
# epoch 306 || Loss:0.0549
# timer:  0.1492 sec.
# -------------
# Epoch 308/500
# epoch 307 || Loss:0.0659
# timer:  0.1770 sec.
# -------------
# Epoch 309/500
# epoch 308 || Loss:0.0539
# timer:  0.1549 sec.
# -------------
# Epoch 310/500
# epoch 309 || Loss:0.0565
# timer:  0.1779 sec.
# -------------
# Epoch 311/500
# epoch 310 || Loss:0.0643
# timer:  0.2066 sec.
# -------------
# Epoch 312/500
# epoch 311 || Loss:0.0698
# timer:  0.1983 sec.
# -------------
# Epoch 313/500
# epoch 312 || Loss:0.0660
# timer:  0.1598 sec.
# -------------
# Epoch 314/500
# epoch 313 || Loss:0.0521
# timer:  0.1349 sec.
# -------------
# Epoch 315/500
# epoch 314 || Loss:0.0547
# timer:  0.1626 sec.
# -------------
# Epoch 316/500
# epoch 315 || Loss:0.0546
# timer:  0.1772 sec.
# -------------
# Epoch 317/500
# epoch 316 || Loss:0.0517
# timer:  0.1499 sec.
# -------------
# Epoch 318/500
# epoch 317 || Loss:0.1146
# timer:  0.2139 sec.
# -------------
# Epoch 319/500
# epoch 318 || Loss:0.0601
# timer:  0.1810 sec.
# -------------
# Epoch 320/500
# epoch 319 || Loss:0.0660
# timer:  0.1228 sec.
# -------------
# Epoch 321/500
# epoch 320 || Loss:0.0616
# timer:  0.1871 sec.
# -------------
# Epoch 322/500
# epoch 321 || Loss:0.0607
# timer:  0.1646 sec.
# -------------
# Epoch 323/500
# epoch 322 || Loss:0.0653
# timer:  0.1906 sec.
# -------------
# Epoch 324/500
# epoch 323 || Loss:0.0762
# timer:  0.1425 sec.
# -------------
# Epoch 325/500
# epoch 324 || Loss:0.0716
# timer:  0.1653 sec.
# -------------
# Epoch 326/500
# epoch 325 || Loss:0.0624
# timer:  0.1120 sec.
# -------------
# Epoch 327/500
# epoch 326 || Loss:0.0912
# timer:  0.1541 sec.
# -------------
# Epoch 328/500
# epoch 327 || Loss:0.0877
# timer:  0.1903 sec.
# -------------
# Epoch 329/500
# epoch 328 || Loss:0.1426
# timer:  0.1568 sec.
# -------------
# Epoch 330/500
# epoch 329 || Loss:0.1286
# timer:  0.1429 sec.
# -------------
# Epoch 331/500
# epoch 330 || Loss:0.0615
# timer:  0.1950 sec.
# -------------
# Epoch 332/500
# epoch 331 || Loss:0.1618
# timer:  0.2006 sec.
# -------------
# Epoch 333/500
# epoch 332 || Loss:0.1187
# timer:  0.1533 sec.
# -------------
# Epoch 334/500
# epoch 333 || Loss:0.0613
# timer:  0.1252 sec.
# -------------
# Epoch 335/500
# epoch 334 || Loss:0.0590
# timer:  0.1942 sec.
# -------------
# Epoch 336/500
# epoch 335 || Loss:0.0628
# timer:  0.1705 sec.
# -------------
# Epoch 337/500
# epoch 336 || Loss:0.0579
# timer:  0.1613 sec.
# -------------
# Epoch 338/500
# epoch 337 || Loss:0.0685
# timer:  0.1597 sec.
# -------------
# Epoch 339/500
# epoch 338 || Loss:0.0502
# timer:  0.1954 sec.
# -------------
# Epoch 340/500
# epoch 339 || Loss:0.0633
# timer:  0.1227 sec.
# -------------
# Epoch 341/500
# epoch 340 || Loss:0.0645
# timer:  0.1724 sec.
# -------------
# Epoch 342/500
# epoch 341 || Loss:0.0520
# timer:  0.1426 sec.
# -------------
# Epoch 343/500
# epoch 342 || Loss:0.0645
# timer:  0.1352 sec.
# -------------
# Epoch 344/500
# epoch 343 || Loss:0.0531
# timer:  0.2111 sec.
# -------------
# Epoch 345/500
# epoch 344 || Loss:0.0504
# timer:  0.1543 sec.
# -------------
# Epoch 346/500
# epoch 345 || Loss:0.0461
# timer:  0.1464 sec.
# -------------
# Epoch 347/500
# epoch 346 || Loss:0.1064
# timer:  0.1734 sec.
# -------------
# Epoch 348/500
# epoch 347 || Loss:0.0973
# timer:  0.1809 sec.
# -------------
# Epoch 349/500
# epoch 348 || Loss:0.0661
# timer:  0.1690 sec.
# -------------
# Epoch 350/500
# epoch 349 || Loss:0.0606
# timer:  0.1644 sec.
# -------------
# Epoch 351/500
# epoch 350 || Loss:0.0651
# timer:  0.1805 sec.
# -------------
# Epoch 352/500
# epoch 351 || Loss:0.0566
# timer:  0.1587 sec.
# -------------
# Epoch 353/500
# epoch 352 || Loss:0.0597
# timer:  0.1615 sec.
# -------------
# Epoch 354/500
# epoch 353 || Loss:0.2062
# timer:  0.1661 sec.
# -------------
# Epoch 355/500
# epoch 354 || Loss:0.0724
# timer:  0.1713 sec.
# -------------
# Epoch 356/500
# epoch 355 || Loss:0.0984
# timer:  0.1761 sec.
# -------------
# Epoch 357/500
# epoch 356 || Loss:0.0792
# timer:  0.1764 sec.
# -------------
# Epoch 358/500
# epoch 357 || Loss:0.0631
# timer:  0.1661 sec.
# -------------
# Epoch 359/500
# epoch 358 || Loss:0.0583
# timer:  0.1827 sec.
# -------------
# Epoch 360/500
# epoch 359 || Loss:0.0596
# timer:  0.1981 sec.
# -------------
# Epoch 361/500
# epoch 360 || Loss:0.0556
# timer:  0.1891 sec.
# -------------
# Epoch 362/500
# epoch 361 || Loss:0.0510
# timer:  0.1429 sec.
# -------------
# Epoch 363/500
# epoch 362 || Loss:0.0772
# timer:  0.1796 sec.
# -------------
# Epoch 364/500
# epoch 363 || Loss:0.0574
# timer:  0.1671 sec.
# -------------
# Epoch 365/500
# epoch 364 || Loss:0.0537
# timer:  0.1645 sec.
# -------------
# Epoch 366/500
# epoch 365 || Loss:0.0571
# timer:  0.1318 sec.
# -------------
# Epoch 367/500
# epoch 366 || Loss:0.0618
# timer:  0.1127 sec.
# -------------
# Epoch 368/500
# epoch 367 || Loss:0.0545
# timer:  0.2150 sec.
# -------------
# Epoch 369/500
# epoch 368 || Loss:0.0711
# timer:  0.1750 sec.
# -------------
# Epoch 370/500
# epoch 369 || Loss:0.0504
# timer:  0.1347 sec.
# -------------
# Epoch 371/500
# epoch 370 || Loss:0.0601
# timer:  0.1506 sec.
# -------------
# Epoch 372/500
# epoch 371 || Loss:0.0535
# timer:  0.1817 sec.
# -------------
# Epoch 373/500
# epoch 372 || Loss:0.0524
# timer:  0.1335 sec.
# -------------
# Epoch 374/500
# epoch 373 || Loss:0.0481
# timer:  0.1420 sec.
# -------------
# Epoch 375/500
# epoch 374 || Loss:0.0502
# timer:  0.1788 sec.
# -------------
# Epoch 376/500
# epoch 375 || Loss:0.1009
# timer:  0.1877 sec.
# -------------
# Epoch 377/500
# epoch 376 || Loss:0.0480
# timer:  0.1735 sec.
# -------------
# Epoch 378/500
# epoch 377 || Loss:0.0572
# timer:  0.1460 sec.
# -------------
# Epoch 379/500
# epoch 378 || Loss:0.0520
# timer:  0.1740 sec.
# -------------
# Epoch 380/500
# epoch 379 || Loss:0.1076
# timer:  0.1520 sec.
# -------------
# Epoch 381/500
# epoch 380 || Loss:0.0559
# timer:  0.1993 sec.
# -------------
# Epoch 382/500
# epoch 381 || Loss:0.0479
# timer:  0.1585 sec.
# -------------
# Epoch 383/500
# epoch 382 || Loss:0.0541
# timer:  0.1273 sec.
# -------------
# Epoch 384/500
# epoch 383 || Loss:0.0600
# timer:  0.1897 sec.
# -------------
# Epoch 385/500
# epoch 384 || Loss:0.0506
# timer:  0.1584 sec.
# -------------
# Epoch 386/500
# epoch 385 || Loss:0.0516
# timer:  0.1761 sec.
# -------------
# Epoch 387/500
# epoch 386 || Loss:0.0548
# timer:  0.1441 sec.
# -------------
# Epoch 388/500
# epoch 387 || Loss:0.0475
# timer:  0.1871 sec.
# -------------
# Epoch 389/500
# epoch 388 || Loss:0.0842
# timer:  0.1572 sec.
# -------------
# Epoch 390/500
# epoch 389 || Loss:0.0491
# timer:  0.1637 sec.
# -------------
# Epoch 391/500
# epoch 390 || Loss:0.0504
# timer:  0.1889 sec.
# -------------
# Epoch 392/500
# epoch 391 || Loss:0.0533
# timer:  0.2016 sec.
# -------------
# Epoch 393/500
# epoch 392 || Loss:0.0464
# timer:  0.1843 sec.
# -------------
# Epoch 394/500
# epoch 393 || Loss:0.0473
# timer:  0.1601 sec.
# -------------
# Epoch 395/500
# epoch 394 || Loss:0.0531
# timer:  0.1308 sec.
# -------------
# Epoch 396/500
# epoch 395 || Loss:0.0562
# timer:  0.1137 sec.
# -------------
# Epoch 397/500
# epoch 396 || Loss:0.0510
# timer:  0.1878 sec.
# -------------
# Epoch 398/500
# epoch 397 || Loss:0.0478
# timer:  0.1501 sec.
# -------------
# Epoch 399/500
# epoch 398 || Loss:0.0609
# timer:  0.1281 sec.
# -------------
# Epoch 400/500
# epoch 399 || Loss:0.0489
# timer:  0.1506 sec.
# -------------
# Epoch 401/500
# epoch 400 || Loss:0.1022
# timer:  0.1611 sec.
# -------------
# Epoch 402/500
# epoch 401 || Loss:0.1148
# timer:  0.1358 sec.
# -------------
# Epoch 403/500
# epoch 402 || Loss:0.0588
# timer:  0.1296 sec.
# -------------
# Epoch 404/500
# epoch 403 || Loss:0.0533
# timer:  0.1511 sec.
# -------------
# Epoch 405/500
# epoch 404 || Loss:0.0537
# timer:  0.1821 sec.
# -------------
# Epoch 406/500
# epoch 405 || Loss:0.0589
# timer:  0.1644 sec.
# -------------
# Epoch 407/500
# epoch 406 || Loss:0.0494
# timer:  0.1806 sec.
# -------------
# Epoch 408/500
# epoch 407 || Loss:0.0544
# timer:  0.1406 sec.
# -------------
# Epoch 409/500
# epoch 408 || Loss:0.0563
# timer:  0.1900 sec.
# -------------
# Epoch 410/500
# epoch 409 || Loss:0.0520
# timer:  0.2004 sec.
# -------------
# Epoch 411/500
# epoch 410 || Loss:0.0480
# timer:  0.1749 sec.
# -------------
# Epoch 412/500
# epoch 411 || Loss:0.0511
# timer:  0.1382 sec.
# -------------
# Epoch 413/500
# epoch 412 || Loss:0.0530
# timer:  0.1718 sec.
# -------------
# Epoch 414/500
# epoch 413 || Loss:0.0499
# timer:  0.1841 sec.
# -------------
# Epoch 415/500
# epoch 414 || Loss:0.0471
# timer:  0.1452 sec.
# -------------
# Epoch 416/500
# epoch 415 || Loss:0.1109
# timer:  0.1684 sec.
# -------------
# Epoch 417/500
# epoch 416 || Loss:0.0645
# timer:  0.1543 sec.
# -------------
# Epoch 418/500
# epoch 417 || Loss:0.2019
# timer:  0.1508 sec.
# -------------
# Epoch 419/500
# epoch 418 || Loss:0.0762
# timer:  0.1509 sec.
# -------------
# Epoch 420/500
# epoch 419 || Loss:0.1831
# timer:  0.1683 sec.
# -------------
# Epoch 421/500
# epoch 420 || Loss:0.0806
# timer:  0.1798 sec.
# -------------
# Epoch 422/500
# epoch 421 || Loss:0.0638
# timer:  0.1965 sec.
# -------------
# Epoch 423/500
# epoch 422 || Loss:0.0707
# timer:  0.1553 sec.
# -------------
# Epoch 424/500
# epoch 423 || Loss:0.0576
# timer:  0.1173 sec.
# -------------
# Epoch 425/500
# epoch 424 || Loss:0.0610
# timer:  0.1536 sec.
# -------------
# Epoch 426/500
# epoch 425 || Loss:0.0554
# timer:  0.1640 sec.
# -------------
# Epoch 427/500
# epoch 426 || Loss:0.0589
# timer:  0.1420 sec.
# -------------
# Epoch 428/500
# epoch 427 || Loss:0.0556
# timer:  0.1759 sec.
# -------------
# Epoch 429/500
# epoch 428 || Loss:0.0507
# timer:  0.1071 sec.
# -------------
# Epoch 430/500
# epoch 429 || Loss:0.0446
# timer:  0.1880 sec.
# -------------
# Epoch 431/500
# epoch 430 || Loss:0.0503
# timer:  0.2137 sec.
# -------------
# Epoch 432/500
# epoch 431 || Loss:0.0559
# timer:  0.1418 sec.
# -------------
# Epoch 433/500
# epoch 432 || Loss:0.0404
# timer:  0.1727 sec.
# -------------
# Epoch 434/500
# epoch 433 || Loss:0.0503
# timer:  0.1816 sec.
# -------------
# Epoch 435/500
# epoch 434 || Loss:0.0487
# timer:  0.1246 sec.
# -------------
# Epoch 436/500
# epoch 435 || Loss:0.0469
# timer:  0.1598 sec.
# -------------
# Epoch 437/500
# epoch 436 || Loss:0.0466
# timer:  0.1578 sec.
# -------------
# Epoch 438/500
# epoch 437 || Loss:0.0474
# timer:  0.1615 sec.
# -------------
# Epoch 439/500
# epoch 438 || Loss:0.0482
# timer:  0.1235 sec.
# -------------
# Epoch 440/500
# epoch 439 || Loss:0.0494
# timer:  0.1731 sec.
# -------------
# Epoch 441/500
# epoch 440 || Loss:0.0474
# timer:  0.1940 sec.
# -------------
# Epoch 442/500
# epoch 441 || Loss:0.0518
# timer:  0.1279 sec.
# -------------
# Epoch 443/500
# epoch 442 || Loss:0.0513
# timer:  0.1943 sec.
# -------------
# Epoch 444/500
# epoch 443 || Loss:0.0519
# timer:  0.1690 sec.
# -------------
# Epoch 445/500
# epoch 444 || Loss:0.0466
# timer:  0.1468 sec.
# -------------
# Epoch 446/500
# epoch 445 || Loss:0.0408
# timer:  0.1576 sec.
# -------------
# Epoch 447/500
# epoch 446 || Loss:0.0517
# timer:  0.1846 sec.
# -------------
# Epoch 448/500
# epoch 447 || Loss:0.0431
# timer:  0.1509 sec.
# -------------
# Epoch 449/500
# epoch 448 || Loss:0.0491
# timer:  0.1548 sec.
# -------------
# Epoch 450/500
# epoch 449 || Loss:0.0491
# timer:  0.1519 sec.
# -------------
# Epoch 451/500
# epoch 450 || Loss:0.0517
# timer:  0.1793 sec.
# -------------
# Epoch 452/500
# epoch 451 || Loss:0.0487
# timer:  0.2050 sec.
# -------------
# Epoch 453/500
# epoch 452 || Loss:0.0448
# timer:  0.1678 sec.
# -------------
# Epoch 454/500
# epoch 453 || Loss:0.0971
# timer:  0.1650 sec.
# -------------
# Epoch 455/500
# epoch 454 || Loss:0.0532
# timer:  0.1623 sec.
# -------------
# Epoch 456/500
# epoch 455 || Loss:0.0502
# timer:  0.1607 sec.
# -------------
# Epoch 457/500
# epoch 456 || Loss:0.0587
# timer:  0.1475 sec.
# -------------
# Epoch 458/500
# epoch 457 || Loss:0.0501
# timer:  0.1548 sec.
# -------------
# Epoch 459/500
# epoch 458 || Loss:0.0445
# timer:  0.1939 sec.
# -------------
# Epoch 460/500
# epoch 459 || Loss:0.0478
# timer:  0.1732 sec.
# -------------
# Epoch 461/500
# epoch 460 || Loss:0.0470
# timer:  0.1360 sec.
# -------------
# Epoch 462/500
# epoch 461 || Loss:0.0489
# timer:  0.1052 sec.
# -------------
# Epoch 463/500
# epoch 462 || Loss:0.0495
# timer:  0.1675 sec.
# -------------
# Epoch 464/500
# epoch 463 || Loss:0.0485
# timer:  0.2147 sec.
# -------------
# Epoch 465/500
# epoch 464 || Loss:0.0494
# timer:  0.1347 sec.
# -------------
# Epoch 466/500
# epoch 465 || Loss:0.1279
# timer:  0.1708 sec.
# -------------
# Epoch 467/500
# epoch 466 || Loss:0.0558
# timer:  0.1924 sec.
# -------------
# Epoch 468/500
# epoch 467 || Loss:0.0559
# timer:  0.1438 sec.
# -------------
# Epoch 469/500
# epoch 468 || Loss:0.0626
# timer:  0.1921 sec.
# -------------
# Epoch 470/500
# epoch 469 || Loss:0.0597
# timer:  0.1709 sec.
# -------------
# Epoch 471/500
# epoch 470 || Loss:0.0485
# timer:  0.1368 sec.
# -------------
# Epoch 472/500
# epoch 471 || Loss:0.0503
# timer:  0.1792 sec.
# -------------
# Epoch 473/500
# epoch 472 || Loss:0.0451
# timer:  0.1795 sec.
# -------------
# Epoch 474/500
# epoch 473 || Loss:0.0462
# timer:  0.1523 sec.
# -------------
# Epoch 475/500
# epoch 474 || Loss:0.1733
# timer:  0.1665 sec.
# -------------
# Epoch 476/500
# epoch 475 || Loss:0.0450
# timer:  0.1919 sec.
# -------------
# Epoch 477/500
# epoch 476 || Loss:0.0594
# timer:  0.1493 sec.
# -------------
# Epoch 478/500
# epoch 477 || Loss:0.0670
# timer:  0.1308 sec.
# -------------
# Epoch 479/500
# epoch 478 || Loss:0.0492
# timer:  0.2269 sec.
# -------------
# Epoch 480/500
# epoch 479 || Loss:0.0545
# timer:  0.1579 sec.
# -------------
# Epoch 481/500
# epoch 480 || Loss:0.0493
# timer:  0.1362 sec.
# -------------
# Epoch 482/500
# epoch 481 || Loss:0.0506
# timer:  0.1357 sec.
# -------------
# Epoch 483/500
# epoch 482 || Loss:0.0485
# timer:  0.1577 sec.
# -------------
# Epoch 484/500
# epoch 483 || Loss:0.0496
# timer:  0.1454 sec.
# -------------
# Epoch 485/500
# epoch 484 || Loss:0.1394
# timer:  0.1914 sec.
# -------------
# Epoch 486/500
# epoch 485 || Loss:0.0651
# timer:  0.1583 sec.
# -------------
# Epoch 487/500
# epoch 486 || Loss:0.0697
# timer:  0.1583 sec.
# -------------
# Epoch 488/500
# epoch 487 || Loss:0.0621
# timer:  0.1589 sec.
# -------------
# Epoch 489/500
# epoch 488 || Loss:0.0556
# timer:  0.1841 sec.
# -------------
# Epoch 490/500
# epoch 489 || Loss:0.0476
# timer:  0.1594 sec.
# -------------
# Epoch 491/500
# epoch 490 || Loss:0.0632
# timer:  0.1079 sec.
# -------------
# Epoch 492/500
# epoch 491 || Loss:0.0662
# timer:  0.1345 sec.
# -------------
# Epoch 493/500
# epoch 492 || Loss:0.0506
# timer:  0.1509 sec.
# -------------
# Epoch 494/500
# epoch 493 || Loss:0.0573
# timer:  0.1803 sec.
# -------------
# Epoch 495/500
# epoch 494 || Loss:0.0489
# timer:  0.1593 sec.
# -------------
# Epoch 496/500
# epoch 495 || Loss:0.0451
# timer:  0.1440 sec.
# -------------
# Epoch 497/500
# epoch 496 || Loss:0.0468
# timer:  0.1695 sec.
# -------------
# Epoch 498/500
# epoch 497 || Loss:0.0398
# timer:  0.1754 sec.
# -------------
# Epoch 499/500
# epoch 498 || Loss:0.0504
# timer:  0.1271 sec.
# -------------
# Epoch 500/500
# epoch 499 || Loss:0.0475
# timer:  0.1367 sec.

# %% [markdown]
# ## Validation

# %% [markdown]
# ### $N(x,0)$

# %%
length = 100
start = -3
end = 3
waith = end - start
in_var = 1e-8
val_x = torch.tensor([[i, in_var] for i in np.arange(start,end,waith/length)])
val_y = (val_x[:,0]>0)*4

pred_y = model(val_x).detach().cpu()
mu = pred_y[:,0]
var = pred_y[:,1]
std = torch.sqrt(var)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.errorbar(val_x[:,0], mu, std, label="predict")
ax.plot(val_x[:,0], val_y, label="true")
ax.grid()
ax.legend(loc='upper left')
plt.xlim(-3, 3)
plt.ylim(-0.5, 4.5)
fig.show()

# %% [markdown]
# ### $N(x,0.5^2)$

# %%
length = 100
start = -3
end = 3
waith = end - start
in_var = 1e-8
val_x = torch.tensor([[i, in_var] for i in np.arange(start,end,waith/length)])
val_y = (val_x[:,0]>0)*4

pred_y = model(val_x).detach().cpu()
mu = pred_y[:,0]
var = pred_y[:,1]
std = torch.sqrt(var)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.errorbar(val_x[:,0], mu, std, label="predict")
ax.plot(val_x[:,0], val_y, label="true")
ax.grid()
ax.legend(loc='upper left')
plt.xlim(-3, 3)
plt.ylim(-1.5, 5.5)
fig.show()
