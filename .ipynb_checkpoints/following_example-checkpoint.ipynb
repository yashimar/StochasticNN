# %% [markdown]
# # Imports

# %%
import random
import math
import time
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import special

import torch 
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms
from torchsummary import summary

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = torch.device('cuda') 
print('device : ', device)
print('num gpu : ', torch.cuda.device_count())
# Out:
# device :  cuda
# num gpu :  4

# %%
# torch.manual_seed(1234)
# np.random.seed(1234)
# random.seed(1234)

# %% [markdown]
# # Generate Data

# %%
class StepDataset(data.Dataset):
    
    def __init__(self, upper=5, lower=-3, length=100, error_range=0.1, center=1, ymax=1., x_var=None, y_var=None, model_mean=None):
        self.upper = upper
        self.lower = lower
        self.length = length
        self.error_range = error_range
        self.y_var = y_var
        if self.y_var != None:
            self.noise = np.array([np.random.normal(center,self.y_var) for i in range(self.length)]).reshape(-1,1).astype(np.float32)
        else:
            self.noise = np.array([2 * self.error_range * np. random.rand() - self.error_range for i in range(self.length)]).reshape(-1,1).astype(np.float32)
            self.y_var = (2*self.error_range)**2/12
        
        if x_var != None:
            self.input = np.array([[(self.upper - self.lower) * np. random.rand() + self.lower, x_var] for i in range(self.length)]).astype(np.float32)
            self.output = np.array([[x.item()*ymax,self.y_var] for x in (self.input[:,0]>center)]).astype(np.float32)
            self.output[:,0] += self.noise.reshape(-1)
        else:    
            self.input = np.array([(self.upper - self.lower) * np. random.rand() + self.lower for i in range(self.length)]).reshape(-1,1).astype(np.float32)
            self.output = (ymax * (self.input > center) + self.noise).astype(np.float32)
            if model_mean!=None:
                pred = model_mean(torch.tensor(self.input)).to("cpu")
                self.output = torch.abs(torch.tensor(self.output) - pred)


    def __len__(self):
        return self.length
    
    def __getitem__(self, index):
        x = self.input[index]
        y = self.output[index]
        
        return x, y

# %%
dataset = StepDataset(ymax=4.)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=100,shuffle=True)
x, y = next(iter(dataloader))
x.shape
# Out:
# torch.Size([100, 1])

# %%
# dataset = StepDataset(ymax=4.)
dataset = StepDataset(5,-3,100,0.1,center=1,ymax=4.)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=100,shuffle=True)
x, y = next(iter(dataloader))
x = x[:,0]
y = y[:,0]


plt.scatter(x, y)
plt.xlim(-3, 5)
plt.ylim(-1.5, 6.)
plt.grid()
plt.show()

# %% [markdown]
# # Basic Regression Model

# %% [markdown]
# ## Modeling

# %%
class BasicRegressor(nn.Module):
    
    def __init__(self):
        super(BasicRegressor, self).__init__()
        self.layer1 = nn.Linear(1, 200)
        self.layer2 = nn.Linear(200, 200)
        self.last = nn.Linear(200, 1)
        self.dropout = nn.Dropout(p=0.01)
        
    def forward(self, x):
        out = self.layer1(x)
        out = F.relu(out)
        out = self.dropout(out)
        out = self.layer2(out)
        out = F.relu(out)
        out = self.dropout(out)
        out = self.last(out)
        
        return out

# %%
net = BasicRegressor().to(device)
print(net)
summary(net,(1,))
# Out:
# BasicRegressor(
#   (layer1): Linear(in_features=1, out_features=200, bias=True)
#   (layer2): Linear(in_features=200, out_features=200, bias=True)
#   (last): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.01, inplace=False)
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 200]             400
#            Dropout-2                  [-1, 200]               0
#             Linear-3                  [-1, 200]          40,200
#            Dropout-4                  [-1, 200]               0
#             Linear-5                    [-1, 1]             201
# ================================================================
# Total params: 40,801
# Trainable params: 40,801
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.16
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------

# %%
net = BasicRegressor()
net(torch.tensor([[0.]]))
# Out:
# tensor([[-0.1086]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ## Train

# %% [markdown]
# ### Mean Model

# %%
def train_mean(model, dataloader, num_epochs, lr=2e-3):   
    model = nn.DataParallel(model)
    model.to(device)
    model.train()
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    
    for epoch in range(num_epochs):      
        t_epoch_start = time.time()
        epoch_loss = 0.0
        
        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')
        
        for data in dataloader:       
            batch_size = len(data[0])
            x = data[0].to(device)
            y = data[1].to(device)
            out = model(x)
            
            loss = criterion(out, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Loss:{:.4f} '.format(epoch, epoch_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        
    model.eval()        
    return model

# %%
dataset = StepDataset(5,-3,100,error_range=0.1,center=1,ymax=4.)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=64,shuffle=True)

model_mean = BasicRegressor()
model_mean = train_mean(model_mean, dataloader,300,lr=5e-3)
# Out:
# -------------
# Epoch 1/300
# -------------
# -------------
# epoch 0 || Loss:0.2310
# timer:  0.0206 sec.
# -------------
# Epoch 2/300
# -------------
# -------------
# epoch 1 || Loss:0.1663
# timer:  0.0164 sec.
# -------------
# Epoch 3/300
# -------------
# -------------
# epoch 2 || Loss:0.0776
# timer:  0.0162 sec.
# -------------
# Epoch 4/300
# -------------
# -------------
# epoch 3 || Loss:0.0865
# timer:  0.0173 sec.
# -------------
# Epoch 5/300
# -------------
# -------------
# epoch 4 || Loss:0.0838
# timer:  0.0190 sec.
# -------------
# Epoch 6/300
# -------------
# -------------
# epoch 5 || Loss:0.0612
# timer:  0.0165 sec.
# -------------
# Epoch 7/300
# -------------
# -------------
# epoch 6 || Loss:0.0673
# timer:  0.0320 sec.
# -------------
# Epoch 8/300
# -------------
# -------------
# epoch 7 || Loss:0.0690
# timer:  0.0318 sec.
# -------------
# Epoch 9/300
# -------------
# -------------
# epoch 8 || Loss:0.0560
# timer:  0.0122 sec.
# -------------
# Epoch 10/300
# -------------
# -------------
# epoch 9 || Loss:0.0540
# timer:  0.0162 sec.
# -------------
# Epoch 11/300
# -------------
# -------------
# epoch 10 || Loss:0.0519
# timer:  0.0135 sec.
# -------------
# Epoch 12/300
# -------------
# -------------
# epoch 11 || Loss:0.0447
# timer:  0.0202 sec.
# -------------
# Epoch 13/300
# -------------
# -------------
# epoch 12 || Loss:0.0400
# timer:  0.0147 sec.
# -------------
# Epoch 14/300
# -------------
# -------------
# epoch 13 || Loss:0.0428
# timer:  0.0144 sec.
# -------------
# Epoch 15/300
# -------------
# -------------
# epoch 14 || Loss:0.0371
# timer:  0.0160 sec.
# -------------
# Epoch 16/300
# -------------
# -------------
# epoch 15 || Loss:0.0364
# timer:  0.0268 sec.
# -------------
# Epoch 17/300
# -------------
# -------------
# epoch 16 || Loss:0.0317
# timer:  0.0409 sec.
# -------------
# Epoch 18/300
# -------------
# -------------
# epoch 17 || Loss:0.0278
# timer:  0.0359 sec.
# -------------
# Epoch 19/300
# -------------
# -------------
# epoch 18 || Loss:0.0250
# timer:  0.0274 sec.
# -------------
# Epoch 20/300
# -------------
# -------------
# epoch 19 || Loss:0.0283
# timer:  0.0240 sec.
# -------------
# Epoch 21/300
# -------------
# -------------
# epoch 20 || Loss:0.0209
# timer:  0.0226 sec.
# -------------
# Epoch 22/300
# -------------
# -------------
# epoch 21 || Loss:0.0224
# timer:  0.0144 sec.
# -------------
# Epoch 23/300
# -------------
# -------------
# epoch 22 || Loss:0.0199
# timer:  0.0130 sec.
# -------------
# Epoch 24/300
# -------------
# -------------
# epoch 23 || Loss:0.0217
# timer:  0.0108 sec.
# -------------
# Epoch 25/300
# -------------
# -------------
# epoch 24 || Loss:0.0164
# timer:  0.0116 sec.
# -------------
# Epoch 26/300
# -------------
# -------------
# epoch 25 || Loss:0.0157
# timer:  0.0108 sec.
# -------------
# Epoch 27/300
# -------------
# -------------
# epoch 26 || Loss:0.0159
# timer:  0.0110 sec.
# -------------
# Epoch 28/300
# -------------
# -------------
# epoch 27 || Loss:0.0147
# timer:  0.0138 sec.
# -------------
# Epoch 29/300
# -------------
# -------------
# epoch 28 || Loss:0.0164
# timer:  0.0106 sec.
# -------------
# Epoch 30/300
# -------------
# -------------
# epoch 29 || Loss:0.0138
# timer:  0.0139 sec.
# -------------
# Epoch 31/300
# -------------
# -------------
# epoch 30 || Loss:0.0133
# timer:  0.0155 sec.
# -------------
# Epoch 32/300
# -------------
# -------------
# epoch 31 || Loss:0.0114
# timer:  0.0242 sec.
# -------------
# Epoch 33/300
# -------------
# -------------
# epoch 32 || Loss:0.0138
# timer:  0.0150 sec.
# -------------
# Epoch 34/300
# -------------
# -------------
# epoch 33 || Loss:0.0134
# timer:  0.0150 sec.
# -------------
# Epoch 35/300
# -------------
# -------------
# epoch 34 || Loss:0.0115
# timer:  0.0152 sec.
# -------------
# Epoch 36/300
# -------------
# -------------
# epoch 35 || Loss:0.0120
# timer:  0.0202 sec.
# -------------
# Epoch 37/300
# -------------
# -------------
# epoch 36 || Loss:0.0105
# timer:  0.0219 sec.
# -------------
# Epoch 38/300
# -------------
# -------------
# epoch 37 || Loss:0.0102
# timer:  0.0208 sec.
# -------------
# Epoch 39/300
# -------------
# -------------
# epoch 38 || Loss:0.0115
# timer:  0.0305 sec.
# -------------
# Epoch 40/300
# -------------
# -------------
# epoch 39 || Loss:0.0098
# timer:  0.0351 sec.
# -------------
# Epoch 41/300
# -------------
# -------------
# epoch 40 || Loss:0.0115
# timer:  0.0188 sec.
# -------------
# Epoch 42/300
# -------------
# -------------
# epoch 41 || Loss:0.0112
# timer:  0.0320 sec.
# -------------
# Epoch 43/300
# -------------
# -------------
# epoch 42 || Loss:0.0107
# timer:  0.0206 sec.
# -------------
# Epoch 44/300
# -------------
# -------------
# epoch 43 || Loss:0.0108
# timer:  0.0186 sec.
# -------------
# Epoch 45/300
# -------------
# -------------
# epoch 44 || Loss:0.0103
# timer:  0.0170 sec.
# -------------
# Epoch 46/300
# -------------
# -------------
# epoch 45 || Loss:0.0092
# timer:  0.0437 sec.
# -------------
# Epoch 47/300
# -------------
# -------------
# epoch 46 || Loss:0.0104
# timer:  0.0179 sec.
# -------------
# Epoch 48/300
# -------------
# -------------
# epoch 47 || Loss:0.0078
# timer:  0.0247 sec.
# -------------
# Epoch 49/300
# -------------
# -------------
# epoch 48 || Loss:0.0100
# timer:  0.0149 sec.
# -------------
# Epoch 50/300
# -------------
# -------------
# epoch 49 || Loss:0.0096
# timer:  0.0194 sec.
# -------------
# Epoch 51/300
# -------------
# -------------
# epoch 50 || Loss:0.0104
# timer:  0.0139 sec.
# -------------
# Epoch 52/300
# -------------
# -------------
# epoch 51 || Loss:0.0101
# timer:  0.0190 sec.
# -------------
# Epoch 53/300
# -------------
# -------------
# epoch 52 || Loss:0.0125
# timer:  0.0372 sec.
# -------------
# Epoch 54/300
# -------------
# -------------
# epoch 53 || Loss:0.0096
# timer:  0.0291 sec.
# -------------
# Epoch 55/300
# -------------
# -------------
# epoch 54 || Loss:0.0091
# timer:  0.0125 sec.
# -------------
# Epoch 56/300
# -------------
# -------------
# epoch 55 || Loss:0.0089
# timer:  0.0126 sec.
# -------------
# Epoch 57/300
# -------------
# -------------
# epoch 56 || Loss:0.0111
# timer:  0.0164 sec.
# -------------
# Epoch 58/300
# -------------
# -------------
# epoch 57 || Loss:0.0081
# timer:  0.0175 sec.
# -------------
# Epoch 59/300
# -------------
# -------------
# epoch 58 || Loss:0.0096
# timer:  0.0165 sec.
# -------------
# Epoch 60/300
# -------------
# -------------
# epoch 59 || Loss:0.0101
# timer:  0.0274 sec.
# -------------
# Epoch 61/300
# -------------
# -------------
# epoch 60 || Loss:0.0088
# timer:  0.0175 sec.
# -------------
# Epoch 62/300
# -------------
# -------------
# epoch 61 || Loss:0.0083
# timer:  0.0180 sec.
# -------------
# Epoch 63/300
# -------------
# -------------
# epoch 62 || Loss:0.0067
# timer:  0.0179 sec.
# -------------
# Epoch 64/300
# -------------
# -------------
# epoch 63 || Loss:0.0072
# timer:  0.0172 sec.
# -------------
# Epoch 65/300
# -------------
# -------------
# epoch 64 || Loss:0.0089
# timer:  0.0199 sec.
# -------------
# Epoch 66/300
# -------------
# -------------
# epoch 65 || Loss:0.0069
# timer:  0.0141 sec.
# -------------
# Epoch 67/300
# -------------
# -------------
# epoch 66 || Loss:0.0075
# timer:  0.0168 sec.
# -------------
# Epoch 68/300
# -------------
# -------------
# epoch 67 || Loss:0.0081
# timer:  0.0134 sec.
# -------------
# Epoch 69/300
# -------------
# -------------
# epoch 68 || Loss:0.0081
# timer:  0.0148 sec.
# -------------
# Epoch 70/300
# -------------
# -------------
# epoch 69 || Loss:0.0078
# timer:  0.0177 sec.
# -------------
# Epoch 71/300
# -------------
# -------------
# epoch 70 || Loss:0.0075
# timer:  0.0309 sec.
# -------------
# Epoch 72/300
# -------------
# -------------
# epoch 71 || Loss:0.0078
# timer:  0.0171 sec.
# -------------
# Epoch 73/300
# -------------
# -------------
# epoch 72 || Loss:0.0070
# timer:  0.0250 sec.
# -------------
# Epoch 74/300
# -------------
# -------------
# epoch 73 || Loss:0.0084
# timer:  0.0156 sec.
# -------------
# Epoch 75/300
# -------------
# -------------
# epoch 74 || Loss:0.0090
# timer:  0.0152 sec.
# -------------
# Epoch 76/300
# -------------
# -------------
# epoch 75 || Loss:0.0085
# timer:  0.0164 sec.
# -------------
# Epoch 77/300
# -------------
# -------------
# epoch 76 || Loss:0.0087
# timer:  0.0160 sec.
# -------------
# Epoch 78/300
# -------------
# -------------
# epoch 77 || Loss:0.0070
# timer:  0.0236 sec.
# -------------
# Epoch 79/300
# -------------
# -------------
# epoch 78 || Loss:0.0073
# timer:  0.0139 sec.
# -------------
# Epoch 80/300
# -------------
# -------------
# epoch 79 || Loss:0.0063
# timer:  0.0163 sec.
# -------------
# Epoch 81/300
# -------------
# -------------
# epoch 80 || Loss:0.0095
# timer:  0.0255 sec.
# -------------
# Epoch 82/300
# -------------
# -------------
# epoch 81 || Loss:0.0066
# timer:  0.0138 sec.
# -------------
# Epoch 83/300
# -------------
# -------------
# epoch 82 || Loss:0.0062
# timer:  0.0150 sec.
# -------------
# Epoch 84/300
# -------------
# -------------
# epoch 83 || Loss:0.0078
# timer:  0.0194 sec.
# -------------
# Epoch 85/300
# -------------
# -------------
# epoch 84 || Loss:0.0056
# timer:  0.0145 sec.
# -------------
# Epoch 86/300
# -------------
# -------------
# epoch 85 || Loss:0.0078
# timer:  0.0155 sec.
# -------------
# Epoch 87/300
# -------------
# -------------
# epoch 86 || Loss:0.0055
# timer:  0.0161 sec.
# -------------
# Epoch 88/300
# -------------
# -------------
# epoch 87 || Loss:0.0055
# timer:  0.0191 sec.
# -------------
# Epoch 89/300
# -------------
# -------------
# epoch 88 || Loss:0.0059
# timer:  0.0307 sec.
# -------------
# Epoch 90/300
# -------------
# -------------
# epoch 89 || Loss:0.0065
# timer:  0.0237 sec.
# -------------
# Epoch 91/300
# -------------
# -------------
# epoch 90 || Loss:0.0055
# timer:  0.0226 sec.
# -------------
# Epoch 92/300
# -------------
# -------------
# epoch 91 || Loss:0.0062
# timer:  0.0123 sec.
# -------------
# Epoch 93/300
# -------------
# -------------
# epoch 92 || Loss:0.0066
# timer:  0.0133 sec.
# -------------
# Epoch 94/300
# -------------
# -------------
# epoch 93 || Loss:0.0074
# timer:  0.0106 sec.
# -------------
# Epoch 95/300
# -------------
# -------------
# epoch 94 || Loss:0.0050
# timer:  0.0124 sec.
# -------------
# Epoch 96/300
# -------------
# -------------
# epoch 95 || Loss:0.0055
# timer:  0.0190 sec.
# -------------
# Epoch 97/300
# -------------
# -------------
# epoch 96 || Loss:0.0060
# timer:  0.0189 sec.
# -------------
# Epoch 98/300
# -------------
# -------------
# epoch 97 || Loss:0.0093
# timer:  0.0174 sec.
# -------------
# Epoch 99/300
# -------------
# -------------
# epoch 98 || Loss:0.0064
# timer:  0.0215 sec.
# -------------
# Epoch 100/300
# -------------
# -------------
# epoch 99 || Loss:0.0054
# timer:  0.0142 sec.
# -------------
# Epoch 101/300
# -------------
# -------------
# epoch 100 || Loss:0.0066
# timer:  0.0168 sec.
# -------------
# Epoch 102/300
# -------------
# -------------
# epoch 101 || Loss:0.0066
# timer:  0.0184 sec.
# -------------
# Epoch 103/300
# -------------
# -------------
# epoch 102 || Loss:0.0065
# timer:  0.0167 sec.
# -------------
# Epoch 104/300
# -------------
# -------------
# epoch 103 || Loss:0.0064
# timer:  0.0268 sec.
# -------------
# Epoch 105/300
# -------------
# -------------
# epoch 104 || Loss:0.0077
# timer:  0.0202 sec.
# -------------
# Epoch 106/300
# -------------
# -------------
# epoch 105 || Loss:0.0062
# timer:  0.0187 sec.
# -------------
# Epoch 107/300
# -------------
# -------------
# epoch 106 || Loss:0.0056
# timer:  0.0192 sec.
# -------------
# Epoch 108/300
# -------------
# -------------
# epoch 107 || Loss:0.0060
# timer:  0.0185 sec.
# -------------
# Epoch 109/300
# -------------
# -------------
# epoch 108 || Loss:0.0041
# timer:  0.0308 sec.
# -------------
# Epoch 110/300
# -------------
# -------------
# epoch 109 || Loss:0.0049
# timer:  0.0165 sec.
# -------------
# Epoch 111/300
# -------------
# -------------
# epoch 110 || Loss:0.0056
# timer:  0.0223 sec.
# -------------
# Epoch 112/300
# -------------
# -------------
# epoch 111 || Loss:0.0044
# timer:  0.0182 sec.
# -------------
# Epoch 113/300
# -------------
# -------------
# epoch 112 || Loss:0.0059
# timer:  0.0138 sec.
# -------------
# Epoch 114/300
# -------------
# -------------
# epoch 113 || Loss:0.0061
# timer:  0.0313 sec.
# -------------
# Epoch 115/300
# -------------
# -------------
# epoch 114 || Loss:0.0059
# timer:  0.0119 sec.
# -------------
# Epoch 116/300
# -------------
# -------------
# epoch 115 || Loss:0.0060
# timer:  0.0127 sec.
# -------------
# Epoch 117/300
# -------------
# -------------
# epoch 116 || Loss:0.0049
# timer:  0.0167 sec.
# -------------
# Epoch 118/300
# -------------
# -------------
# epoch 117 || Loss:0.0056
# timer:  0.0312 sec.
# -------------
# Epoch 119/300
# -------------
# -------------
# epoch 118 || Loss:0.0077
# timer:  0.0235 sec.
# -------------
# Epoch 120/300
# -------------
# -------------
# epoch 119 || Loss:0.0096
# timer:  0.0151 sec.
# -------------
# Epoch 121/300
# -------------
# -------------
# epoch 120 || Loss:0.0053
# timer:  0.0136 sec.
# -------------
# Epoch 122/300
# -------------
# -------------
# epoch 121 || Loss:0.0065
# timer:  0.0282 sec.
# -------------
# Epoch 123/300
# -------------
# -------------
# epoch 122 || Loss:0.0092
# timer:  0.0396 sec.
# -------------
# Epoch 124/300
# -------------
# -------------
# epoch 123 || Loss:0.0047
# timer:  0.0196 sec.
# -------------
# Epoch 125/300
# -------------
# -------------
# epoch 124 || Loss:0.0071
# timer:  0.0124 sec.
# -------------
# Epoch 126/300
# -------------
# -------------
# epoch 125 || Loss:0.0066
# timer:  0.0132 sec.
# -------------
# Epoch 127/300
# -------------
# -------------
# epoch 126 || Loss:0.0046
# timer:  0.0155 sec.
# -------------
# Epoch 128/300
# -------------
# -------------
# epoch 127 || Loss:0.0067
# timer:  0.0176 sec.
# -------------
# Epoch 129/300
# -------------
# -------------
# epoch 128 || Loss:0.0072
# timer:  0.0162 sec.
# -------------
# Epoch 130/300
# -------------
# -------------
# epoch 129 || Loss:0.0065
# timer:  0.0157 sec.
# -------------
# Epoch 131/300
# -------------
# -------------
# epoch 130 || Loss:0.0043
# timer:  0.0167 sec.
# -------------
# Epoch 132/300
# -------------
# -------------
# epoch 131 || Loss:0.0061
# timer:  0.0134 sec.
# -------------
# Epoch 133/300
# -------------
# -------------
# epoch 132 || Loss:0.0062
# timer:  0.0168 sec.
# -------------
# Epoch 134/300
# -------------
# -------------
# epoch 133 || Loss:0.0049
# timer:  0.0164 sec.
# -------------
# Epoch 135/300
# -------------
# -------------
# epoch 134 || Loss:0.0048
# timer:  0.0160 sec.
# -------------
# Epoch 136/300
# -------------
# -------------
# epoch 135 || Loss:0.0055
# timer:  0.0179 sec.
# -------------
# Epoch 137/300
# -------------
# -------------
# epoch 136 || Loss:0.0059
# timer:  0.0226 sec.
# -------------
# Epoch 138/300
# -------------
# -------------
# epoch 137 || Loss:0.0054
# timer:  0.0154 sec.
# -------------
# Epoch 139/300
# -------------
# -------------
# epoch 138 || Loss:0.0041
# timer:  0.0163 sec.
# -------------
# Epoch 140/300
# -------------
# -------------
# epoch 139 || Loss:0.0042
# timer:  0.0144 sec.
# -------------
# Epoch 141/300
# -------------
# -------------
# epoch 140 || Loss:0.0030
# timer:  0.0145 sec.
# -------------
# Epoch 142/300
# -------------
# -------------
# epoch 141 || Loss:0.0040
# timer:  0.0161 sec.
# -------------
# Epoch 143/300
# -------------
# -------------
# epoch 142 || Loss:0.0041
# timer:  0.0150 sec.
# -------------
# Epoch 144/300
# -------------
# -------------
# epoch 143 || Loss:0.0045
# timer:  0.0152 sec.
# -------------
# Epoch 145/300
# -------------
# -------------
# epoch 144 || Loss:0.0040
# timer:  0.0145 sec.
# -------------
# Epoch 146/300
# -------------
# -------------
# epoch 145 || Loss:0.0041
# timer:  0.0243 sec.
# -------------
# Epoch 147/300
# -------------
# -------------
# epoch 146 || Loss:0.0031
# timer:  0.0169 sec.
# -------------
# Epoch 148/300
# -------------
# -------------
# epoch 147 || Loss:0.0032
# timer:  0.0170 sec.
# -------------
# Epoch 149/300
# -------------
# -------------
# epoch 148 || Loss:0.0039
# timer:  0.0149 sec.
# -------------
# Epoch 150/300
# -------------
# -------------
# epoch 149 || Loss:0.0039
# timer:  0.0146 sec.
# -------------
# Epoch 151/300
# -------------
# -------------
# epoch 150 || Loss:0.0028
# timer:  0.0171 sec.
# -------------
# Epoch 152/300
# -------------
# -------------
# epoch 151 || Loss:0.0032
# timer:  0.0144 sec.
# -------------
# Epoch 153/300
# -------------
# -------------
# epoch 152 || Loss:0.0029
# timer:  0.0159 sec.
# -------------
# Epoch 154/300
# -------------
# -------------
# epoch 153 || Loss:0.0034
# timer:  0.0331 sec.
# -------------
# Epoch 155/300
# -------------
# -------------
# epoch 154 || Loss:0.0031
# timer:  0.0247 sec.
# -------------
# Epoch 156/300
# -------------
# -------------
# epoch 155 || Loss:0.0033
# timer:  0.0275 sec.
# -------------
# Epoch 157/300
# -------------
# -------------
# epoch 156 || Loss:0.0024
# timer:  0.0126 sec.
# -------------
# Epoch 158/300
# -------------
# -------------
# epoch 157 || Loss:0.0028
# timer:  0.0127 sec.
# -------------
# Epoch 159/300
# -------------
# -------------
# epoch 158 || Loss:0.0030
# timer:  0.0166 sec.
# -------------
# Epoch 160/300
# -------------
# -------------
# epoch 159 || Loss:0.0022
# timer:  0.0174 sec.
# -------------
# Epoch 161/300
# -------------
# -------------
# epoch 160 || Loss:0.0026
# timer:  0.0174 sec.
# -------------
# Epoch 162/300
# -------------
# -------------
# epoch 161 || Loss:0.0028
# timer:  0.0242 sec.
# -------------
# Epoch 163/300
# -------------
# -------------
# epoch 162 || Loss:0.0027
# timer:  0.0164 sec.
# -------------
# Epoch 164/300
# -------------
# -------------
# epoch 163 || Loss:0.0027
# timer:  0.0173 sec.
# -------------
# Epoch 165/300
# -------------
# -------------
# epoch 164 || Loss:0.0023
# timer:  0.0138 sec.
# -------------
# Epoch 166/300
# -------------
# -------------
# epoch 165 || Loss:0.0023
# timer:  0.0147 sec.
# -------------
# Epoch 167/300
# -------------
# -------------
# epoch 166 || Loss:0.0024
# timer:  0.0123 sec.
# -------------
# Epoch 168/300
# -------------
# -------------
# epoch 167 || Loss:0.0021
# timer:  0.0125 sec.
# -------------
# Epoch 169/300
# -------------
# -------------
# epoch 168 || Loss:0.0017
# timer:  0.0124 sec.
# -------------
# Epoch 170/300
# -------------
# -------------
# epoch 169 || Loss:0.0022
# timer:  0.0117 sec.
# -------------
# Epoch 171/300
# -------------
# -------------
# epoch 170 || Loss:0.0033
# timer:  0.0109 sec.
# -------------
# Epoch 172/300
# -------------
# -------------
# epoch 171 || Loss:0.0029
# timer:  0.0191 sec.
# -------------
# Epoch 173/300
# -------------
# -------------
# epoch 172 || Loss:0.0023
# timer:  0.0196 sec.
# -------------
# Epoch 174/300
# -------------
# -------------
# epoch 173 || Loss:0.0022
# timer:  0.0199 sec.
# -------------
# Epoch 175/300
# -------------
# -------------
# epoch 174 || Loss:0.0027
# timer:  0.0176 sec.
# -------------
# Epoch 176/300
# -------------
# -------------
# epoch 175 || Loss:0.0027
# timer:  0.0127 sec.
# -------------
# Epoch 177/300
# -------------
# -------------
# epoch 176 || Loss:0.0030
# timer:  0.0153 sec.
# -------------
# Epoch 178/300
# -------------
# -------------
# epoch 177 || Loss:0.0027
# timer:  0.0185 sec.
# -------------
# Epoch 179/300
# -------------
# -------------
# epoch 178 || Loss:0.0032
# timer:  0.0169 sec.
# -------------
# Epoch 180/300
# -------------
# -------------
# epoch 179 || Loss:0.0029
# timer:  0.0290 sec.
# -------------
# Epoch 181/300
# -------------
# -------------
# epoch 180 || Loss:0.0038
# timer:  0.0158 sec.
# -------------
# Epoch 182/300
# -------------
# -------------
# epoch 181 || Loss:0.0030
# timer:  0.0273 sec.
# -------------
# Epoch 183/300
# -------------
# -------------
# epoch 182 || Loss:0.0034
# timer:  0.0212 sec.
# -------------
# Epoch 184/300
# -------------
# -------------
# epoch 183 || Loss:0.0029
# timer:  0.0140 sec.
# -------------
# Epoch 185/300
# -------------
# -------------
# epoch 184 || Loss:0.0021
# timer:  0.0135 sec.
# -------------
# Epoch 186/300
# -------------
# -------------
# epoch 185 || Loss:0.0022
# timer:  0.0140 sec.
# -------------
# Epoch 187/300
# -------------
# -------------
# epoch 186 || Loss:0.0024
# timer:  0.0151 sec.
# -------------
# Epoch 188/300
# -------------
# -------------
# epoch 187 || Loss:0.0019
# timer:  0.0150 sec.
# -------------
# Epoch 189/300
# -------------
# -------------
# epoch 188 || Loss:0.0029
# timer:  0.0155 sec.
# -------------
# Epoch 190/300
# -------------
# -------------
# epoch 189 || Loss:0.0019
# timer:  0.0224 sec.
# -------------
# Epoch 191/300
# -------------
# -------------
# epoch 190 || Loss:0.0022
# timer:  0.0219 sec.
# -------------
# Epoch 192/300
# -------------
# -------------
# epoch 191 || Loss:0.0022
# timer:  0.0262 sec.
# -------------
# Epoch 193/300
# -------------
# -------------
# epoch 192 || Loss:0.0020
# timer:  0.0138 sec.
# -------------
# Epoch 194/300
# -------------
# -------------
# epoch 193 || Loss:0.0019
# timer:  0.0161 sec.
# -------------
# Epoch 195/300
# -------------
# -------------
# epoch 194 || Loss:0.0018
# timer:  0.0213 sec.
# -------------
# Epoch 196/300
# -------------
# -------------
# epoch 195 || Loss:0.0016
# timer:  0.0131 sec.
# -------------
# Epoch 197/300
# -------------
# -------------
# epoch 196 || Loss:0.0012
# timer:  0.0143 sec.
# -------------
# Epoch 198/300
# -------------
# -------------
# epoch 197 || Loss:0.0016
# timer:  0.0162 sec.
# -------------
# Epoch 199/300
# -------------
# -------------
# epoch 198 || Loss:0.0025
# timer:  0.0260 sec.
# -------------
# Epoch 200/300
# -------------
# -------------
# epoch 199 || Loss:0.0024
# timer:  0.0162 sec.
# -------------
# Epoch 201/300
# -------------
# -------------
# epoch 200 || Loss:0.0017
# timer:  0.0160 sec.
# -------------
# Epoch 202/300
# -------------
# -------------
# epoch 201 || Loss:0.0025
# timer:  0.0221 sec.
# -------------
# Epoch 203/300
# -------------
# -------------
# epoch 202 || Loss:0.0015
# timer:  0.0123 sec.
# -------------
# Epoch 204/300
# -------------
# -------------
# epoch 203 || Loss:0.0026
# timer:  0.0136 sec.
# -------------
# Epoch 205/300
# -------------
# -------------
# epoch 204 || Loss:0.0020
# timer:  0.0117 sec.
# -------------
# Epoch 206/300
# -------------
# -------------
# epoch 205 || Loss:0.0018
# timer:  0.0122 sec.
# -------------
# Epoch 207/300
# -------------
# -------------
# epoch 206 || Loss:0.0020
# timer:  0.0122 sec.
# -------------
# Epoch 208/300
# -------------
# -------------
# epoch 207 || Loss:0.0024
# timer:  0.0120 sec.
# -------------
# Epoch 209/300
# -------------
# -------------
# epoch 208 || Loss:0.0023
# timer:  0.0143 sec.
# -------------
# Epoch 210/300
# -------------
# -------------
# epoch 209 || Loss:0.0020
# timer:  0.0138 sec.
# -------------
# Epoch 211/300
# -------------
# -------------
# epoch 210 || Loss:0.0013
# timer:  0.0119 sec.
# -------------
# Epoch 212/300
# -------------
# -------------
# epoch 211 || Loss:0.0018
# timer:  0.0148 sec.
# -------------
# Epoch 213/300
# -------------
# -------------
# epoch 212 || Loss:0.0019
# timer:  0.0169 sec.
# -------------
# Epoch 214/300
# -------------
# -------------
# epoch 213 || Loss:0.0020
# timer:  0.0161 sec.
# -------------
# Epoch 215/300
# -------------
# -------------
# epoch 214 || Loss:0.0017
# timer:  0.0148 sec.
# -------------
# Epoch 216/300
# -------------
# -------------
# epoch 215 || Loss:0.0017
# timer:  0.0161 sec.
# -------------
# Epoch 217/300
# -------------
# -------------
# epoch 216 || Loss:0.0014
# timer:  0.0172 sec.
# -------------
# Epoch 218/300
# -------------
# -------------
# epoch 217 || Loss:0.0015
# timer:  0.0240 sec.
# -------------
# Epoch 219/300
# -------------
# -------------
# epoch 218 || Loss:0.0015
# timer:  0.0153 sec.
# -------------
# Epoch 220/300
# -------------
# -------------
# epoch 219 || Loss:0.0014
# timer:  0.0301 sec.
# -------------
# Epoch 221/300
# -------------
# -------------
# epoch 220 || Loss:0.0011
# timer:  0.0212 sec.
# -------------
# Epoch 222/300
# -------------
# -------------
# epoch 221 || Loss:0.0014
# timer:  0.0150 sec.
# -------------
# Epoch 223/300
# -------------
# -------------
# epoch 222 || Loss:0.0018
# timer:  0.0220 sec.
# -------------
# Epoch 224/300
# -------------
# -------------
# epoch 223 || Loss:0.0016
# timer:  0.0173 sec.
# -------------
# Epoch 225/300
# -------------
# -------------
# epoch 224 || Loss:0.0016
# timer:  0.0162 sec.
# -------------
# Epoch 226/300
# -------------
# -------------
# epoch 225 || Loss:0.0014
# timer:  0.0177 sec.
# -------------
# Epoch 227/300
# -------------
# -------------
# epoch 226 || Loss:0.0013
# timer:  0.0177 sec.
# -------------
# Epoch 228/300
# -------------
# -------------
# epoch 227 || Loss:0.0013
# timer:  0.0125 sec.
# -------------
# Epoch 229/300
# -------------
# -------------
# epoch 228 || Loss:0.0013
# timer:  0.0168 sec.
# -------------
# Epoch 230/300
# -------------
# -------------
# epoch 229 || Loss:0.0018
# timer:  0.0158 sec.
# -------------
# Epoch 231/300
# -------------
# -------------
# epoch 230 || Loss:0.0019
# timer:  0.0136 sec.
# -------------
# Epoch 232/300
# -------------
# -------------
# epoch 231 || Loss:0.0015
# timer:  0.0145 sec.
# -------------
# Epoch 233/300
# -------------
# -------------
# epoch 232 || Loss:0.0021
# timer:  0.0150 sec.
# -------------
# Epoch 234/300
# -------------
# -------------
# epoch 233 || Loss:0.0021
# timer:  0.0143 sec.
# -------------
# Epoch 235/300
# -------------
# -------------
# epoch 234 || Loss:0.0018
# timer:  0.0195 sec.
# -------------
# Epoch 236/300
# -------------
# -------------
# epoch 235 || Loss:0.0022
# timer:  0.0157 sec.
# -------------
# Epoch 237/300
# -------------
# -------------
# epoch 236 || Loss:0.0024
# timer:  0.0146 sec.
# -------------
# Epoch 238/300
# -------------
# -------------
# epoch 237 || Loss:0.0021
# timer:  0.0126 sec.
# -------------
# Epoch 239/300
# -------------
# -------------
# epoch 238 || Loss:0.0015
# timer:  0.0146 sec.
# -------------
# Epoch 240/300
# -------------
# -------------
# epoch 239 || Loss:0.0018
# timer:  0.0126 sec.
# -------------
# Epoch 241/300
# -------------
# -------------
# epoch 240 || Loss:0.0011
# timer:  0.0185 sec.
# -------------
# Epoch 242/300
# -------------
# -------------
# epoch 241 || Loss:0.0013
# timer:  0.0127 sec.
# -------------
# Epoch 243/300
# -------------
# -------------
# epoch 242 || Loss:0.0008
# timer:  0.0170 sec.
# -------------
# Epoch 244/300
# -------------
# -------------
# epoch 243 || Loss:0.0011
# timer:  0.0184 sec.
# -------------
# Epoch 245/300
# -------------
# -------------
# epoch 244 || Loss:0.0008
# timer:  0.0209 sec.
# -------------
# Epoch 246/300
# -------------
# -------------
# epoch 245 || Loss:0.0009
# timer:  0.0214 sec.
# -------------
# Epoch 247/300
# -------------
# -------------
# epoch 246 || Loss:0.0008
# timer:  0.0169 sec.
# -------------
# Epoch 248/300
# -------------
# -------------
# epoch 247 || Loss:0.0012
# timer:  0.0212 sec.
# -------------
# Epoch 249/300
# -------------
# -------------
# epoch 248 || Loss:0.0008
# timer:  0.0224 sec.
# -------------
# Epoch 250/300
# -------------
# -------------
# epoch 249 || Loss:0.0012
# timer:  0.0309 sec.
# -------------
# Epoch 251/300
# -------------
# -------------
# epoch 250 || Loss:0.0009
# timer:  0.0150 sec.
# -------------
# Epoch 252/300
# -------------
# -------------
# epoch 251 || Loss:0.0010
# timer:  0.0161 sec.
# -------------
# Epoch 253/300
# -------------
# -------------
# epoch 252 || Loss:0.0012
# timer:  0.0118 sec.
# -------------
# Epoch 254/300
# -------------
# -------------
# epoch 253 || Loss:0.0017
# timer:  0.0148 sec.
# -------------
# Epoch 255/300
# -------------
# -------------
# epoch 254 || Loss:0.0009
# timer:  0.0197 sec.
# -------------
# Epoch 256/300
# -------------
# -------------
# epoch 255 || Loss:0.0012
# timer:  0.0201 sec.
# -------------
# Epoch 257/300
# -------------
# -------------
# epoch 256 || Loss:0.0010
# timer:  0.0171 sec.
# -------------
# Epoch 258/300
# -------------
# -------------
# epoch 257 || Loss:0.0016
# timer:  0.0148 sec.
# -------------
# Epoch 259/300
# -------------
# -------------
# epoch 258 || Loss:0.0018
# timer:  0.0149 sec.
# -------------
# Epoch 260/300
# -------------
# -------------
# epoch 259 || Loss:0.0019
# timer:  0.0149 sec.
# -------------
# Epoch 261/300
# -------------
# -------------
# epoch 260 || Loss:0.0016
# timer:  0.0181 sec.
# -------------
# Epoch 262/300
# -------------
# -------------
# epoch 261 || Loss:0.0015
# timer:  0.0133 sec.
# -------------
# Epoch 263/300
# -------------
# -------------
# epoch 262 || Loss:0.0017
# timer:  0.0145 sec.
# -------------
# Epoch 264/300
# -------------
# -------------
# epoch 263 || Loss:0.0015
# timer:  0.0190 sec.
# -------------
# Epoch 265/300
# -------------
# -------------
# epoch 264 || Loss:0.0012
# timer:  0.0158 sec.
# -------------
# Epoch 266/300
# -------------
# -------------
# epoch 265 || Loss:0.0015
# timer:  0.0326 sec.
# -------------
# Epoch 267/300
# -------------
# -------------
# epoch 266 || Loss:0.0010
# timer:  0.0249 sec.
# -------------
# Epoch 268/300
# -------------
# -------------
# epoch 267 || Loss:0.0009
# timer:  0.0283 sec.
# -------------
# Epoch 269/300
# -------------
# -------------
# epoch 268 || Loss:0.0010
# timer:  0.0168 sec.
# -------------
# Epoch 270/300
# -------------
# -------------
# epoch 269 || Loss:0.0007
# timer:  0.0178 sec.
# -------------
# Epoch 271/300
# -------------
# -------------
# epoch 270 || Loss:0.0007
# timer:  0.0163 sec.
# -------------
# Epoch 272/300
# -------------
# -------------
# epoch 271 || Loss:0.0009
# timer:  0.0194 sec.
# -------------
# Epoch 273/300
# -------------
# -------------
# epoch 272 || Loss:0.0011
# timer:  0.0156 sec.
# -------------
# Epoch 274/300
# -------------
# -------------
# epoch 273 || Loss:0.0012
# timer:  0.0256 sec.
# -------------
# Epoch 275/300
# -------------
# -------------
# epoch 274 || Loss:0.0011
# timer:  0.0155 sec.
# -------------
# Epoch 276/300
# -------------
# -------------
# epoch 275 || Loss:0.0012
# timer:  0.0152 sec.
# -------------
# Epoch 277/300
# -------------
# -------------
# epoch 276 || Loss:0.0011
# timer:  0.0138 sec.
# -------------
# Epoch 278/300
# -------------
# -------------
# epoch 277 || Loss:0.0007
# timer:  0.0243 sec.
# -------------
# Epoch 279/300
# -------------
# -------------
# epoch 278 || Loss:0.0011
# timer:  0.0162 sec.
# -------------
# Epoch 280/300
# -------------
# -------------
# epoch 279 || Loss:0.0007
# timer:  0.0139 sec.
# -------------
# Epoch 281/300
# -------------
# -------------
# epoch 280 || Loss:0.0014
# timer:  0.0239 sec.
# -------------
# Epoch 282/300
# -------------
# -------------
# epoch 281 || Loss:0.0011
# timer:  0.0196 sec.
# -------------
# Epoch 283/300
# -------------
# -------------
# epoch 282 || Loss:0.0021
# timer:  0.0209 sec.
# -------------
# Epoch 284/300
# -------------
# -------------
# epoch 283 || Loss:0.0017
# timer:  0.0173 sec.
# -------------
# Epoch 285/300
# -------------
# -------------
# epoch 284 || Loss:0.0021
# timer:  0.0176 sec.
# -------------
# Epoch 286/300
# -------------
# -------------
# epoch 285 || Loss:0.0012
# timer:  0.0219 sec.
# -------------
# Epoch 287/300
# -------------
# -------------
# epoch 286 || Loss:0.0021
# timer:  0.0261 sec.
# -------------
# Epoch 288/300
# -------------
# -------------
# epoch 287 || Loss:0.0020
# timer:  0.0334 sec.
# -------------
# Epoch 289/300
# -------------
# -------------
# epoch 288 || Loss:0.0015
# timer:  0.0178 sec.
# -------------
# Epoch 290/300
# -------------
# -------------
# epoch 289 || Loss:0.0012
# timer:  0.0152 sec.
# -------------
# Epoch 291/300
# -------------
# -------------
# epoch 290 || Loss:0.0015
# timer:  0.0122 sec.
# -------------
# Epoch 292/300
# -------------
# -------------
# epoch 291 || Loss:0.0017
# timer:  0.0173 sec.
# -------------
# Epoch 293/300
# -------------
# -------------
# epoch 292 || Loss:0.0007
# timer:  0.0154 sec.
# -------------
# Epoch 294/300
# -------------
# -------------
# epoch 293 || Loss:0.0015
# timer:  0.0226 sec.
# -------------
# Epoch 295/300
# -------------
# -------------
# epoch 294 || Loss:0.0008
# timer:  0.0209 sec.
# -------------
# Epoch 296/300
# -------------
# -------------
# epoch 295 || Loss:0.0009
# timer:  0.0183 sec.
# -------------
# Epoch 297/300
# -------------
# -------------
# epoch 296 || Loss:0.0012
# timer:  0.0216 sec.
# -------------
# Epoch 298/300
# -------------
# -------------
# epoch 297 || Loss:0.0006
# timer:  0.0190 sec.
# -------------
# Epoch 299/300
# -------------
# -------------
# epoch 298 || Loss:0.0009
# timer:  0.0231 sec.
# -------------
# Epoch 300/300
# -------------
# -------------
# epoch 299 || Loss:0.0008
# timer:  0.0200 sec.

# %% [markdown]
# ### Error Model

# %%
# dataset = StepDataset(ymax=4., model_mean=model_mean)
# dataloader = torch.utils.data.DataLoader(dataset,batch_size=100,shuffle=True)
# x, y = next(iter(dataloader))
# y

# %%
class CustomLoss(nn.Module):
    
    def __init__(self, beta=0.1):
        super(CustomLoss, self).__init__()
        self.beta = beta
        
    def forward(self, x, y):
        dist = torch.sum(
            torch.pow((y - x).clamp(min=0.),2) + self.beta*torch.pow((y - x).clamp(max=0.),2)
            )
        loss = dist/(x.shape[0]*x.shape[1])
        return loss

# %%
def train_error(model, dataloader, num_epochs, lr=2e-3):   
    model = nn.DataParallel(model)
    model.to(device)
    model.train()
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = CustomLoss(beta=0.1)
    
    for epoch in range(num_epochs):      
        t_epoch_start = time.time()
        epoch_loss = 0.0
        
        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')
        
        for data in dataloader:       
            batch_size = len(data[0])
            x = data[0].to(device)
            y = data[1].to(device)
            out = model(x)
            
            loss = criterion(out, y)
            optimizer.zero_grad()
            loss.backward(retain_graph=True)
            optimizer.step()
            
            epoch_loss += loss.item()
            
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Loss:{:.4f} '.format(epoch, epoch_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        
    model.eval()        
    return model

# %%
dataset = StepDataset(5,-3,100,error_range=0.1,center=1,ymax=4.,model_mean=model_mean)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=64,shuffle=True)

model_error = BasicRegressor()

model_error = train_error(model_error, dataloader, 600, lr=5e-3)
# Out:
# -------------
# Epoch 1/600
# -------------
# -------------
# epoch 0 || Loss:0.0197
# timer:  0.0229 sec.
# -------------
# Epoch 2/600
# -------------
# -------------
# epoch 1 || Loss:0.0149
# timer:  0.0205 sec.
# -------------
# Epoch 3/600
# -------------
# -------------
# epoch 2 || Loss:0.0023
# timer:  0.0217 sec.
# -------------
# Epoch 4/600
# -------------
# -------------
# epoch 3 || Loss:0.0041
# timer:  0.0194 sec.
# -------------
# Epoch 5/600
# -------------
# -------------
# epoch 4 || Loss:0.0005
# timer:  0.0229 sec.
# -------------
# Epoch 6/600
# -------------
# -------------
# epoch 5 || Loss:0.0015
# timer:  0.0250 sec.
# -------------
# Epoch 7/600
# -------------
# -------------
# epoch 6 || Loss:0.0020
# timer:  0.0226 sec.
# -------------
# Epoch 8/600
# -------------
# -------------
# epoch 7 || Loss:0.0013
# timer:  0.0223 sec.
# -------------
# Epoch 9/600
# -------------
# -------------
# epoch 8 || Loss:0.0005
# timer:  0.0248 sec.
# -------------
# Epoch 10/600
# -------------
# -------------
# epoch 9 || Loss:0.0005
# timer:  0.0231 sec.
# -------------
# Epoch 11/600
# -------------
# -------------
# epoch 10 || Loss:0.0005
# timer:  0.0258 sec.
# -------------
# Epoch 12/600
# -------------
# -------------
# epoch 11 || Loss:0.0002
# timer:  0.0251 sec.
# -------------
# Epoch 13/600
# -------------
# -------------
# epoch 12 || Loss:0.0002
# timer:  0.0398 sec.
# -------------
# Epoch 14/600
# -------------
# -------------
# epoch 13 || Loss:0.0003
# timer:  0.0209 sec.
# -------------
# Epoch 15/600
# -------------
# -------------
# epoch 14 || Loss:0.0003
# timer:  0.0236 sec.
# -------------
# Epoch 16/600
# -------------
# -------------
# epoch 15 || Loss:0.0002
# timer:  0.0294 sec.
# -------------
# Epoch 17/600
# -------------
# -------------
# epoch 16 || Loss:0.0001
# timer:  0.0264 sec.
# -------------
# Epoch 18/600
# -------------
# -------------
# epoch 17 || Loss:0.0001
# timer:  0.0394 sec.
# -------------
# Epoch 19/600
# -------------
# -------------
# epoch 18 || Loss:0.0001
# timer:  0.0197 sec.
# -------------
# Epoch 20/600
# -------------
# -------------
# epoch 19 || Loss:0.0001
# timer:  0.0206 sec.
# -------------
# Epoch 21/600
# -------------
# -------------
# epoch 20 || Loss:0.0001
# timer:  0.0277 sec.
# -------------
# Epoch 22/600
# -------------
# -------------
# epoch 21 || Loss:0.0000
# timer:  0.0187 sec.
# -------------
# Epoch 23/600
# -------------
# -------------
# epoch 22 || Loss:0.0001
# timer:  0.0162 sec.
# -------------
# Epoch 24/600
# -------------
# -------------
# epoch 23 || Loss:0.0001
# timer:  0.0184 sec.
# -------------
# Epoch 25/600
# -------------
# -------------
# epoch 24 || Loss:0.0001
# timer:  0.0180 sec.
# -------------
# Epoch 26/600
# -------------
# -------------
# epoch 25 || Loss:0.0001
# timer:  0.0235 sec.
# -------------
# Epoch 27/600
# -------------
# -------------
# epoch 26 || Loss:0.0001
# timer:  0.0268 sec.
# -------------
# Epoch 28/600
# -------------
# -------------
# epoch 27 || Loss:0.0001
# timer:  0.0267 sec.
# -------------
# Epoch 29/600
# -------------
# -------------
# epoch 28 || Loss:0.0000
# timer:  0.0221 sec.
# -------------
# Epoch 30/600
# -------------
# -------------
# epoch 29 || Loss:0.0001
# timer:  0.0270 sec.
# -------------
# Epoch 31/600
# -------------
# -------------
# epoch 30 || Loss:0.0001
# timer:  0.0259 sec.
# -------------
# Epoch 32/600
# -------------
# -------------
# epoch 31 || Loss:0.0000
# timer:  0.0220 sec.
# -------------
# Epoch 33/600
# -------------
# -------------
# epoch 32 || Loss:0.0001
# timer:  0.0277 sec.
# -------------
# Epoch 34/600
# -------------
# -------------
# epoch 33 || Loss:0.0000
# timer:  0.0165 sec.
# -------------
# Epoch 35/600
# -------------
# -------------
# epoch 34 || Loss:0.0000
# timer:  0.0207 sec.
# -------------
# Epoch 36/600
# -------------
# -------------
# epoch 35 || Loss:0.0000
# timer:  0.0233 sec.
# -------------
# Epoch 37/600
# -------------
# -------------
# epoch 36 || Loss:0.0000
# timer:  0.0252 sec.
# -------------
# Epoch 38/600
# -------------
# -------------
# epoch 37 || Loss:0.0000
# timer:  0.0260 sec.
# -------------
# Epoch 39/600
# -------------
# -------------
# epoch 38 || Loss:0.0000
# timer:  0.0258 sec.
# -------------
# Epoch 40/600
# -------------
# -------------
# epoch 39 || Loss:0.0000
# timer:  0.0288 sec.
# -------------
# Epoch 41/600
# -------------
# -------------
# epoch 40 || Loss:0.0000
# timer:  0.0254 sec.
# -------------
# Epoch 42/600
# -------------
# -------------
# epoch 41 || Loss:0.0000
# timer:  0.0245 sec.
# -------------
# Epoch 43/600
# -------------
# -------------
# epoch 42 || Loss:0.0000
# timer:  0.0258 sec.
# -------------
# Epoch 44/600
# -------------
# -------------
# epoch 43 || Loss:0.0000
# timer:  0.0453 sec.
# -------------
# Epoch 45/600
# -------------
# -------------
# epoch 44 || Loss:0.0000
# timer:  0.0184 sec.
# -------------
# Epoch 46/600
# -------------
# -------------
# epoch 45 || Loss:0.0000
# timer:  0.0314 sec.
# -------------
# Epoch 47/600
# -------------
# -------------
# epoch 46 || Loss:0.0000
# timer:  0.0238 sec.
# -------------
# Epoch 48/600
# -------------
# -------------
# epoch 47 || Loss:0.0000
# timer:  0.0173 sec.
# -------------
# Epoch 49/600
# -------------
# -------------
# epoch 48 || Loss:0.0000
# timer:  0.0274 sec.
# -------------
# Epoch 50/600
# -------------
# -------------
# epoch 49 || Loss:0.0000
# timer:  0.0436 sec.
# -------------
# Epoch 51/600
# -------------
# -------------
# epoch 50 || Loss:0.0000
# timer:  0.0240 sec.
# -------------
# Epoch 52/600
# -------------
# -------------
# epoch 51 || Loss:0.0000
# timer:  0.0194 sec.
# -------------
# Epoch 53/600
# -------------
# -------------
# epoch 52 || Loss:0.0000
# timer:  0.0211 sec.
# -------------
# Epoch 54/600
# -------------
# -------------
# epoch 53 || Loss:0.0000
# timer:  0.0243 sec.
# -------------
# Epoch 55/600
# -------------
# -------------
# epoch 54 || Loss:0.0000
# timer:  0.0203 sec.
# -------------
# Epoch 56/600
# -------------
# -------------
# epoch 55 || Loss:0.0000
# timer:  0.0207 sec.
# -------------
# Epoch 57/600
# -------------
# -------------
# epoch 56 || Loss:0.0000
# timer:  0.0178 sec.
# -------------
# Epoch 58/600
# -------------
# -------------
# epoch 57 || Loss:0.0000
# timer:  0.0142 sec.
# -------------
# Epoch 59/600
# -------------
# -------------
# epoch 58 || Loss:0.0000
# timer:  0.0157 sec.
# -------------
# Epoch 60/600
# -------------
# -------------
# epoch 59 || Loss:0.0000
# timer:  0.0214 sec.
# -------------
# Epoch 61/600
# -------------
# -------------
# epoch 60 || Loss:0.0000
# timer:  0.0264 sec.
# -------------
# Epoch 62/600
# -------------
# -------------
# epoch 61 || Loss:0.0000
# timer:  0.0230 sec.
# -------------
# Epoch 63/600
# -------------
# -------------
# epoch 62 || Loss:0.0000
# timer:  0.0241 sec.
# -------------
# Epoch 64/600
# -------------
# -------------
# epoch 63 || Loss:0.0000
# timer:  0.0179 sec.
# -------------
# Epoch 65/600
# -------------
# -------------
# epoch 64 || Loss:0.0000
# timer:  0.0186 sec.
# -------------
# Epoch 66/600
# -------------
# -------------
# epoch 65 || Loss:0.0000
# timer:  0.0213 sec.
# -------------
# Epoch 67/600
# -------------
# -------------
# epoch 66 || Loss:0.0000
# timer:  0.0245 sec.
# -------------
# Epoch 68/600
# -------------
# -------------
# epoch 67 || Loss:0.0000
# timer:  0.0292 sec.
# -------------
# Epoch 69/600
# -------------
# -------------
# epoch 68 || Loss:0.0000
# timer:  0.0414 sec.
# -------------
# Epoch 70/600
# -------------
# -------------
# epoch 69 || Loss:0.0000
# timer:  0.0319 sec.
# -------------
# Epoch 71/600
# -------------
# -------------
# epoch 70 || Loss:0.0000
# timer:  0.0252 sec.
# -------------
# Epoch 72/600
# -------------
# -------------
# epoch 71 || Loss:0.0000
# timer:  0.0205 sec.
# -------------
# Epoch 73/600
# -------------
# -------------
# epoch 72 || Loss:0.0000
# timer:  0.0201 sec.
# -------------
# Epoch 74/600
# -------------
# -------------
# epoch 73 || Loss:0.0000
# timer:  0.0232 sec.
# -------------
# Epoch 75/600
# -------------
# -------------
# epoch 74 || Loss:0.0000
# timer:  0.0434 sec.
# -------------
# Epoch 76/600
# -------------
# -------------
# epoch 75 || Loss:0.0000
# timer:  0.0298 sec.
# -------------
# Epoch 77/600
# -------------
# -------------
# epoch 76 || Loss:0.0000
# timer:  0.0324 sec.
# -------------
# Epoch 78/600
# -------------
# -------------
# epoch 77 || Loss:0.0000
# timer:  0.0267 sec.
# -------------
# Epoch 79/600
# -------------
# -------------
# epoch 78 || Loss:0.0000
# timer:  0.0189 sec.
# -------------
# Epoch 80/600
# -------------
# -------------
# epoch 79 || Loss:0.0000
# timer:  0.0256 sec.
# -------------
# Epoch 81/600
# -------------
# -------------
# epoch 80 || Loss:0.0000
# timer:  0.0341 sec.
# -------------
# Epoch 82/600
# -------------
# -------------
# epoch 81 || Loss:0.0000
# timer:  0.0215 sec.
# -------------
# Epoch 83/600
# -------------
# -------------
# epoch 82 || Loss:0.0000
# timer:  0.0237 sec.
# -------------
# Epoch 84/600
# -------------
# -------------
# epoch 83 || Loss:0.0000
# timer:  0.0239 sec.
# -------------
# Epoch 85/600
# -------------
# -------------
# epoch 84 || Loss:0.0000
# timer:  0.0282 sec.
# -------------
# Epoch 86/600
# -------------
# -------------
# epoch 85 || Loss:0.0000
# timer:  0.0201 sec.
# -------------
# Epoch 87/600
# -------------
# -------------
# epoch 86 || Loss:0.0000
# timer:  0.0280 sec.
# -------------
# Epoch 88/600
# -------------
# -------------
# epoch 87 || Loss:0.0000
# timer:  0.0221 sec.
# -------------
# Epoch 89/600
# -------------
# -------------
# epoch 88 || Loss:0.0000
# timer:  0.0190 sec.
# -------------
# Epoch 90/600
# -------------
# -------------
# epoch 89 || Loss:0.0000
# timer:  0.0223 sec.
# -------------
# Epoch 91/600
# -------------
# -------------
# epoch 90 || Loss:0.0000
# timer:  0.0186 sec.
# -------------
# Epoch 92/600
# -------------
# -------------
# epoch 91 || Loss:0.0000
# timer:  0.0256 sec.
# -------------
# Epoch 93/600
# -------------
# -------------
# epoch 92 || Loss:0.0000
# timer:  0.0230 sec.
# -------------
# Epoch 94/600
# -------------
# -------------
# epoch 93 || Loss:0.0000
# timer:  0.0363 sec.
# -------------
# Epoch 95/600
# -------------
# -------------
# epoch 94 || Loss:0.0000
# timer:  0.0307 sec.
# -------------
# Epoch 96/600
# -------------
# -------------
# epoch 95 || Loss:0.0000
# timer:  0.0222 sec.
# -------------
# Epoch 97/600
# -------------
# -------------
# epoch 96 || Loss:0.0000
# timer:  0.0194 sec.
# -------------
# Epoch 98/600
# -------------
# -------------
# epoch 97 || Loss:0.0000
# timer:  0.0270 sec.
# -------------
# Epoch 99/600
# -------------
# -------------
# epoch 98 || Loss:0.0000
# timer:  0.0254 sec.
# -------------
# Epoch 100/600
# -------------
# -------------
# epoch 99 || Loss:0.0000
# timer:  0.0227 sec.
# -------------
# Epoch 101/600
# -------------
# -------------
# epoch 100 || Loss:0.0000
# timer:  0.0205 sec.
# -------------
# Epoch 102/600
# -------------
# -------------
# epoch 101 || Loss:0.0000
# timer:  0.0302 sec.
# -------------
# Epoch 103/600
# -------------
# -------------
# epoch 102 || Loss:0.0000
# timer:  0.0206 sec.
# -------------
# Epoch 104/600
# -------------
# -------------
# epoch 103 || Loss:0.0000
# timer:  0.0229 sec.
# -------------
# Epoch 105/600
# -------------
# -------------
# epoch 104 || Loss:0.0000
# timer:  0.0278 sec.
# -------------
# Epoch 106/600
# -------------
# -------------
# epoch 105 || Loss:0.0000
# timer:  0.0215 sec.
# -------------
# Epoch 107/600
# -------------
# -------------
# epoch 106 || Loss:0.0000
# timer:  0.0254 sec.
# -------------
# Epoch 108/600
# -------------
# -------------
# epoch 107 || Loss:0.0000
# timer:  0.0298 sec.
# -------------
# Epoch 109/600
# -------------
# -------------
# epoch 108 || Loss:0.0000
# timer:  0.0161 sec.
# -------------
# Epoch 110/600
# -------------
# -------------
# epoch 109 || Loss:0.0000
# timer:  0.0157 sec.
# -------------
# Epoch 111/600
# -------------
# -------------
# epoch 110 || Loss:0.0000
# timer:  0.0193 sec.
# -------------
# Epoch 112/600
# -------------
# -------------
# epoch 111 || Loss:0.0000
# timer:  0.0173 sec.
# -------------
# Epoch 113/600
# -------------
# -------------
# epoch 112 || Loss:0.0000
# timer:  0.0254 sec.
# -------------
# Epoch 114/600
# -------------
# -------------
# epoch 113 || Loss:0.0000
# timer:  0.0196 sec.
# -------------
# Epoch 115/600
# -------------
# -------------
# epoch 114 || Loss:0.0000
# timer:  0.0232 sec.
# -------------
# Epoch 116/600
# -------------
# -------------
# epoch 115 || Loss:0.0000
# timer:  0.0274 sec.
# -------------
# Epoch 117/600
# -------------
# -------------
# epoch 116 || Loss:0.0000
# timer:  0.0198 sec.
# -------------
# Epoch 118/600
# -------------
# -------------
# epoch 117 || Loss:0.0000
# timer:  0.0210 sec.
# -------------
# Epoch 119/600
# -------------
# -------------
# epoch 118 || Loss:0.0000
# timer:  0.0234 sec.
# -------------
# Epoch 120/600
# -------------
# -------------
# epoch 119 || Loss:0.0000
# timer:  0.0168 sec.
# -------------
# Epoch 121/600
# -------------
# -------------
# epoch 120 || Loss:0.0000
# timer:  0.0211 sec.
# -------------
# Epoch 122/600
# -------------
# -------------
# epoch 121 || Loss:0.0000
# timer:  0.0256 sec.
# -------------
# Epoch 123/600
# -------------
# -------------
# epoch 122 || Loss:0.0000
# timer:  0.0223 sec.
# -------------
# Epoch 124/600
# -------------
# -------------
# epoch 123 || Loss:0.0000
# timer:  0.0304 sec.
# -------------
# Epoch 125/600
# -------------
# -------------
# epoch 124 || Loss:0.0000
# timer:  0.0269 sec.
# -------------
# Epoch 126/600
# -------------
# -------------
# epoch 125 || Loss:0.0000
# timer:  0.0193 sec.
# -------------
# Epoch 127/600
# -------------
# -------------
# epoch 126 || Loss:0.0000
# timer:  0.0226 sec.
# -------------
# Epoch 128/600
# -------------
# -------------
# epoch 127 || Loss:0.0000
# timer:  0.0224 sec.
# -------------
# Epoch 129/600
# -------------
# -------------
# epoch 128 || Loss:0.0000
# timer:  0.0291 sec.
# -------------
# Epoch 130/600
# -------------
# -------------
# epoch 129 || Loss:0.0000
# timer:  0.0204 sec.
# -------------
# Epoch 131/600
# -------------
# -------------
# epoch 130 || Loss:0.0000
# timer:  0.0217 sec.
# -------------
# Epoch 132/600
# -------------
# -------------
# epoch 131 || Loss:0.0000
# timer:  0.0191 sec.
# -------------
# Epoch 133/600
# -------------
# -------------
# epoch 132 || Loss:0.0000
# timer:  0.0197 sec.
# -------------
# Epoch 134/600
# -------------
# -------------
# epoch 133 || Loss:0.0000
# timer:  0.0292 sec.
# -------------
# Epoch 135/600
# -------------
# -------------
# epoch 134 || Loss:0.0000
# timer:  0.0219 sec.
# -------------
# Epoch 136/600
# -------------
# -------------
# epoch 135 || Loss:0.0000
# timer:  0.0266 sec.
# -------------
# Epoch 137/600
# -------------
# -------------
# epoch 136 || Loss:0.0000
# timer:  0.0462 sec.
# -------------
# Epoch 138/600
# -------------
# -------------
# epoch 137 || Loss:0.0000
# timer:  0.0170 sec.
# -------------
# Epoch 139/600
# -------------
# -------------
# epoch 138 || Loss:0.0000
# timer:  0.0208 sec.
# -------------
# Epoch 140/600
# -------------
# -------------
# epoch 139 || Loss:0.0000
# timer:  0.0254 sec.
# -------------
# Epoch 141/600
# -------------
# -------------
# epoch 140 || Loss:0.0000
# timer:  0.0236 sec.
# -------------
# Epoch 142/600
# -------------
# -------------
# epoch 141 || Loss:0.0000
# timer:  0.0191 sec.
# -------------
# Epoch 143/600
# -------------
# -------------
# epoch 142 || Loss:0.0000
# timer:  0.0156 sec.
# -------------
# Epoch 144/600
# -------------
# -------------
# epoch 143 || Loss:0.0000
# timer:  0.0170 sec.
# -------------
# Epoch 145/600
# -------------
# -------------
# epoch 144 || Loss:0.0000
# timer:  0.0160 sec.
# -------------
# Epoch 146/600
# -------------
# -------------
# epoch 145 || Loss:0.0000
# timer:  0.0204 sec.
# -------------
# Epoch 147/600
# -------------
# -------------
# epoch 146 || Loss:0.0000
# timer:  0.0156 sec.
# -------------
# Epoch 148/600
# -------------
# -------------
# epoch 147 || Loss:0.0000
# timer:  0.0153 sec.
# -------------
# Epoch 149/600
# -------------
# -------------
# epoch 148 || Loss:0.0000
# timer:  0.0163 sec.
# -------------
# Epoch 150/600
# -------------
# -------------
# epoch 149 || Loss:0.0000
# timer:  0.0169 sec.
# -------------
# Epoch 151/600
# -------------
# -------------
# epoch 150 || Loss:0.0000
# timer:  0.0209 sec.
# -------------
# Epoch 152/600
# -------------
# -------------
# epoch 151 || Loss:0.0000
# timer:  0.0279 sec.
# -------------
# Epoch 153/600
# -------------
# -------------
# epoch 152 || Loss:0.0000
# timer:  0.0243 sec.
# -------------
# Epoch 154/600
# -------------
# -------------
# epoch 153 || Loss:0.0000
# timer:  0.0178 sec.
# -------------
# Epoch 155/600
# -------------
# -------------
# epoch 154 || Loss:0.0000
# timer:  0.0204 sec.
# -------------
# Epoch 156/600
# -------------
# -------------
# epoch 155 || Loss:0.0000
# timer:  0.0209 sec.
# -------------
# Epoch 157/600
# -------------
# -------------
# epoch 156 || Loss:0.0000
# timer:  0.0158 sec.
# -------------
# Epoch 158/600
# -------------
# -------------
# epoch 157 || Loss:0.0000
# timer:  0.0208 sec.
# -------------
# Epoch 159/600
# -------------
# -------------
# epoch 158 || Loss:0.0000
# timer:  0.0222 sec.
# -------------
# Epoch 160/600
# -------------
# -------------
# epoch 159 || Loss:0.0000
# timer:  0.0343 sec.
# -------------
# Epoch 161/600
# -------------
# -------------
# epoch 160 || Loss:0.0000
# timer:  0.0259 sec.
# -------------
# Epoch 162/600
# -------------
# -------------
# epoch 161 || Loss:0.0000
# timer:  0.0200 sec.
# -------------
# Epoch 163/600
# -------------
# -------------
# epoch 162 || Loss:0.0000
# timer:  0.0183 sec.
# -------------
# Epoch 164/600
# -------------
# -------------
# epoch 163 || Loss:0.0000
# timer:  0.0210 sec.
# -------------
# Epoch 165/600
# -------------
# -------------
# epoch 164 || Loss:0.0000
# timer:  0.0425 sec.
# -------------
# Epoch 166/600
# -------------
# -------------
# epoch 165 || Loss:0.0000
# timer:  0.0184 sec.
# -------------
# Epoch 167/600
# -------------
# -------------
# epoch 166 || Loss:0.0000
# timer:  0.0194 sec.
# -------------
# Epoch 168/600
# -------------
# -------------
# epoch 167 || Loss:0.0000
# timer:  0.0210 sec.
# -------------
# Epoch 169/600
# -------------
# -------------
# epoch 168 || Loss:0.0000
# timer:  0.0236 sec.
# -------------
# Epoch 170/600
# -------------
# -------------
# epoch 169 || Loss:0.0000
# timer:  0.0263 sec.
# -------------
# Epoch 171/600
# -------------
# -------------
# epoch 170 || Loss:0.0000
# timer:  0.0230 sec.
# -------------
# Epoch 172/600
# -------------
# -------------
# epoch 171 || Loss:0.0000
# timer:  0.0209 sec.
# -------------
# Epoch 173/600
# -------------
# -------------
# epoch 172 || Loss:0.0000
# timer:  0.0213 sec.
# -------------
# Epoch 174/600
# -------------
# -------------
# epoch 173 || Loss:0.0000
# timer:  0.0387 sec.
# -------------
# Epoch 175/600
# -------------
# -------------
# epoch 174 || Loss:0.0000
# timer:  0.0183 sec.
# -------------
# Epoch 176/600
# -------------
# -------------
# epoch 175 || Loss:0.0000
# timer:  0.0286 sec.
# -------------
# Epoch 177/600
# -------------
# -------------
# epoch 176 || Loss:0.0000
# timer:  0.0203 sec.
# -------------
# Epoch 178/600
# -------------
# -------------
# epoch 177 || Loss:0.0000
# timer:  0.0243 sec.
# -------------
# Epoch 179/600
# -------------
# -------------
# epoch 178 || Loss:0.0000
# timer:  0.0241 sec.
# -------------
# Epoch 180/600
# -------------
# -------------
# epoch 179 || Loss:0.0000
# timer:  0.0213 sec.
# -------------
# Epoch 181/600
# -------------
# -------------
# epoch 180 || Loss:0.0000
# timer:  0.0226 sec.
# -------------
# Epoch 182/600
# -------------
# -------------
# epoch 181 || Loss:0.0000
# timer:  0.0166 sec.
# -------------
# Epoch 183/600
# -------------
# -------------
# epoch 182 || Loss:0.0000
# timer:  0.0220 sec.
# -------------
# Epoch 184/600
# -------------
# -------------
# epoch 183 || Loss:0.0000
# timer:  0.0242 sec.
# -------------
# Epoch 185/600
# -------------
# -------------
# epoch 184 || Loss:0.0000
# timer:  0.0234 sec.
# -------------
# Epoch 186/600
# -------------
# -------------
# epoch 185 || Loss:0.0000
# timer:  0.0187 sec.
# -------------
# Epoch 187/600
# -------------
# -------------
# epoch 186 || Loss:0.0000
# timer:  0.0312 sec.
# -------------
# Epoch 188/600
# -------------
# -------------
# epoch 187 || Loss:0.0000
# timer:  0.0167 sec.
# -------------
# Epoch 189/600
# -------------
# -------------
# epoch 188 || Loss:0.0000
# timer:  0.0272 sec.
# -------------
# Epoch 190/600
# -------------
# -------------
# epoch 189 || Loss:0.0000
# timer:  0.0311 sec.
# -------------
# Epoch 191/600
# -------------
# -------------
# epoch 190 || Loss:0.0000
# timer:  0.0252 sec.
# -------------
# Epoch 192/600
# -------------
# -------------
# epoch 191 || Loss:0.0000
# timer:  0.0176 sec.
# -------------
# Epoch 193/600
# -------------
# -------------
# epoch 192 || Loss:0.0000
# timer:  0.0234 sec.
# -------------
# Epoch 194/600
# -------------
# -------------
# epoch 193 || Loss:0.0000
# timer:  0.0232 sec.
# -------------
# Epoch 195/600
# -------------
# -------------
# epoch 194 || Loss:0.0000
# timer:  0.0225 sec.
# -------------
# Epoch 196/600
# -------------
# -------------
# epoch 195 || Loss:0.0000
# timer:  0.0251 sec.
# -------------
# Epoch 197/600
# -------------
# -------------
# epoch 196 || Loss:0.0000
# timer:  0.0248 sec.
# -------------
# Epoch 198/600
# -------------
# -------------
# epoch 197 || Loss:0.0000
# timer:  0.0265 sec.
# -------------
# Epoch 199/600
# -------------
# -------------
# epoch 198 || Loss:0.0000
# timer:  0.0258 sec.
# -------------
# Epoch 200/600
# -------------
# -------------
# epoch 199 || Loss:0.0000
# timer:  0.0227 sec.
# -------------
# Epoch 201/600
# -------------
# -------------
# epoch 200 || Loss:0.0000
# timer:  0.0215 sec.
# -------------
# Epoch 202/600
# -------------
# -------------
# epoch 201 || Loss:0.0000
# timer:  0.0223 sec.
# -------------
# Epoch 203/600
# -------------
# -------------
# epoch 202 || Loss:0.0000
# timer:  0.0243 sec.
# -------------
# Epoch 204/600
# -------------
# -------------
# epoch 203 || Loss:0.0000
# timer:  0.0245 sec.
# -------------
# Epoch 205/600
# -------------
# -------------
# epoch 204 || Loss:0.0000
# timer:  0.0282 sec.
# -------------
# Epoch 206/600
# -------------
# -------------
# epoch 205 || Loss:0.0000
# timer:  0.0224 sec.
# -------------
# Epoch 207/600
# -------------
# -------------
# epoch 206 || Loss:0.0000
# timer:  0.0244 sec.
# -------------
# Epoch 208/600
# -------------
# -------------
# epoch 207 || Loss:0.0000
# timer:  0.0316 sec.
# -------------
# Epoch 209/600
# -------------
# -------------
# epoch 208 || Loss:0.0000
# timer:  0.0244 sec.
# -------------
# Epoch 210/600
# -------------
# -------------
# epoch 209 || Loss:0.0000
# timer:  0.0283 sec.
# -------------
# Epoch 211/600
# -------------
# -------------
# epoch 210 || Loss:0.0000
# timer:  0.0404 sec.
# -------------
# Epoch 212/600
# -------------
# -------------
# epoch 211 || Loss:0.0000
# timer:  0.0279 sec.
# -------------
# Epoch 213/600
# -------------
# -------------
# epoch 212 || Loss:0.0000
# timer:  0.0257 sec.
# -------------
# Epoch 214/600
# -------------
# -------------
# epoch 213 || Loss:0.0000
# timer:  0.0209 sec.
# -------------
# Epoch 215/600
# -------------
# -------------
# epoch 214 || Loss:0.0000
# timer:  0.0210 sec.
# -------------
# Epoch 216/600
# -------------
# -------------
# epoch 215 || Loss:0.0000
# timer:  0.0251 sec.
# -------------
# Epoch 217/600
# -------------
# -------------
# epoch 216 || Loss:0.0000
# timer:  0.0262 sec.
# -------------
# Epoch 218/600
# -------------
# -------------
# epoch 217 || Loss:0.0000
# timer:  0.0251 sec.
# -------------
# Epoch 219/600
# -------------
# -------------
# epoch 218 || Loss:0.0000
# timer:  0.0198 sec.
# -------------
# Epoch 220/600
# -------------
# -------------
# epoch 219 || Loss:0.0000
# timer:  0.0185 sec.
# -------------
# Epoch 221/600
# -------------
# -------------
# epoch 220 || Loss:0.0000
# timer:  0.0168 sec.
# -------------
# Epoch 222/600
# -------------
# -------------
# epoch 221 || Loss:0.0000
# timer:  0.0187 sec.
# -------------
# Epoch 223/600
# -------------
# -------------
# epoch 222 || Loss:0.0000
# timer:  0.0193 sec.
# -------------
# Epoch 224/600
# -------------
# -------------
# epoch 223 || Loss:0.0000
# timer:  0.0235 sec.
# -------------
# Epoch 225/600
# -------------
# -------------
# epoch 224 || Loss:0.0000
# timer:  0.0216 sec.
# -------------
# Epoch 226/600
# -------------
# -------------
# epoch 225 || Loss:0.0000
# timer:  0.0250 sec.
# -------------
# Epoch 227/600
# -------------
# -------------
# epoch 226 || Loss:0.0000
# timer:  0.0236 sec.
# -------------
# Epoch 228/600
# -------------
# -------------
# epoch 227 || Loss:0.0000
# timer:  0.0310 sec.
# -------------
# Epoch 229/600
# -------------
# -------------
# epoch 228 || Loss:0.0000
# timer:  0.0223 sec.
# -------------
# Epoch 230/600
# -------------
# -------------
# epoch 229 || Loss:0.0000
# timer:  0.0165 sec.
# -------------
# Epoch 231/600
# -------------
# -------------
# epoch 230 || Loss:0.0000
# timer:  0.0255 sec.
# -------------
# Epoch 232/600
# -------------
# -------------
# epoch 231 || Loss:0.0000
# timer:  0.0252 sec.
# -------------
# Epoch 233/600
# -------------
# -------------
# epoch 232 || Loss:0.0000
# timer:  0.0240 sec.
# -------------
# Epoch 234/600
# -------------
# -------------
# epoch 233 || Loss:0.0000
# timer:  0.0241 sec.
# -------------
# Epoch 235/600
# -------------
# -------------
# epoch 234 || Loss:0.0000
# timer:  0.0261 sec.
# -------------
# Epoch 236/600
# -------------
# -------------
# epoch 235 || Loss:0.0000
# timer:  0.0235 sec.
# -------------
# Epoch 237/600
# -------------
# -------------
# epoch 236 || Loss:0.0000
# timer:  0.0252 sec.
# -------------
# Epoch 238/600
# -------------
# -------------
# epoch 237 || Loss:0.0000
# timer:  0.0297 sec.
# -------------
# Epoch 239/600
# -------------
# -------------
# epoch 238 || Loss:0.0000
# timer:  0.0250 sec.
# -------------
# Epoch 240/600
# -------------
# -------------
# epoch 239 || Loss:0.0000
# timer:  0.0392 sec.
# -------------
# Epoch 241/600
# -------------
# -------------
# epoch 240 || Loss:0.0000
# timer:  0.0413 sec.
# -------------
# Epoch 242/600
# -------------
# -------------
# epoch 241 || Loss:0.0000
# timer:  0.0264 sec.
# -------------
# Epoch 243/600
# -------------
# -------------
# epoch 242 || Loss:0.0000
# timer:  0.0300 sec.
# -------------
# Epoch 244/600
# -------------
# -------------
# epoch 243 || Loss:0.0000
# timer:  0.0196 sec.
# -------------
# Epoch 245/600
# -------------
# -------------
# epoch 244 || Loss:0.0000
# timer:  0.0228 sec.
# -------------
# Epoch 246/600
# -------------
# -------------
# epoch 245 || Loss:0.0000
# timer:  0.0268 sec.
# -------------
# Epoch 247/600
# -------------
# -------------
# epoch 246 || Loss:0.0000
# timer:  0.0186 sec.
# -------------
# Epoch 248/600
# -------------
# -------------
# epoch 247 || Loss:0.0000
# timer:  0.0170 sec.
# -------------
# Epoch 249/600
# -------------
# -------------
# epoch 248 || Loss:0.0000
# timer:  0.0186 sec.
# -------------
# Epoch 250/600
# -------------
# -------------
# epoch 249 || Loss:0.0000
# timer:  0.0188 sec.
# -------------
# Epoch 251/600
# -------------
# -------------
# epoch 250 || Loss:0.0000
# timer:  0.0177 sec.
# -------------
# Epoch 252/600
# -------------
# -------------
# epoch 251 || Loss:0.0000
# timer:  0.0166 sec.
# -------------
# Epoch 253/600
# -------------
# -------------
# epoch 252 || Loss:0.0000
# timer:  0.0166 sec.
# -------------
# Epoch 254/600
# -------------
# -------------
# epoch 253 || Loss:0.0000
# timer:  0.0159 sec.
# -------------
# Epoch 255/600
# -------------
# -------------
# epoch 254 || Loss:0.0000
# timer:  0.0193 sec.
# -------------
# Epoch 256/600
# -------------
# -------------
# epoch 255 || Loss:0.0000
# timer:  0.0214 sec.
# -------------
# Epoch 257/600
# -------------
# -------------
# epoch 256 || Loss:0.0000
# timer:  0.0229 sec.
# -------------
# Epoch 258/600
# -------------
# -------------
# epoch 257 || Loss:0.0000
# timer:  0.0232 sec.
# -------------
# Epoch 259/600
# -------------
# -------------
# epoch 258 || Loss:0.0000
# timer:  0.0255 sec.
# -------------
# Epoch 260/600
# -------------
# -------------
# epoch 259 || Loss:0.0000
# timer:  0.0187 sec.
# -------------
# Epoch 261/600
# -------------
# -------------
# epoch 260 || Loss:0.0000
# timer:  0.0189 sec.
# -------------
# Epoch 262/600
# -------------
# -------------
# epoch 261 || Loss:0.0000
# timer:  0.0226 sec.
# -------------
# Epoch 263/600
# -------------
# -------------
# epoch 262 || Loss:0.0000
# timer:  0.0181 sec.
# -------------
# Epoch 264/600
# -------------
# -------------
# epoch 263 || Loss:0.0000
# timer:  0.0160 sec.
# -------------
# Epoch 265/600
# -------------
# -------------
# epoch 264 || Loss:0.0000
# timer:  0.0200 sec.
# -------------
# Epoch 266/600
# -------------
# -------------
# epoch 265 || Loss:0.0000
# timer:  0.0207 sec.
# -------------
# Epoch 267/600
# -------------
# -------------
# epoch 266 || Loss:0.0000
# timer:  0.0236 sec.
# -------------
# Epoch 268/600
# -------------
# -------------
# epoch 267 || Loss:0.0000
# timer:  0.0230 sec.
# -------------
# Epoch 269/600
# -------------
# -------------
# epoch 268 || Loss:0.0000
# timer:  0.0234 sec.
# -------------
# Epoch 270/600
# -------------
# -------------
# epoch 269 || Loss:0.0000
# timer:  0.0218 sec.
# -------------
# Epoch 271/600
# -------------
# -------------
# epoch 270 || Loss:0.0000
# timer:  0.0253 sec.
# -------------
# Epoch 272/600
# -------------
# -------------
# epoch 271 || Loss:0.0000
# timer:  0.0238 sec.
# -------------
# Epoch 273/600
# -------------
# -------------
# epoch 272 || Loss:0.0000
# timer:  0.0238 sec.
# -------------
# Epoch 274/600
# -------------
# -------------
# epoch 273 || Loss:0.0000
# timer:  0.0246 sec.
# -------------
# Epoch 275/600
# -------------
# -------------
# epoch 274 || Loss:0.0000
# timer:  0.0383 sec.
# -------------
# Epoch 276/600
# -------------
# -------------
# epoch 275 || Loss:0.0000
# timer:  0.0352 sec.
# -------------
# Epoch 277/600
# -------------
# -------------
# epoch 276 || Loss:0.0000
# timer:  0.0355 sec.
# -------------
# Epoch 278/600
# -------------
# -------------
# epoch 277 || Loss:0.0000
# timer:  0.0241 sec.
# -------------
# Epoch 279/600
# -------------
# -------------
# epoch 278 || Loss:0.0000
# timer:  0.0203 sec.
# -------------
# Epoch 280/600
# -------------
# -------------
# epoch 279 || Loss:0.0000
# timer:  0.0225 sec.
# -------------
# Epoch 281/600
# -------------
# -------------
# epoch 280 || Loss:0.0000
# timer:  0.0568 sec.
# -------------
# Epoch 282/600
# -------------
# -------------
# epoch 281 || Loss:0.0000
# timer:  0.0276 sec.
# -------------
# Epoch 283/600
# -------------
# -------------
# epoch 282 || Loss:0.0000
# timer:  0.0172 sec.
# -------------
# Epoch 284/600
# -------------
# -------------
# epoch 283 || Loss:0.0000
# timer:  0.0244 sec.
# -------------
# Epoch 285/600
# -------------
# -------------
# epoch 284 || Loss:0.0000
# timer:  0.0188 sec.
# -------------
# Epoch 286/600
# -------------
# -------------
# epoch 285 || Loss:0.0000
# timer:  0.0264 sec.
# -------------
# Epoch 287/600
# -------------
# -------------
# epoch 286 || Loss:0.0000
# timer:  0.0227 sec.
# -------------
# Epoch 288/600
# -------------
# -------------
# epoch 287 || Loss:0.0000
# timer:  0.0243 sec.
# -------------
# Epoch 289/600
# -------------
# -------------
# epoch 288 || Loss:0.0000
# timer:  0.0243 sec.
# -------------
# Epoch 290/600
# -------------
# -------------
# epoch 289 || Loss:0.0000
# timer:  0.0212 sec.
# -------------
# Epoch 291/600
# -------------
# -------------
# epoch 290 || Loss:0.0000
# timer:  0.0254 sec.
# -------------
# Epoch 292/600
# -------------
# -------------
# epoch 291 || Loss:0.0000
# timer:  0.0179 sec.
# -------------
# Epoch 293/600
# -------------
# -------------
# epoch 292 || Loss:0.0000
# timer:  0.0185 sec.
# -------------
# Epoch 294/600
# -------------
# -------------
# epoch 293 || Loss:0.0000
# timer:  0.0183 sec.
# -------------
# Epoch 295/600
# -------------
# -------------
# epoch 294 || Loss:0.0000
# timer:  0.0187 sec.
# -------------
# Epoch 296/600
# -------------
# -------------
# epoch 295 || Loss:0.0000
# timer:  0.0209 sec.
# -------------
# Epoch 297/600
# -------------
# -------------
# epoch 296 || Loss:0.0000
# timer:  0.0229 sec.
# -------------
# Epoch 298/600
# -------------
# -------------
# epoch 297 || Loss:0.0000
# timer:  0.0247 sec.
# -------------
# Epoch 299/600
# -------------
# -------------
# epoch 298 || Loss:0.0000
# timer:  0.0230 sec.
# -------------
# Epoch 300/600
# -------------
# -------------
# epoch 299 || Loss:0.0000
# timer:  0.0390 sec.
# -------------
# Epoch 301/600
# -------------
# -------------
# epoch 300 || Loss:0.0000
# timer:  0.0354 sec.
# -------------
# Epoch 302/600
# -------------
# -------------
# epoch 301 || Loss:0.0000
# timer:  0.0226 sec.
# -------------
# Epoch 303/600
# -------------
# -------------
# epoch 302 || Loss:0.0000
# timer:  0.0196 sec.
# -------------
# Epoch 304/600
# -------------
# -------------
# epoch 303 || Loss:0.0000
# timer:  0.0215 sec.
# -------------
# Epoch 305/600
# -------------
# -------------
# epoch 304 || Loss:0.0000
# timer:  0.0424 sec.
# -------------
# Epoch 306/600
# -------------
# -------------
# epoch 305 || Loss:0.0000
# timer:  0.0175 sec.
# -------------
# Epoch 307/600
# -------------
# -------------
# epoch 306 || Loss:0.0000
# timer:  0.0188 sec.
# -------------
# Epoch 308/600
# -------------
# -------------
# epoch 307 || Loss:0.0000
# timer:  0.0231 sec.
# -------------
# Epoch 309/600
# -------------
# -------------
# epoch 308 || Loss:0.0000
# timer:  0.0207 sec.
# -------------
# Epoch 310/600
# -------------
# -------------
# epoch 309 || Loss:0.0000
# timer:  0.0231 sec.
# -------------
# Epoch 311/600
# -------------
# -------------
# epoch 310 || Loss:0.0000
# timer:  0.0208 sec.
# -------------
# Epoch 312/600
# -------------
# -------------
# epoch 311 || Loss:0.0000
# timer:  0.0307 sec.
# -------------
# Epoch 313/600
# -------------
# -------------
# epoch 312 || Loss:0.0000
# timer:  0.0282 sec.
# -------------
# Epoch 314/600
# -------------
# -------------
# epoch 313 || Loss:0.0000
# timer:  0.0229 sec.
# -------------
# Epoch 315/600
# -------------
# -------------
# epoch 314 || Loss:0.0000
# timer:  0.0192 sec.
# -------------
# Epoch 316/600
# -------------
# -------------
# epoch 315 || Loss:0.0000
# timer:  0.0152 sec.
# -------------
# Epoch 317/600
# -------------
# -------------
# epoch 316 || Loss:0.0000
# timer:  0.0171 sec.
# -------------
# Epoch 318/600
# -------------
# -------------
# epoch 317 || Loss:0.0000
# timer:  0.0160 sec.
# -------------
# Epoch 319/600
# -------------
# -------------
# epoch 318 || Loss:0.0000
# timer:  0.0151 sec.
# -------------
# Epoch 320/600
# -------------
# -------------
# epoch 319 || Loss:0.0000
# timer:  0.0161 sec.
# -------------
# Epoch 321/600
# -------------
# -------------
# epoch 320 || Loss:0.0000
# timer:  0.0153 sec.
# -------------
# Epoch 322/600
# -------------
# -------------
# epoch 321 || Loss:0.0000
# timer:  0.0219 sec.
# -------------
# Epoch 323/600
# -------------
# -------------
# epoch 322 || Loss:0.0000
# timer:  0.0258 sec.
# -------------
# Epoch 324/600
# -------------
# -------------
# epoch 323 || Loss:0.0000
# timer:  0.0246 sec.
# -------------
# Epoch 325/600
# -------------
# -------------
# epoch 324 || Loss:0.0000
# timer:  0.0203 sec.
# -------------
# Epoch 326/600
# -------------
# -------------
# epoch 325 || Loss:0.0000
# timer:  0.0232 sec.
# -------------
# Epoch 327/600
# -------------
# -------------
# epoch 326 || Loss:0.0000
# timer:  0.0191 sec.
# -------------
# Epoch 328/600
# -------------
# -------------
# epoch 327 || Loss:0.0000
# timer:  0.0279 sec.
# -------------
# Epoch 329/600
# -------------
# -------------
# epoch 328 || Loss:0.0000
# timer:  0.0280 sec.
# -------------
# Epoch 330/600
# -------------
# -------------
# epoch 329 || Loss:0.0000
# timer:  0.0313 sec.
# -------------
# Epoch 331/600
# -------------
# -------------
# epoch 330 || Loss:0.0000
# timer:  0.0219 sec.
# -------------
# Epoch 332/600
# -------------
# -------------
# epoch 331 || Loss:0.0000
# timer:  0.0207 sec.
# -------------
# Epoch 333/600
# -------------
# -------------
# epoch 332 || Loss:0.0000
# timer:  0.0231 sec.
# -------------
# Epoch 334/600
# -------------
# -------------
# epoch 333 || Loss:0.0000
# timer:  0.0366 sec.
# -------------
# Epoch 335/600
# -------------
# -------------
# epoch 334 || Loss:0.0000
# timer:  0.0198 sec.
# -------------
# Epoch 336/600
# -------------
# -------------
# epoch 335 || Loss:0.0000
# timer:  0.0197 sec.
# -------------
# Epoch 337/600
# -------------
# -------------
# epoch 336 || Loss:0.0000
# timer:  0.0193 sec.
# -------------
# Epoch 338/600
# -------------
# -------------
# epoch 337 || Loss:0.0000
# timer:  0.0217 sec.
# -------------
# Epoch 339/600
# -------------
# -------------
# epoch 338 || Loss:0.0000
# timer:  0.0214 sec.
# -------------
# Epoch 340/600
# -------------
# -------------
# epoch 339 || Loss:0.0000
# timer:  0.0287 sec.
# -------------
# Epoch 341/600
# -------------
# -------------
# epoch 340 || Loss:0.0000
# timer:  0.0189 sec.
# -------------
# Epoch 342/600
# -------------
# -------------
# epoch 341 || Loss:0.0000
# timer:  0.0214 sec.
# -------------
# Epoch 343/600
# -------------
# -------------
# epoch 342 || Loss:0.0000
# timer:  0.0258 sec.
# -------------
# Epoch 344/600
# -------------
# -------------
# epoch 343 || Loss:0.0000
# timer:  0.0264 sec.
# -------------
# Epoch 345/600
# -------------
# -------------
# epoch 344 || Loss:0.0000
# timer:  0.0229 sec.
# -------------
# Epoch 346/600
# -------------
# -------------
# epoch 345 || Loss:0.0000
# timer:  0.0209 sec.
# -------------
# Epoch 347/600
# -------------
# -------------
# epoch 346 || Loss:0.0000
# timer:  0.0201 sec.
# -------------
# Epoch 348/600
# -------------
# -------------
# epoch 347 || Loss:0.0000
# timer:  0.0349 sec.
# -------------
# Epoch 349/600
# -------------
# -------------
# epoch 348 || Loss:0.0000
# timer:  0.0209 sec.
# -------------
# Epoch 350/600
# -------------
# -------------
# epoch 349 || Loss:0.0000
# timer:  0.0190 sec.
# -------------
# Epoch 351/600
# -------------
# -------------
# epoch 350 || Loss:0.0000
# timer:  0.0232 sec.
# -------------
# Epoch 352/600
# -------------
# -------------
# epoch 351 || Loss:0.0000
# timer:  0.0212 sec.
# -------------
# Epoch 353/600
# -------------
# -------------
# epoch 352 || Loss:0.0000
# timer:  0.0209 sec.
# -------------
# Epoch 354/600
# -------------
# -------------
# epoch 353 || Loss:0.0000
# timer:  0.0242 sec.
# -------------
# Epoch 355/600
# -------------
# -------------
# epoch 354 || Loss:0.0000
# timer:  0.0323 sec.
# -------------
# Epoch 356/600
# -------------
# -------------
# epoch 355 || Loss:0.0000
# timer:  0.0400 sec.
# -------------
# Epoch 357/600
# -------------
# -------------
# epoch 356 || Loss:0.0000
# timer:  0.0260 sec.
# -------------
# Epoch 358/600
# -------------
# -------------
# epoch 357 || Loss:0.0000
# timer:  0.0203 sec.
# -------------
# Epoch 359/600
# -------------
# -------------
# epoch 358 || Loss:0.0000
# timer:  0.0182 sec.
# -------------
# Epoch 360/600
# -------------
# -------------
# epoch 359 || Loss:0.0000
# timer:  0.0159 sec.
# -------------
# Epoch 361/600
# -------------
# -------------
# epoch 360 || Loss:0.0000
# timer:  0.0150 sec.
# -------------
# Epoch 362/600
# -------------
# -------------
# epoch 361 || Loss:0.0000
# timer:  0.0246 sec.
# -------------
# Epoch 363/600
# -------------
# -------------
# epoch 362 || Loss:0.0000
# timer:  0.0313 sec.
# -------------
# Epoch 364/600
# -------------
# -------------
# epoch 363 || Loss:0.0000
# timer:  0.0238 sec.
# -------------
# Epoch 365/600
# -------------
# -------------
# epoch 364 || Loss:0.0000
# timer:  0.0258 sec.
# -------------
# Epoch 366/600
# -------------
# -------------
# epoch 365 || Loss:0.0000
# timer:  0.0264 sec.
# -------------
# Epoch 367/600
# -------------
# -------------
# epoch 366 || Loss:0.0000
# timer:  0.0321 sec.
# -------------
# Epoch 368/600
# -------------
# -------------
# epoch 367 || Loss:0.0000
# timer:  0.0200 sec.
# -------------
# Epoch 369/600
# -------------
# -------------
# epoch 368 || Loss:0.0000
# timer:  0.0199 sec.
# -------------
# Epoch 370/600
# -------------
# -------------
# epoch 369 || Loss:0.0000
# timer:  0.0198 sec.
# -------------
# Epoch 371/600
# -------------
# -------------
# epoch 370 || Loss:0.0000
# timer:  0.0216 sec.
# -------------
# Epoch 372/600
# -------------
# -------------
# epoch 371 || Loss:0.0000
# timer:  0.0262 sec.
# -------------
# Epoch 373/600
# -------------
# -------------
# epoch 372 || Loss:0.0000
# timer:  0.0186 sec.
# -------------
# Epoch 374/600
# -------------
# -------------
# epoch 373 || Loss:0.0000
# timer:  0.0257 sec.
# -------------
# Epoch 375/600
# -------------
# -------------
# epoch 374 || Loss:0.0000
# timer:  0.0236 sec.
# -------------
# Epoch 376/600
# -------------
# -------------
# epoch 375 || Loss:0.0000
# timer:  0.0381 sec.
# -------------
# Epoch 377/600
# -------------
# -------------
# epoch 376 || Loss:0.0000
# timer:  0.0291 sec.
# -------------
# Epoch 378/600
# -------------
# -------------
# epoch 377 || Loss:0.0000
# timer:  0.0239 sec.
# -------------
# Epoch 379/600
# -------------
# -------------
# epoch 378 || Loss:0.0000
# timer:  0.0214 sec.
# -------------
# Epoch 380/600
# -------------
# -------------
# epoch 379 || Loss:0.0000
# timer:  0.0237 sec.
# -------------
# Epoch 381/600
# -------------
# -------------
# epoch 380 || Loss:0.0000
# timer:  0.0252 sec.
# -------------
# Epoch 382/600
# -------------
# -------------
# epoch 381 || Loss:0.0000
# timer:  0.0286 sec.
# -------------
# Epoch 383/600
# -------------
# -------------
# epoch 382 || Loss:0.0000
# timer:  0.0223 sec.
# -------------
# Epoch 384/600
# -------------
# -------------
# epoch 383 || Loss:0.0000
# timer:  0.0230 sec.
# -------------
# Epoch 385/600
# -------------
# -------------
# epoch 384 || Loss:0.0000
# timer:  0.0222 sec.
# -------------
# Epoch 386/600
# -------------
# -------------
# epoch 385 || Loss:0.0000
# timer:  0.0228 sec.
# -------------
# Epoch 387/600
# -------------
# -------------
# epoch 386 || Loss:0.0000
# timer:  0.0240 sec.
# -------------
# Epoch 388/600
# -------------
# -------------
# epoch 387 || Loss:0.0000
# timer:  0.0170 sec.
# -------------
# Epoch 389/600
# -------------
# -------------
# epoch 388 || Loss:0.0000
# timer:  0.0168 sec.
# -------------
# Epoch 390/600
# -------------
# -------------
# epoch 389 || Loss:0.0000
# timer:  0.0194 sec.
# -------------
# Epoch 391/600
# -------------
# -------------
# epoch 390 || Loss:0.0000
# timer:  0.0309 sec.
# -------------
# Epoch 392/600
# -------------
# -------------
# epoch 391 || Loss:0.0000
# timer:  0.0220 sec.
# -------------
# Epoch 393/600
# -------------
# -------------
# epoch 392 || Loss:0.0000
# timer:  0.0174 sec.
# -------------
# Epoch 394/600
# -------------
# -------------
# epoch 393 || Loss:0.0000
# timer:  0.0162 sec.
# -------------
# Epoch 395/600
# -------------
# -------------
# epoch 394 || Loss:0.0000
# timer:  0.0214 sec.
# -------------
# Epoch 396/600
# -------------
# -------------
# epoch 395 || Loss:0.0000
# timer:  0.0175 sec.
# -------------
# Epoch 397/600
# -------------
# -------------
# epoch 396 || Loss:0.0000
# timer:  0.0298 sec.
# -------------
# Epoch 398/600
# -------------
# -------------
# epoch 397 || Loss:0.0000
# timer:  0.0262 sec.
# -------------
# Epoch 399/600
# -------------
# -------------
# epoch 398 || Loss:0.0000
# timer:  0.0192 sec.
# -------------
# Epoch 400/600
# -------------
# -------------
# epoch 399 || Loss:0.0000
# timer:  0.0215 sec.
# -------------
# Epoch 401/600
# -------------
# -------------
# epoch 400 || Loss:0.0000
# timer:  0.0176 sec.
# -------------
# Epoch 402/600
# -------------
# -------------
# epoch 401 || Loss:0.0000
# timer:  0.0182 sec.
# -------------
# Epoch 403/600
# -------------
# -------------
# epoch 402 || Loss:0.0000
# timer:  0.0225 sec.
# -------------
# Epoch 404/600
# -------------
# -------------
# epoch 403 || Loss:0.0000
# timer:  0.0238 sec.
# -------------
# Epoch 405/600
# -------------
# -------------
# epoch 404 || Loss:0.0000
# timer:  0.0253 sec.
# -------------
# Epoch 406/600
# -------------
# -------------
# epoch 405 || Loss:0.0000
# timer:  0.0245 sec.
# -------------
# Epoch 407/600
# -------------
# -------------
# epoch 406 || Loss:0.0000
# timer:  0.0333 sec.
# -------------
# Epoch 408/600
# -------------
# -------------
# epoch 407 || Loss:0.0000
# timer:  0.0258 sec.
# -------------
# Epoch 409/600
# -------------
# -------------
# epoch 408 || Loss:0.0000
# timer:  0.0265 sec.
# -------------
# Epoch 410/600
# -------------
# -------------
# epoch 409 || Loss:0.0000
# timer:  0.0229 sec.
# -------------
# Epoch 411/600
# -------------
# -------------
# epoch 410 || Loss:0.0000
# timer:  0.0260 sec.
# -------------
# Epoch 412/600
# -------------
# -------------
# epoch 411 || Loss:0.0000
# timer:  0.0248 sec.
# -------------
# Epoch 413/600
# -------------
# -------------
# epoch 412 || Loss:0.0000
# timer:  0.0425 sec.
# -------------
# Epoch 414/600
# -------------
# -------------
# epoch 413 || Loss:0.0000
# timer:  0.0201 sec.
# -------------
# Epoch 415/600
# -------------
# -------------
# epoch 414 || Loss:0.0000
# timer:  0.0327 sec.
# -------------
# Epoch 416/600
# -------------
# -------------
# epoch 415 || Loss:0.0000
# timer:  0.0214 sec.
# -------------
# Epoch 417/600
# -------------
# -------------
# epoch 416 || Loss:0.0000
# timer:  0.0253 sec.
# -------------
# Epoch 418/600
# -------------
# -------------
# epoch 417 || Loss:0.0000
# timer:  0.0193 sec.
# -------------
# Epoch 419/600
# -------------
# -------------
# epoch 418 || Loss:0.0000
# timer:  0.0215 sec.
# -------------
# Epoch 420/600
# -------------
# -------------
# epoch 419 || Loss:0.0000
# timer:  0.0459 sec.
# -------------
# Epoch 421/600
# -------------
# -------------
# epoch 420 || Loss:0.0000
# timer:  0.0173 sec.
# -------------
# Epoch 422/600
# -------------
# -------------
# epoch 421 || Loss:0.0000
# timer:  0.0215 sec.
# -------------
# Epoch 423/600
# -------------
# -------------
# epoch 422 || Loss:0.0000
# timer:  0.0230 sec.
# -------------
# Epoch 424/600
# -------------
# -------------
# epoch 423 || Loss:0.0000
# timer:  0.0172 sec.
# -------------
# Epoch 425/600
# -------------
# -------------
# epoch 424 || Loss:0.0000
# timer:  0.0210 sec.
# -------------
# Epoch 426/600
# -------------
# -------------
# epoch 425 || Loss:0.0000
# timer:  0.0187 sec.
# -------------
# Epoch 427/600
# -------------
# -------------
# epoch 426 || Loss:0.0000
# timer:  0.0213 sec.
# -------------
# Epoch 428/600
# -------------
# -------------
# epoch 427 || Loss:0.0000
# timer:  0.0176 sec.
# -------------
# Epoch 429/600
# -------------
# -------------
# epoch 428 || Loss:0.0000
# timer:  0.0257 sec.
# -------------
# Epoch 430/600
# -------------
# -------------
# epoch 429 || Loss:0.0000
# timer:  0.0225 sec.
# -------------
# Epoch 431/600
# -------------
# -------------
# epoch 430 || Loss:0.0000
# timer:  0.0226 sec.
# -------------
# Epoch 432/600
# -------------
# -------------
# epoch 431 || Loss:0.0000
# timer:  0.0202 sec.
# -------------
# Epoch 433/600
# -------------
# -------------
# epoch 432 || Loss:0.0000
# timer:  0.0208 sec.
# -------------
# Epoch 434/600
# -------------
# -------------
# epoch 433 || Loss:0.0000
# timer:  0.0230 sec.
# -------------
# Epoch 435/600
# -------------
# -------------
# epoch 434 || Loss:0.0000
# timer:  0.0223 sec.
# -------------
# Epoch 436/600
# -------------
# -------------
# epoch 435 || Loss:0.0000
# timer:  0.0272 sec.
# -------------
# Epoch 437/600
# -------------
# -------------
# epoch 436 || Loss:0.0000
# timer:  0.0200 sec.
# -------------
# Epoch 438/600
# -------------
# -------------
# epoch 437 || Loss:0.0000
# timer:  0.0180 sec.
# -------------
# Epoch 439/600
# -------------
# -------------
# epoch 438 || Loss:0.0000
# timer:  0.0263 sec.
# -------------
# Epoch 440/600
# -------------
# -------------
# epoch 439 || Loss:0.0000
# timer:  0.0236 sec.
# -------------
# Epoch 441/600
# -------------
# -------------
# epoch 440 || Loss:0.0000
# timer:  0.0214 sec.
# -------------
# Epoch 442/600
# -------------
# -------------
# epoch 441 || Loss:0.0000
# timer:  0.0232 sec.
# -------------
# Epoch 443/600
# -------------
# -------------
# epoch 442 || Loss:0.0000
# timer:  0.0269 sec.
# -------------
# Epoch 444/600
# -------------
# -------------
# epoch 443 || Loss:0.0000
# timer:  0.0250 sec.
# -------------
# Epoch 445/600
# -------------
# -------------
# epoch 444 || Loss:0.0000
# timer:  0.0211 sec.
# -------------
# Epoch 446/600
# -------------
# -------------
# epoch 445 || Loss:0.0000
# timer:  0.0210 sec.
# -------------
# Epoch 447/600
# -------------
# -------------
# epoch 446 || Loss:0.0000
# timer:  0.0335 sec.
# -------------
# Epoch 448/600
# -------------
# -------------
# epoch 447 || Loss:0.0000
# timer:  0.0196 sec.
# -------------
# Epoch 449/600
# -------------
# -------------
# epoch 448 || Loss:0.0000
# timer:  0.0489 sec.
# -------------
# Epoch 450/600
# -------------
# -------------
# epoch 449 || Loss:0.0000
# timer:  0.0238 sec.
# -------------
# Epoch 451/600
# -------------
# -------------
# epoch 450 || Loss:0.0000
# timer:  0.0359 sec.
# -------------
# Epoch 452/600
# -------------
# -------------
# epoch 451 || Loss:0.0000
# timer:  0.0277 sec.
# -------------
# Epoch 453/600
# -------------
# -------------
# epoch 452 || Loss:0.0000
# timer:  0.0156 sec.
# -------------
# Epoch 454/600
# -------------
# -------------
# epoch 453 || Loss:0.0000
# timer:  0.0189 sec.
# -------------
# Epoch 455/600
# -------------
# -------------
# epoch 454 || Loss:0.0000
# timer:  0.0224 sec.
# -------------
# Epoch 456/600
# -------------
# -------------
# epoch 455 || Loss:0.0000
# timer:  0.0206 sec.
# -------------
# Epoch 457/600
# -------------
# -------------
# epoch 456 || Loss:0.0000
# timer:  0.0197 sec.
# -------------
# Epoch 458/600
# -------------
# -------------
# epoch 457 || Loss:0.0000
# timer:  0.0207 sec.
# -------------
# Epoch 459/600
# -------------
# -------------
# epoch 458 || Loss:0.0000
# timer:  0.0230 sec.
# -------------
# Epoch 460/600
# -------------
# -------------
# epoch 459 || Loss:0.0000
# timer:  0.0226 sec.
# -------------
# Epoch 461/600
# -------------
# -------------
# epoch 460 || Loss:0.0000
# timer:  0.0224 sec.
# -------------
# Epoch 462/600
# -------------
# -------------
# epoch 461 || Loss:0.0000
# timer:  0.0270 sec.
# -------------
# Epoch 463/600
# -------------
# -------------
# epoch 462 || Loss:0.0000
# timer:  0.0203 sec.
# -------------
# Epoch 464/600
# -------------
# -------------
# epoch 463 || Loss:0.0000
# timer:  0.0274 sec.
# -------------
# Epoch 465/600
# -------------
# -------------
# epoch 464 || Loss:0.0000
# timer:  0.0226 sec.
# -------------
# Epoch 466/600
# -------------
# -------------
# epoch 465 || Loss:0.0000
# timer:  0.0233 sec.
# -------------
# Epoch 467/600
# -------------
# -------------
# epoch 466 || Loss:0.0000
# timer:  0.0222 sec.
# -------------
# Epoch 468/600
# -------------
# -------------
# epoch 467 || Loss:0.0000
# timer:  0.0172 sec.
# -------------
# Epoch 469/600
# -------------
# -------------
# epoch 468 || Loss:0.0000
# timer:  0.0202 sec.
# -------------
# Epoch 470/600
# -------------
# -------------
# epoch 469 || Loss:0.0000
# timer:  0.0247 sec.
# -------------
# Epoch 471/600
# -------------
# -------------
# epoch 470 || Loss:0.0000
# timer:  0.0237 sec.
# -------------
# Epoch 472/600
# -------------
# -------------
# epoch 471 || Loss:0.0000
# timer:  0.0256 sec.
# -------------
# Epoch 473/600
# -------------
# -------------
# epoch 472 || Loss:0.0000
# timer:  0.0265 sec.
# -------------
# Epoch 474/600
# -------------
# -------------
# epoch 473 || Loss:0.0000
# timer:  0.0382 sec.
# -------------
# Epoch 475/600
# -------------
# -------------
# epoch 474 || Loss:0.0000
# timer:  0.0220 sec.
# -------------
# Epoch 476/600
# -------------
# -------------
# epoch 475 || Loss:0.0000
# timer:  0.0332 sec.
# -------------
# Epoch 477/600
# -------------
# -------------
# epoch 476 || Loss:0.0000
# timer:  0.0204 sec.
# -------------
# Epoch 478/600
# -------------
# -------------
# epoch 477 || Loss:0.0000
# timer:  0.0401 sec.
# -------------
# Epoch 479/600
# -------------
# -------------
# epoch 478 || Loss:0.0000
# timer:  0.0194 sec.
# -------------
# Epoch 480/600
# -------------
# -------------
# epoch 479 || Loss:0.0000
# timer:  0.0280 sec.
# -------------
# Epoch 481/600
# -------------
# -------------
# epoch 480 || Loss:0.0000
# timer:  0.0364 sec.
# -------------
# Epoch 482/600
# -------------
# -------------
# epoch 481 || Loss:0.0000
# timer:  0.0207 sec.
# -------------
# Epoch 483/600
# -------------
# -------------
# epoch 482 || Loss:0.0000
# timer:  0.0322 sec.
# -------------
# Epoch 484/600
# -------------
# -------------
# epoch 483 || Loss:0.0000
# timer:  0.0465 sec.
# -------------
# Epoch 485/600
# -------------
# -------------
# epoch 484 || Loss:0.0000
# timer:  0.0329 sec.
# -------------
# Epoch 486/600
# -------------
# -------------
# epoch 485 || Loss:0.0000
# timer:  0.0275 sec.
# -------------
# Epoch 487/600
# -------------
# -------------
# epoch 486 || Loss:0.0000
# timer:  0.0239 sec.
# -------------
# Epoch 488/600
# -------------
# -------------
# epoch 487 || Loss:0.0000
# timer:  0.0185 sec.
# -------------
# Epoch 489/600
# -------------
# -------------
# epoch 488 || Loss:0.0000
# timer:  0.0200 sec.
# -------------
# Epoch 490/600
# -------------
# -------------
# epoch 489 || Loss:0.0000
# timer:  0.0227 sec.
# -------------
# Epoch 491/600
# -------------
# -------------
# epoch 490 || Loss:0.0000
# timer:  0.0201 sec.
# -------------
# Epoch 492/600
# -------------
# -------------
# epoch 491 || Loss:0.0000
# timer:  0.0234 sec.
# -------------
# Epoch 493/600
# -------------
# -------------
# epoch 492 || Loss:0.0000
# timer:  0.0224 sec.
# -------------
# Epoch 494/600
# -------------
# -------------
# epoch 493 || Loss:0.0000
# timer:  0.0221 sec.
# -------------
# Epoch 495/600
# -------------
# -------------
# epoch 494 || Loss:0.0000
# timer:  0.0247 sec.
# -------------
# Epoch 496/600
# -------------
# -------------
# epoch 495 || Loss:0.0000
# timer:  0.0267 sec.
# -------------
# Epoch 497/600
# -------------
# -------------
# epoch 496 || Loss:0.0000
# timer:  0.0251 sec.
# -------------
# Epoch 498/600
# -------------
# -------------
# epoch 497 || Loss:0.0000
# timer:  0.0274 sec.
# -------------
# Epoch 499/600
# -------------
# -------------
# epoch 498 || Loss:0.0000
# timer:  0.0235 sec.
# -------------
# Epoch 500/600
# -------------
# -------------
# epoch 499 || Loss:0.0000
# timer:  0.0288 sec.
# -------------
# Epoch 501/600
# -------------
# -------------
# epoch 500 || Loss:0.0000
# timer:  0.0277 sec.
# -------------
# Epoch 502/600
# -------------
# -------------
# epoch 501 || Loss:0.0000
# timer:  0.0280 sec.
# -------------
# Epoch 503/600
# -------------
# -------------
# epoch 502 || Loss:0.0000
# timer:  0.0325 sec.
# -------------
# Epoch 504/600
# -------------
# -------------
# epoch 503 || Loss:0.0000
# timer:  0.0529 sec.
# -------------
# Epoch 505/600
# -------------
# -------------
# epoch 504 || Loss:0.0000
# timer:  0.0318 sec.
# -------------
# Epoch 506/600
# -------------
# -------------
# epoch 505 || Loss:0.0000
# timer:  0.0248 sec.
# -------------
# Epoch 507/600
# -------------
# -------------
# epoch 506 || Loss:0.0000
# timer:  0.0237 sec.
# -------------
# Epoch 508/600
# -------------
# -------------
# epoch 507 || Loss:0.0000
# timer:  0.0183 sec.
# -------------
# Epoch 509/600
# -------------
# -------------
# epoch 508 || Loss:0.0000
# timer:  0.0180 sec.
# -------------
# Epoch 510/600
# -------------
# -------------
# epoch 509 || Loss:0.0000
# timer:  0.0311 sec.
# -------------
# Epoch 511/600
# -------------
# -------------
# epoch 510 || Loss:0.0000
# timer:  0.0199 sec.
# -------------
# Epoch 512/600
# -------------
# -------------
# epoch 511 || Loss:0.0000
# timer:  0.0176 sec.
# -------------
# Epoch 513/600
# -------------
# -------------
# epoch 512 || Loss:0.0000
# timer:  0.0190 sec.
# -------------
# Epoch 514/600
# -------------
# -------------
# epoch 513 || Loss:0.0000
# timer:  0.0183 sec.
# -------------
# Epoch 515/600
# -------------
# -------------
# epoch 514 || Loss:0.0000
# timer:  0.0169 sec.
# -------------
# Epoch 516/600
# -------------
# -------------
# epoch 515 || Loss:0.0000
# timer:  0.0186 sec.
# -------------
# Epoch 517/600
# -------------
# -------------
# epoch 516 || Loss:0.0000
# timer:  0.0188 sec.
# -------------
# Epoch 518/600
# -------------
# -------------
# epoch 517 || Loss:0.0000
# timer:  0.0194 sec.
# -------------
# Epoch 519/600
# -------------
# -------------
# epoch 518 || Loss:0.0000
# timer:  0.0276 sec.
# -------------
# Epoch 520/600
# -------------
# -------------
# epoch 519 || Loss:0.0000
# timer:  0.0262 sec.
# -------------
# Epoch 521/600
# -------------
# -------------
# epoch 520 || Loss:0.0000
# timer:  0.0239 sec.
# -------------
# Epoch 522/600
# -------------
# -------------
# epoch 521 || Loss:0.0000
# timer:  0.0251 sec.
# -------------
# Epoch 523/600
# -------------
# -------------
# epoch 522 || Loss:0.0000
# timer:  0.0276 sec.
# -------------
# Epoch 524/600
# -------------
# -------------
# epoch 523 || Loss:0.0000
# timer:  0.0188 sec.
# -------------
# Epoch 525/600
# -------------
# -------------
# epoch 524 || Loss:0.0000
# timer:  0.0254 sec.
# -------------
# Epoch 526/600
# -------------
# -------------
# epoch 525 || Loss:0.0000
# timer:  0.0190 sec.
# -------------
# Epoch 527/600
# -------------
# -------------
# epoch 526 || Loss:0.0000
# timer:  0.0222 sec.
# -------------
# Epoch 528/600
# -------------
# -------------
# epoch 527 || Loss:0.0000
# timer:  0.0219 sec.
# -------------
# Epoch 529/600
# -------------
# -------------
# epoch 528 || Loss:0.0000
# timer:  0.0278 sec.
# -------------
# Epoch 530/600
# -------------
# -------------
# epoch 529 || Loss:0.0000
# timer:  0.0241 sec.
# -------------
# Epoch 531/600
# -------------
# -------------
# epoch 530 || Loss:0.0000
# timer:  0.0252 sec.
# -------------
# Epoch 532/600
# -------------
# -------------
# epoch 531 || Loss:0.0000
# timer:  0.0277 sec.
# -------------
# Epoch 533/600
# -------------
# -------------
# epoch 532 || Loss:0.0000
# timer:  0.0210 sec.
# -------------
# Epoch 534/600
# -------------
# -------------
# epoch 533 || Loss:0.0000
# timer:  0.0335 sec.
# -------------
# Epoch 535/600
# -------------
# -------------
# epoch 534 || Loss:0.0000
# timer:  0.0209 sec.
# -------------
# Epoch 536/600
# -------------
# -------------
# epoch 535 || Loss:0.0000
# timer:  0.0207 sec.
# -------------
# Epoch 537/600
# -------------
# -------------
# epoch 536 || Loss:0.0000
# timer:  0.0346 sec.
# -------------
# Epoch 538/600
# -------------
# -------------
# epoch 537 || Loss:0.0000
# timer:  0.0182 sec.
# -------------
# Epoch 539/600
# -------------
# -------------
# epoch 538 || Loss:0.0000
# timer:  0.0192 sec.
# -------------
# Epoch 540/600
# -------------
# -------------
# epoch 539 || Loss:0.0000
# timer:  0.0242 sec.
# -------------
# Epoch 541/600
# -------------
# -------------
# epoch 540 || Loss:0.0000
# timer:  0.0182 sec.
# -------------
# Epoch 542/600
# -------------
# -------------
# epoch 541 || Loss:0.0000
# timer:  0.0204 sec.
# -------------
# Epoch 543/600
# -------------
# -------------
# epoch 542 || Loss:0.0000
# timer:  0.0232 sec.
# -------------
# Epoch 544/600
# -------------
# -------------
# epoch 543 || Loss:0.0000
# timer:  0.0195 sec.
# -------------
# Epoch 545/600
# -------------
# -------------
# epoch 544 || Loss:0.0000
# timer:  0.0435 sec.
# -------------
# Epoch 546/600
# -------------
# -------------
# epoch 545 || Loss:0.0000
# timer:  0.0239 sec.
# -------------
# Epoch 547/600
# -------------
# -------------
# epoch 546 || Loss:0.0000
# timer:  0.0216 sec.
# -------------
# Epoch 548/600
# -------------
# -------------
# epoch 547 || Loss:0.0000
# timer:  0.0231 sec.
# -------------
# Epoch 549/600
# -------------
# -------------
# epoch 548 || Loss:0.0000
# timer:  0.0196 sec.
# -------------
# Epoch 550/600
# -------------
# -------------
# epoch 549 || Loss:0.0000
# timer:  0.0231 sec.
# -------------
# Epoch 551/600
# -------------
# -------------
# epoch 550 || Loss:0.0000
# timer:  0.0295 sec.
# -------------
# Epoch 552/600
# -------------
# -------------
# epoch 551 || Loss:0.0000
# timer:  0.0273 sec.
# -------------
# Epoch 553/600
# -------------
# -------------
# epoch 552 || Loss:0.0000
# timer:  0.0271 sec.
# -------------
# Epoch 554/600
# -------------
# -------------
# epoch 553 || Loss:0.0000
# timer:  0.0313 sec.
# -------------
# Epoch 555/600
# -------------
# -------------
# epoch 554 || Loss:0.0000
# timer:  0.0194 sec.
# -------------
# Epoch 556/600
# -------------
# -------------
# epoch 555 || Loss:0.0000
# timer:  0.0175 sec.
# -------------
# Epoch 557/600
# -------------
# -------------
# epoch 556 || Loss:0.0000
# timer:  0.0217 sec.
# -------------
# Epoch 558/600
# -------------
# -------------
# epoch 557 || Loss:0.0000
# timer:  0.0227 sec.
# -------------
# Epoch 559/600
# -------------
# -------------
# epoch 558 || Loss:0.0000
# timer:  0.0257 sec.
# -------------
# Epoch 560/600
# -------------
# -------------
# epoch 559 || Loss:0.0000
# timer:  0.0238 sec.
# -------------
# Epoch 561/600
# -------------
# -------------
# epoch 560 || Loss:0.0000
# timer:  0.0251 sec.
# -------------
# Epoch 562/600
# -------------
# -------------
# epoch 561 || Loss:0.0000
# timer:  0.0357 sec.
# -------------
# Epoch 563/600
# -------------
# -------------
# epoch 562 || Loss:0.0000
# timer:  0.0274 sec.
# -------------
# Epoch 564/600
# -------------
# -------------
# epoch 563 || Loss:0.0000
# timer:  0.0286 sec.
# -------------
# Epoch 565/600
# -------------
# -------------
# epoch 564 || Loss:0.0000
# timer:  0.0214 sec.
# -------------
# Epoch 566/600
# -------------
# -------------
# epoch 565 || Loss:0.0000
# timer:  0.0246 sec.
# -------------
# Epoch 567/600
# -------------
# -------------
# epoch 566 || Loss:0.0000
# timer:  0.0400 sec.
# -------------
# Epoch 568/600
# -------------
# -------------
# epoch 567 || Loss:0.0000
# timer:  0.0206 sec.
# -------------
# Epoch 569/600
# -------------
# -------------
# epoch 568 || Loss:0.0000
# timer:  0.0269 sec.
# -------------
# Epoch 570/600
# -------------
# -------------
# epoch 569 || Loss:0.0000
# timer:  0.0254 sec.
# -------------
# Epoch 571/600
# -------------
# -------------
# epoch 570 || Loss:0.0000
# timer:  0.0237 sec.
# -------------
# Epoch 572/600
# -------------
# -------------
# epoch 571 || Loss:0.0000
# timer:  0.0205 sec.
# -------------
# Epoch 573/600
# -------------
# -------------
# epoch 572 || Loss:0.0000
# timer:  0.0211 sec.
# -------------
# Epoch 574/600
# -------------
# -------------
# epoch 573 || Loss:0.0000
# timer:  0.0336 sec.
# -------------
# Epoch 575/600
# -------------
# -------------
# epoch 574 || Loss:0.0000
# timer:  0.0202 sec.
# -------------
# Epoch 576/600
# -------------
# -------------
# epoch 575 || Loss:0.0000
# timer:  0.0211 sec.
# -------------
# Epoch 577/600
# -------------
# -------------
# epoch 576 || Loss:0.0000
# timer:  0.0240 sec.
# -------------
# Epoch 578/600
# -------------
# -------------
# epoch 577 || Loss:0.0000
# timer:  0.0199 sec.
# -------------
# Epoch 579/600
# -------------
# -------------
# epoch 578 || Loss:0.0000
# timer:  0.0255 sec.
# -------------
# Epoch 580/600
# -------------
# -------------
# epoch 579 || Loss:0.0000
# timer:  0.0176 sec.
# -------------
# Epoch 581/600
# -------------
# -------------
# epoch 580 || Loss:0.0000
# timer:  0.0200 sec.
# -------------
# Epoch 582/600
# -------------
# -------------
# epoch 581 || Loss:0.0000
# timer:  0.0212 sec.
# -------------
# Epoch 583/600
# -------------
# -------------
# epoch 582 || Loss:0.0000
# timer:  0.0331 sec.
# -------------
# Epoch 584/600
# -------------
# -------------
# epoch 583 || Loss:0.0000
# timer:  0.0272 sec.
# -------------
# Epoch 585/600
# -------------
# -------------
# epoch 584 || Loss:0.0000
# timer:  0.0189 sec.
# -------------
# Epoch 586/600
# -------------
# -------------
# epoch 585 || Loss:0.0000
# timer:  0.0233 sec.
# -------------
# Epoch 587/600
# -------------
# -------------
# epoch 586 || Loss:0.0000
# timer:  0.0237 sec.
# -------------
# Epoch 588/600
# -------------
# -------------
# epoch 587 || Loss:0.0000
# timer:  0.0225 sec.
# -------------
# Epoch 589/600
# -------------
# -------------
# epoch 588 || Loss:0.0000
# timer:  0.0231 sec.
# -------------
# Epoch 590/600
# -------------
# -------------
# epoch 589 || Loss:0.0000
# timer:  0.0255 sec.
# -------------
# Epoch 591/600
# -------------
# -------------
# epoch 590 || Loss:0.0000
# timer:  0.0300 sec.
# -------------
# Epoch 592/600
# -------------
# -------------
# epoch 591 || Loss:0.0000
# timer:  0.0272 sec.
# -------------
# Epoch 593/600
# -------------
# -------------
# epoch 592 || Loss:0.0000
# timer:  0.0404 sec.
# -------------
# Epoch 594/600
# -------------
# -------------
# epoch 593 || Loss:0.0000
# timer:  0.0414 sec.
# -------------
# Epoch 595/600
# -------------
# -------------
# epoch 594 || Loss:0.0000
# timer:  0.0261 sec.
# -------------
# Epoch 596/600
# -------------
# -------------
# epoch 595 || Loss:0.0000
# timer:  0.0269 sec.
# -------------
# Epoch 597/600
# -------------
# -------------
# epoch 596 || Loss:0.0000
# timer:  0.0264 sec.
# -------------
# Epoch 598/600
# -------------
# -------------
# epoch 597 || Loss:0.0000
# timer:  0.0362 sec.
# -------------
# Epoch 599/600
# -------------
# -------------
# epoch 598 || Loss:0.0000
# timer:  0.0406 sec.
# -------------
# Epoch 600/600
# -------------
# -------------
# epoch 599 || Loss:0.0000
# timer:  0.0232 sec.

# %% [markdown]
# ## Validation

# %%
length = 100
start = -3
end = 5
waith = end - start
val_x = torch.tensor([[i] for i in np.arange(start,end,waith/length)])
val_y = (val_x>1)*4
pred_y = model_mean(val_x).detach().cpu()
pred_std = model_error(val_x).detach().cpu()


fig = plt.figure()
ax = fig.add_subplot(1,1,1)
# ax.plot(val_x, pred_y,  label="predict")
ax.errorbar(val_x, pred_y, pred_std, label="predict")
ax.plot(val_x, val_y, label="true",c="red")
ax.grid()
ax.legend(loc='upper left')
plt.xlim(-3, 5)
plt.ylim(-1.5, 6)
fig.show()
# Out:
# /home/yashima/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.

# %% [markdown]
# # Stochastic Reression Model

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Modified ReLU

# %%
def ReLUGauss(mu_in, var_in, epsilon=1.0e-6, cut_sd=4.0):
    mu_out = torch.zeros(mu_in.shape[0], mu_in.shape[1])
    var_out = torch.zeros(var_in.shape[0], var_in.shape[1])
    mu = mu_in
    var = var_in
    sigma = torch.sqrt(var+1e-16)

    if (var < 0).any().item(): raise Exception(f"ERROR in ReLUGauss: 'var_in' should be all positive value, but it has negative value.")
    idx_SmallSigma = (sigma < epsilon)
    if cut_sd != None:
        idx_LargeMu = (mu > cut_sd*sigma)
        idx_SmallMU = (mu < -cut_sd*sigma)

    sqrt2 = math.sqrt(2.0)
    sqrt2pi = math.sqrt(2.0*math.pi)    
    z = mu / (sqrt2*sigma+1e-16)
    E = torch.erf(z)
    X = torch.exp(-z*z)
    mu_out = sigma/sqrt2pi*X + mu/2.0*(1.0+E)
    var_out = (1.0+E)/4.0*(mu*mu*(1.0-E)+2.0*var) - sigma*X/sqrt2pi*(sigma*X/sqrt2pi+mu*E)
    
    idx_SmallVarOut = (var_out<0.0)*(var_out>-epsilon)
    isError = ((var_out<0.0)*(var_out<=-epsilon)).any().item()
    if isError:
        msg= f'ERROR in ReLUGauss: (mu: {mu}\n, sigma: {sigma}\n, mu_out: {mu_out}\n, var_out: {var_out}\n)'
        print(msg)
        raise Exception(msg)


    mu_out = mu_out*~idx_SmallSigma + idx_SmallSigma*torch.relu(mu)
    var_out *= ~idx_SmallSigma
    if cut_sd != None:
        mu_out = mu_out*~(idx_LargeMu*~idx_SmallSigma) + (idx_LargeMu*~idx_SmallSigma)*mu
        var_out = var_out*~(idx_LargeMu*~idx_SmallSigma) + (idx_LargeMu*~idx_SmallSigma)*var
        mu_out = mu_out*~(idx_SmallMU*~(idx_LargeMu|idx_SmallSigma))
        var_out = var_out*~(idx_SmallMU*~(idx_LargeMu|idx_SmallSigma))
        var_out = var_out*~(idx_SmallVarOut*~((idx_LargeMu|idx_SmallSigma)|idx_SmallMU))
    else:
        var_out = var_out*~(idx_SmallVarOut*~idx_SmallSigma)
            
    var_out = torch.diag_embed(var_out)
    
    return mu_out, var_out

# %%
length = 100
start = -5
end = 5
waith = end - start
x = torch.arange(start, end, waith/length).view(-1, 1)
in_var = torch.ones(length, 1)
y, out_var = ReLUGauss(x, in_var)
out_var = out_var.reshape(-1, 1)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.errorbar(x, y, torch.sqrt(out_var), label="E[ReLU] +/- sd[ReLU]")
ax.plot(x, torch.relu(x), label="ReLU")
ax.grid()
ax.legend(loc='upper left')
plt.xlim(start, end)
plt.ylim(-0.5, end+0.5)
fig.show()
# Out:
# /home/yashima/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   if sys.path[0] == '':

# %% [markdown]
# Fig. 2. Expectation of ReLU.

# %% [markdown]
# ### Custom DropOut

# %%
class CustomDropout(nn.Module):
    
    __constants__ = ['p', 'inplace']

    def __init__(self, p=0.5, inplace=False):
        super(CustomDropout, self).__init__()
        if p < 0 or p > 1:
            raise ValueError("dropout probability has to be between 0 and 1, "
                             "but got {}".format(p))
        self.p = p
        self.inplace = inplace
        self.flag = torch.zeros(1,1)
    
    def forward(self, input):
        mu_in = input[0]
        var_in = input[1]    
        self.flag = F.dropout(torch.ones(mu_in.shape[0], mu_in.shape[1]), self.p, self.training, self.inplace)
        self.flag = self.flag.to(device)
        try:           
            mu_out = mu_in*self.flag
            var_out = var_in*(torch.diag_embed(self.flag))
        except:     
            self.flag = self.flag.to("cpu")
            mu_out = mu_in*self.flag
            var_out = var_in*(torch.diag_embed(self.flag))
        
        return mu_out, var_out
    
    def extra_repr(self):
        return 'p={}, inplace={}'.format(self.p, self.inplace)
    
    def to(self, *args, **kwargs):
        self.b = self.flag.to(*args, **kwargs) 
        return self

# %% [markdown]
# ### Modeling

# %%
def ModifyInput(input):
    if input.dim() == 2:
        mu = input[:, 0].unsqueeze(-1)
        var = input[:, 1].unsqueeze(-1).unsqueeze(-1)
    else:
        raise Exception("Input shape should be (BATCH x 2).")
    return mu, var

def ModifyOutput(input):
    mu = input[0]
    var = input[1]
    out = torch.cat([mu, var], dim=1)
        
    return out


class StochasticLinear(nn.Module):
    
    def __init__(self, in_features, out_features):
        super(StochasticLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(torch.Tensor(out_features, in_features))
        self.bias = nn.Parameter(torch.Tensor(out_features))
        self.reset_parameters()
        
    def reset_parameters(self):
        nn.init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        fan_in, _ = nn.init._calculate_fan_in_and_fan_out(self.weight)
        bound = 1 / math.sqrt(fan_in)
        nn.init.uniform_(self.bias, -bound, bound)
        
    def forward(self, input):
        mu_in = input[0]
        var_in = input[1]
        mu_out = mu_in @ self.weight.T + self.bias
        var_out = torch.diagonal(self.weight @ var_in @ self.weight.T, dim1=-2, dim2=-1)
                
        return mu_out, var_out
    
    def extra_repr(self):
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias
        )
    
    
class StochasticReLU(nn.Module):
    def __init__(self, inplace=False):
        super(StochasticReLU, self).__init__()
        self.inplace = inplace
        
    def forward(self, input):
        mu_in = input[0]
        var_in = input[1]
        mu_out, var_out = ReLUGauss(mu_in, var_in)
        return mu_out, var_out
        
    def extra_repr(self):
        inplace_str = 'inplace=True' if self.inplace else ''
        return inplace_str

# %%
class StochasticRegressor(nn.Module):
    
    def __init__(self):
        super(StochasticRegressor, self).__init__()
        self.layer1 = StochasticLinear(1, 200)
        self.layer2 = StochasticLinear(200, 200)
        self.last = StochasticLinear(200, 1)
        self.dropout = CustomDropout(p=0.01)
        
    def forward(self, x):
        out = ModifyInput(x)
        out = self.layer1(out)
        out = StochasticReLU()(out)
        out = self.dropout(out)
        out = self.layer2(out)
        out = StochasticReLU()(out)
        out = self.dropout(out)
        out = self.last(out)
        out = ModifyOutput(out)
        
        return out

# %% [markdown]
# ## Get Weigts

# %%
def LoadMeanWeight(model_mean, model_stochastic):
    length = len(model_mean.state_dict().keys())
    keys_mean = iter(model_mean.state_dict().keys())
    keys_stochastic = iter(model_stochastic.state_dict().keys())
    for i in range(length):
        model_stochastic.state_dict()[next(keys_stochastic)][:] = model_mean.state_dict()[next(keys_mean)]
    
    model_stochastic.eval()
    return model_stochastic

# %%
model_stochastic = StochasticRegressor()
model_stochastic = LoadMeanWeight(model_mean, model_stochastic)

# %% [markdown]
# ## Prediction

# %%
length = 100
start = -3
end = 5
waith = end - start
in_var1 = 0.
in_var2 = 0.25
val_x1 = torch.tensor([[i, in_var1] for i in np.arange(start,end,waith/length)])
val_x2 = torch.tensor([[i, in_var2] for i in np.arange(start,end,waith/length)])
val_y = (val_x1[:,0]>1)*4

pred_y1 = model_stochastic(val_x1).detach().cpu()
mu1 = pred_y1[:,0]
std1 = torch.sqrt(pred_y1[:,1] + torch.pow(model_error(val_x[:,0].view(-1,1)).detach().cpu(),2).view(-1))

pred_y2 = model_stochastic(val_x2).detach().cpu()
mu2 = pred_y2[:,0]
std2 = torch.sqrt(pred_y1[:,1] + torch.pow(model_error(val_x[:,0].view(-1,1)).detach().cpu(),2).view(-1))


fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(1,2,1)
ax1.errorbar(val_x[:,0], mu1, std1, label="NN (mean+std, x_sd=0)",c="orange")
ax1.plot(val_x[:,0], val_y, label="true",c="g")
ax1.grid()
ax1.legend(loc='upper left')
plt.xlim(-3, 5)
plt.ylim(-1.5, 6.5)

ax2 = fig.add_subplot(1,2,2)
ax2.errorbar(val_x[:,0], mu2, std2, label="NN (mean+std, x_sd=0.5)",c="orange")
ax2.plot(val_x[:,0], val_y, label="true",c="g")
ax2.grid()
ax2.legend(loc='upper left')
plt.xlim(-3, 5)
plt.ylim(-1.5, 6.5)

fig.show()

# %% [markdown]
# Fig. 3. Learning a step function.

# %% [markdown]
# # Regressrion Linear Function with changing noize

# %%
class LinearDataset(data.Dataset):
    
    def __init__(self, upper=5, lower=-5, length=100, error_range1=1, error_range2=0.25, model_mean=None):
        self.length = length
        noise1 = np.array([np.random.uniform(-error_range1,error_range1) for i in range(self.length)]).reshape(-1,1).astype(np.float32)
        noise2 = np.array([np.random.uniform(-error_range2,error_range2) for i in range(self.length)]).reshape(-1,1).astype(np.float32)
         
        self.input = np.array([np.random.uniform(lower,upper) for i in range(self.length)]).reshape(-1,1).astype(np.float32)
        self.output = (0.5 * self.input).astype(np.float32)
        self.output[np.abs(self.output)<1] += np.array([np.random.uniform(-error_range1,error_range1) for i in range(len(self.output[np.abs(self.output)<1]))]).astype(np.float32)
        self.output[np.abs(self.output)>=1] += np.array([np.random.uniform(-error_range2,error_range2) for i in range(len(self.output[np.abs(self.output)>=1]))]).astype(np.float32)
        if model_mean!=None:
            pred = model_mean(torch.tensor(self.input)).to("cpu")
            self.output = torch.abs(torch.tensor(self.output) - pred)

    def __len__(self):
        return self.length
    
    def __getitem__(self, index):
        x = self.input[index]
        y = self.output[index]
        
        return x, y

# %%
dataset = LinearDataset(length=300)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=300,shuffle=True)
x, y = next(iter(dataloader))

plt.scatter(x, y)
plt.xlim(-6, 6)
plt.ylim(-3, 3)
plt.grid()
plt.show()

# %%
dataset = LinearDataset(length=300)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=64,shuffle=True)

model_mean_l = BasicRegressor()
model_mean_l = train_mean(model_mean_l, dataloader,30)
# Out:
# -------------
# Epoch 1/30
# -------------
# -------------
# epoch 0 || Loss:0.0988
# timer:  0.0380 sec.
# -------------
# Epoch 2/30
# -------------
# -------------
# epoch 1 || Loss:0.0294
# timer:  0.0353 sec.
# -------------
# Epoch 3/30
# -------------
# -------------
# epoch 2 || Loss:0.0256
# timer:  0.0381 sec.
# -------------
# Epoch 4/30
# -------------
# -------------
# epoch 3 || Loss:0.0180
# timer:  0.0488 sec.
# -------------
# Epoch 5/30
# -------------
# -------------
# epoch 4 || Loss:0.0162
# timer:  0.0291 sec.
# -------------
# Epoch 6/30
# -------------
# -------------
# epoch 5 || Loss:0.0163
# timer:  0.0474 sec.
# -------------
# Epoch 7/30
# -------------
# -------------
# epoch 6 || Loss:0.0151
# timer:  0.0442 sec.
# -------------
# Epoch 8/30
# -------------
# -------------
# epoch 7 || Loss:0.0150
# timer:  0.0660 sec.
# -------------
# Epoch 9/30
# -------------
# -------------
# epoch 8 || Loss:0.0143
# timer:  0.0338 sec.
# -------------
# Epoch 10/30
# -------------
# -------------
# epoch 9 || Loss:0.0150
# timer:  0.0438 sec.
# -------------
# Epoch 11/30
# -------------
# -------------
# epoch 10 || Loss:0.0144
# timer:  0.0453 sec.
# -------------
# Epoch 12/30
# -------------
# -------------
# epoch 11 || Loss:0.0143
# timer:  0.0387 sec.
# -------------
# Epoch 13/30
# -------------
# -------------
# epoch 12 || Loss:0.0147
# timer:  0.0402 sec.
# -------------
# Epoch 14/30
# -------------
# -------------
# epoch 13 || Loss:0.0143
# timer:  0.0476 sec.
# -------------
# Epoch 15/30
# -------------
# -------------
# epoch 14 || Loss:0.0142
# timer:  0.0584 sec.
# -------------
# Epoch 16/30
# -------------
# -------------
# epoch 15 || Loss:0.0147
# timer:  0.0361 sec.
# -------------
# Epoch 17/30
# -------------
# -------------
# epoch 16 || Loss:0.0141
# timer:  0.0425 sec.
# -------------
# Epoch 18/30
# -------------
# -------------
# epoch 17 || Loss:0.0147
# timer:  0.0346 sec.
# -------------
# Epoch 19/30
# -------------
# -------------
# epoch 18 || Loss:0.0144
# timer:  0.0631 sec.
# -------------
# Epoch 20/30
# -------------
# -------------
# epoch 19 || Loss:0.0141
# timer:  0.0466 sec.
# -------------
# Epoch 21/30
# -------------
# -------------
# epoch 20 || Loss:0.0146
# timer:  0.0394 sec.
# -------------
# Epoch 22/30
# -------------
# -------------
# epoch 21 || Loss:0.0148
# timer:  0.0398 sec.
# -------------
# Epoch 23/30
# -------------
# -------------
# epoch 22 || Loss:0.0147
# timer:  0.0693 sec.
# -------------
# Epoch 24/30
# -------------
# -------------
# epoch 23 || Loss:0.0142
# timer:  0.0422 sec.
# -------------
# Epoch 25/30
# -------------
# -------------
# epoch 24 || Loss:0.0147
# timer:  0.0378 sec.
# -------------
# Epoch 26/30
# -------------
# -------------
# epoch 25 || Loss:0.0144
# timer:  0.0456 sec.
# -------------
# Epoch 27/30
# -------------
# -------------
# epoch 26 || Loss:0.0151
# timer:  0.0419 sec.
# -------------
# Epoch 28/30
# -------------
# -------------
# epoch 27 || Loss:0.0148
# timer:  0.0436 sec.
# -------------
# Epoch 29/30
# -------------
# -------------
# epoch 28 || Loss:0.0142
# timer:  0.0422 sec.
# -------------
# Epoch 30/30
# -------------
# -------------
# epoch 29 || Loss:0.0142
# timer:  0.0460 sec.

# %%
dataset = LinearDataset(length=300, model_mean=model_mean_l)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=64,shuffle=True)

model_error_l = BasicRegressor()
model_error_l = train_error(model_error_l, dataloader,600)
# Out:
# -------------
# Epoch 1/600
# -------------
# -------------
# epoch 0 || Loss:0.0184
# timer:  0.0864 sec.
# -------------
# Epoch 2/600
# -------------
# -------------
# epoch 1 || Loss:0.0140
# timer:  0.0607 sec.
# -------------
# Epoch 3/600
# -------------
# -------------
# epoch 2 || Loss:0.0051
# timer:  0.0704 sec.
# -------------
# Epoch 4/600
# -------------
# -------------
# epoch 3 || Loss:0.0040
# timer:  0.0586 sec.
# -------------
# Epoch 5/600
# -------------
# -------------
# epoch 4 || Loss:0.0028
# timer:  0.0480 sec.
# -------------
# Epoch 6/600
# -------------
# -------------
# epoch 5 || Loss:0.0028
# timer:  0.0496 sec.
# -------------
# Epoch 7/600
# -------------
# -------------
# epoch 6 || Loss:0.0024
# timer:  0.0524 sec.
# -------------
# Epoch 8/600
# -------------
# -------------
# epoch 7 || Loss:0.0021
# timer:  0.0592 sec.
# -------------
# Epoch 9/600
# -------------
# -------------
# epoch 8 || Loss:0.0020
# timer:  0.0548 sec.
# -------------
# Epoch 10/600
# -------------
# -------------
# epoch 9 || Loss:0.0020
# timer:  0.0597 sec.
# -------------
# Epoch 11/600
# -------------
# -------------
# epoch 10 || Loss:0.0019
# timer:  0.0601 sec.
# -------------
# Epoch 12/600
# -------------
# -------------
# epoch 11 || Loss:0.0019
# timer:  0.0856 sec.
# -------------
# Epoch 13/600
# -------------
# -------------
# epoch 12 || Loss:0.0019
# timer:  0.0547 sec.
# -------------
# Epoch 14/600
# -------------
# -------------
# epoch 13 || Loss:0.0018
# timer:  0.0607 sec.
# -------------
# Epoch 15/600
# -------------
# -------------
# epoch 14 || Loss:0.0017
# timer:  0.0714 sec.
# -------------
# Epoch 16/600
# -------------
# -------------
# epoch 15 || Loss:0.0017
# timer:  0.0675 sec.
# -------------
# Epoch 17/600
# -------------
# -------------
# epoch 16 || Loss:0.0018
# timer:  0.0783 sec.
# -------------
# Epoch 18/600
# -------------
# -------------
# epoch 17 || Loss:0.0016
# timer:  0.0503 sec.
# -------------
# Epoch 19/600
# -------------
# -------------
# epoch 18 || Loss:0.0017
# timer:  0.0691 sec.
# -------------
# Epoch 20/600
# -------------
# -------------
# epoch 19 || Loss:0.0018
# timer:  0.0563 sec.
# -------------
# Epoch 21/600
# -------------
# -------------
# epoch 20 || Loss:0.0018
# timer:  0.0578 sec.
# -------------
# Epoch 22/600
# -------------
# -------------
# epoch 21 || Loss:0.0017
# timer:  0.0770 sec.
# -------------
# Epoch 23/600
# -------------
# -------------
# epoch 22 || Loss:0.0018
# timer:  0.0615 sec.
# -------------
# Epoch 24/600
# -------------
# -------------
# epoch 23 || Loss:0.0017
# timer:  0.0801 sec.
# -------------
# Epoch 25/600
# -------------
# -------------
# epoch 24 || Loss:0.0018
# timer:  0.0485 sec.
# -------------
# Epoch 26/600
# -------------
# -------------
# epoch 25 || Loss:0.0017
# timer:  0.0618 sec.
# -------------
# Epoch 27/600
# -------------
# -------------
# epoch 26 || Loss:0.0017
# timer:  0.0654 sec.
# -------------
# Epoch 28/600
# -------------
# -------------
# epoch 27 || Loss:0.0017
# timer:  0.0728 sec.
# -------------
# Epoch 29/600
# -------------
# -------------
# epoch 28 || Loss:0.0017
# timer:  0.0656 sec.
# -------------
# Epoch 30/600
# -------------
# -------------
# epoch 29 || Loss:0.0017
# timer:  0.0660 sec.
# -------------
# Epoch 31/600
# -------------
# -------------
# epoch 30 || Loss:0.0016
# timer:  0.0805 sec.
# -------------
# Epoch 32/600
# -------------
# -------------
# epoch 31 || Loss:0.0016
# timer:  0.0578 sec.
# -------------
# Epoch 33/600
# -------------
# -------------
# epoch 32 || Loss:0.0016
# timer:  0.0717 sec.
# -------------
# Epoch 34/600
# -------------
# -------------
# epoch 33 || Loss:0.0017
# timer:  0.0530 sec.
# -------------
# Epoch 35/600
# -------------
# -------------
# epoch 34 || Loss:0.0017
# timer:  0.0451 sec.
# -------------
# Epoch 36/600
# -------------
# -------------
# epoch 35 || Loss:0.0015
# timer:  0.0748 sec.
# -------------
# Epoch 37/600
# -------------
# -------------
# epoch 36 || Loss:0.0016
# timer:  0.0486 sec.
# -------------
# Epoch 38/600
# -------------
# -------------
# epoch 37 || Loss:0.0015
# timer:  0.0588 sec.
# -------------
# Epoch 39/600
# -------------
# -------------
# epoch 38 || Loss:0.0016
# timer:  0.0591 sec.
# -------------
# Epoch 40/600
# -------------
# -------------
# epoch 39 || Loss:0.0015
# timer:  0.0556 sec.
# -------------
# Epoch 41/600
# -------------
# -------------
# epoch 40 || Loss:0.0016
# timer:  0.0526 sec.
# -------------
# Epoch 42/600
# -------------
# -------------
# epoch 41 || Loss:0.0015
# timer:  0.0758 sec.
# -------------
# Epoch 43/600
# -------------
# -------------
# epoch 42 || Loss:0.0015
# timer:  0.0529 sec.
# -------------
# Epoch 44/600
# -------------
# -------------
# epoch 43 || Loss:0.0015
# timer:  0.0572 sec.
# -------------
# Epoch 45/600
# -------------
# -------------
# epoch 44 || Loss:0.0015
# timer:  0.0667 sec.
# -------------
# Epoch 46/600
# -------------
# -------------
# epoch 45 || Loss:0.0016
# timer:  0.0555 sec.
# -------------
# Epoch 47/600
# -------------
# -------------
# epoch 46 || Loss:0.0015
# timer:  0.0503 sec.
# -------------
# Epoch 48/600
# -------------
# -------------
# epoch 47 || Loss:0.0015
# timer:  0.0702 sec.
# -------------
# Epoch 49/600
# -------------
# -------------
# epoch 48 || Loss:0.0015
# timer:  0.0573 sec.
# -------------
# Epoch 50/600
# -------------
# -------------
# epoch 49 || Loss:0.0015
# timer:  0.0513 sec.
# -------------
# Epoch 51/600
# -------------
# -------------
# epoch 50 || Loss:0.0015
# timer:  0.0592 sec.
# -------------
# Epoch 52/600
# -------------
# -------------
# epoch 51 || Loss:0.0016
# timer:  0.0588 sec.
# -------------
# Epoch 53/600
# -------------
# -------------
# epoch 52 || Loss:0.0015
# timer:  0.0558 sec.
# -------------
# Epoch 54/600
# -------------
# -------------
# epoch 53 || Loss:0.0015
# timer:  0.0787 sec.
# -------------
# Epoch 55/600
# -------------
# -------------
# epoch 54 || Loss:0.0015
# timer:  0.0580 sec.
# -------------
# Epoch 56/600
# -------------
# -------------
# epoch 55 || Loss:0.0015
# timer:  0.0795 sec.
# -------------
# Epoch 57/600
# -------------
# -------------
# epoch 56 || Loss:0.0015
# timer:  0.0505 sec.
# -------------
# Epoch 58/600
# -------------
# -------------
# epoch 57 || Loss:0.0015
# timer:  0.0490 sec.
# -------------
# Epoch 59/600
# -------------
# -------------
# epoch 58 || Loss:0.0015
# timer:  0.0540 sec.
# -------------
# Epoch 60/600
# -------------
# -------------
# epoch 59 || Loss:0.0015
# timer:  0.0571 sec.
# -------------
# Epoch 61/600
# -------------
# -------------
# epoch 60 || Loss:0.0015
# timer:  0.0528 sec.
# -------------
# Epoch 62/600
# -------------
# -------------
# epoch 61 || Loss:0.0016
# timer:  0.0404 sec.
# -------------
# Epoch 63/600
# -------------
# -------------
# epoch 62 || Loss:0.0015
# timer:  0.0489 sec.
# -------------
# Epoch 64/600
# -------------
# -------------
# epoch 63 || Loss:0.0016
# timer:  0.0505 sec.
# -------------
# Epoch 65/600
# -------------
# -------------
# epoch 64 || Loss:0.0016
# timer:  0.0477 sec.
# -------------
# Epoch 66/600
# -------------
# -------------
# epoch 65 || Loss:0.0016
# timer:  0.0463 sec.
# -------------
# Epoch 67/600
# -------------
# -------------
# epoch 66 || Loss:0.0016
# timer:  0.0538 sec.
# -------------
# Epoch 68/600
# -------------
# -------------
# epoch 67 || Loss:0.0016
# timer:  0.0486 sec.
# -------------
# Epoch 69/600
# -------------
# -------------
# epoch 68 || Loss:0.0017
# timer:  0.0647 sec.
# -------------
# Epoch 70/600
# -------------
# -------------
# epoch 69 || Loss:0.0016
# timer:  0.0457 sec.
# -------------
# Epoch 71/600
# -------------
# -------------
# epoch 70 || Loss:0.0017
# timer:  0.0573 sec.
# -------------
# Epoch 72/600
# -------------
# -------------
# epoch 71 || Loss:0.0017
# timer:  0.0559 sec.
# -------------
# Epoch 73/600
# -------------
# -------------
# epoch 72 || Loss:0.0015
# timer:  0.0465 sec.
# -------------
# Epoch 74/600
# -------------
# -------------
# epoch 73 || Loss:0.0014
# timer:  0.0548 sec.
# -------------
# Epoch 75/600
# -------------
# -------------
# epoch 74 || Loss:0.0014
# timer:  0.0536 sec.
# -------------
# Epoch 76/600
# -------------
# -------------
# epoch 75 || Loss:0.0016
# timer:  0.0502 sec.
# -------------
# Epoch 77/600
# -------------
# -------------
# epoch 76 || Loss:0.0016
# timer:  0.0494 sec.
# -------------
# Epoch 78/600
# -------------
# -------------
# epoch 77 || Loss:0.0014
# timer:  0.0497 sec.
# -------------
# Epoch 79/600
# -------------
# -------------
# epoch 78 || Loss:0.0015
# timer:  0.0471 sec.
# -------------
# Epoch 80/600
# -------------
# -------------
# epoch 79 || Loss:0.0014
# timer:  0.0465 sec.
# -------------
# Epoch 81/600
# -------------
# -------------
# epoch 80 || Loss:0.0015
# timer:  0.0509 sec.
# -------------
# Epoch 82/600
# -------------
# -------------
# epoch 81 || Loss:0.0014
# timer:  0.0578 sec.
# -------------
# Epoch 83/600
# -------------
# -------------
# epoch 82 || Loss:0.0014
# timer:  0.0636 sec.
# -------------
# Epoch 84/600
# -------------
# -------------
# epoch 83 || Loss:0.0015
# timer:  0.0469 sec.
# -------------
# Epoch 85/600
# -------------
# -------------
# epoch 84 || Loss:0.0015
# timer:  0.0573 sec.
# -------------
# Epoch 86/600
# -------------
# -------------
# epoch 85 || Loss:0.0014
# timer:  0.0658 sec.
# -------------
# Epoch 87/600
# -------------
# -------------
# epoch 86 || Loss:0.0015
# timer:  0.0617 sec.
# -------------
# Epoch 88/600
# -------------
# -------------
# epoch 87 || Loss:0.0015
# timer:  0.0643 sec.
# -------------
# Epoch 89/600
# -------------
# -------------
# epoch 88 || Loss:0.0014
# timer:  0.0551 sec.
# -------------
# Epoch 90/600
# -------------
# -------------
# epoch 89 || Loss:0.0013
# timer:  0.0657 sec.
# -------------
# Epoch 91/600
# -------------
# -------------
# epoch 90 || Loss:0.0015
# timer:  0.0593 sec.
# -------------
# Epoch 92/600
# -------------
# -------------
# epoch 91 || Loss:0.0015
# timer:  0.0582 sec.
# -------------
# Epoch 93/600
# -------------
# -------------
# epoch 92 || Loss:0.0015
# timer:  0.0501 sec.
# -------------
# Epoch 94/600
# -------------
# -------------
# epoch 93 || Loss:0.0015
# timer:  0.0735 sec.
# -------------
# Epoch 95/600
# -------------
# -------------
# epoch 94 || Loss:0.0014
# timer:  0.0608 sec.
# -------------
# Epoch 96/600
# -------------
# -------------
# epoch 95 || Loss:0.0014
# timer:  0.0575 sec.
# -------------
# Epoch 97/600
# -------------
# -------------
# epoch 96 || Loss:0.0014
# timer:  0.0617 sec.
# -------------
# Epoch 98/600
# -------------
# -------------
# epoch 97 || Loss:0.0014
# timer:  0.0538 sec.
# -------------
# Epoch 99/600
# -------------
# -------------
# epoch 98 || Loss:0.0013
# timer:  0.0627 sec.
# -------------
# Epoch 100/600
# -------------
# -------------
# epoch 99 || Loss:0.0014
# timer:  0.0573 sec.
# -------------
# Epoch 101/600
# -------------
# -------------
# epoch 100 || Loss:0.0014
# timer:  0.0566 sec.
# -------------
# Epoch 102/600
# -------------
# -------------
# epoch 101 || Loss:0.0014
# timer:  0.0438 sec.
# -------------
# Epoch 103/600
# -------------
# -------------
# epoch 102 || Loss:0.0014
# timer:  0.0435 sec.
# -------------
# Epoch 104/600
# -------------
# -------------
# epoch 103 || Loss:0.0014
# timer:  0.0448 sec.
# -------------
# Epoch 105/600
# -------------
# -------------
# epoch 104 || Loss:0.0014
# timer:  0.0587 sec.
# -------------
# Epoch 106/600
# -------------
# -------------
# epoch 105 || Loss:0.0014
# timer:  0.0483 sec.
# -------------
# Epoch 107/600
# -------------
# -------------
# epoch 106 || Loss:0.0015
# timer:  0.0788 sec.
# -------------
# Epoch 108/600
# -------------
# -------------
# epoch 107 || Loss:0.0015
# timer:  0.0565 sec.
# -------------
# Epoch 109/600
# -------------
# -------------
# epoch 108 || Loss:0.0014
# timer:  0.0668 sec.
# -------------
# Epoch 110/600
# -------------
# -------------
# epoch 109 || Loss:0.0014
# timer:  0.0515 sec.
# -------------
# Epoch 111/600
# -------------
# -------------
# epoch 110 || Loss:0.0013
# timer:  0.0518 sec.
# -------------
# Epoch 112/600
# -------------
# -------------
# epoch 111 || Loss:0.0014
# timer:  0.0771 sec.
# -------------
# Epoch 113/600
# -------------
# -------------
# epoch 112 || Loss:0.0014
# timer:  0.0659 sec.
# -------------
# Epoch 114/600
# -------------
# -------------
# epoch 113 || Loss:0.0014
# timer:  0.0592 sec.
# -------------
# Epoch 115/600
# -------------
# -------------
# epoch 114 || Loss:0.0013
# timer:  0.0588 sec.
# -------------
# Epoch 116/600
# -------------
# -------------
# epoch 115 || Loss:0.0014
# timer:  0.0649 sec.
# -------------
# Epoch 117/600
# -------------
# -------------
# epoch 116 || Loss:0.0013
# timer:  0.0554 sec.
# -------------
# Epoch 118/600
# -------------
# -------------
# epoch 117 || Loss:0.0013
# timer:  0.0619 sec.
# -------------
# Epoch 119/600
# -------------
# -------------
# epoch 118 || Loss:0.0014
# timer:  0.0493 sec.
# -------------
# Epoch 120/600
# -------------
# -------------
# epoch 119 || Loss:0.0014
# timer:  0.0436 sec.
# -------------
# Epoch 121/600
# -------------
# -------------
# epoch 120 || Loss:0.0014
# timer:  0.0486 sec.
# -------------
# Epoch 122/600
# -------------
# -------------
# epoch 121 || Loss:0.0013
# timer:  0.0604 sec.
# -------------
# Epoch 123/600
# -------------
# -------------
# epoch 122 || Loss:0.0014
# timer:  0.0614 sec.
# -------------
# Epoch 124/600
# -------------
# -------------
# epoch 123 || Loss:0.0013
# timer:  0.0580 sec.
# -------------
# Epoch 125/600
# -------------
# -------------
# epoch 124 || Loss:0.0013
# timer:  0.0621 sec.
# -------------
# Epoch 126/600
# -------------
# -------------
# epoch 125 || Loss:0.0013
# timer:  0.0593 sec.
# -------------
# Epoch 127/600
# -------------
# -------------
# epoch 126 || Loss:0.0013
# timer:  0.0741 sec.
# -------------
# Epoch 128/600
# -------------
# -------------
# epoch 127 || Loss:0.0014
# timer:  0.0596 sec.
# -------------
# Epoch 129/600
# -------------
# -------------
# epoch 128 || Loss:0.0016
# timer:  0.0556 sec.
# -------------
# Epoch 130/600
# -------------
# -------------
# epoch 129 || Loss:0.0014
# timer:  0.0537 sec.
# -------------
# Epoch 131/600
# -------------
# -------------
# epoch 130 || Loss:0.0014
# timer:  0.0497 sec.
# -------------
# Epoch 132/600
# -------------
# -------------
# epoch 131 || Loss:0.0014
# timer:  0.0686 sec.
# -------------
# Epoch 133/600
# -------------
# -------------
# epoch 132 || Loss:0.0014
# timer:  0.0519 sec.
# -------------
# Epoch 134/600
# -------------
# -------------
# epoch 133 || Loss:0.0014
# timer:  0.0804 sec.
# -------------
# Epoch 135/600
# -------------
# -------------
# epoch 134 || Loss:0.0013
# timer:  0.0822 sec.
# -------------
# Epoch 136/600
# -------------
# -------------
# epoch 135 || Loss:0.0013
# timer:  0.0623 sec.
# -------------
# Epoch 137/600
# -------------
# -------------
# epoch 136 || Loss:0.0013
# timer:  0.0534 sec.
# -------------
# Epoch 138/600
# -------------
# -------------
# epoch 137 || Loss:0.0014
# timer:  0.0557 sec.
# -------------
# Epoch 139/600
# -------------
# -------------
# epoch 138 || Loss:0.0013
# timer:  0.0642 sec.
# -------------
# Epoch 140/600
# -------------
# -------------
# epoch 139 || Loss:0.0013
# timer:  0.0718 sec.
# -------------
# Epoch 141/600
# -------------
# -------------
# epoch 140 || Loss:0.0013
# timer:  0.0433 sec.
# -------------
# Epoch 142/600
# -------------
# -------------
# epoch 141 || Loss:0.0013
# timer:  0.0690 sec.
# -------------
# Epoch 143/600
# -------------
# -------------
# epoch 142 || Loss:0.0013
# timer:  0.0719 sec.
# -------------
# Epoch 144/600
# -------------
# -------------
# epoch 143 || Loss:0.0013
# timer:  0.0428 sec.
# -------------
# Epoch 145/600
# -------------
# -------------
# epoch 144 || Loss:0.0014
# timer:  0.0442 sec.
# -------------
# Epoch 146/600
# -------------
# -------------
# epoch 145 || Loss:0.0014
# timer:  0.0493 sec.
# -------------
# Epoch 147/600
# -------------
# -------------
# epoch 146 || Loss:0.0015
# timer:  0.0452 sec.
# -------------
# Epoch 148/600
# -------------
# -------------
# epoch 147 || Loss:0.0015
# timer:  0.0535 sec.
# -------------
# Epoch 149/600
# -------------
# -------------
# epoch 148 || Loss:0.0013
# timer:  0.0583 sec.
# -------------
# Epoch 150/600
# -------------
# -------------
# epoch 149 || Loss:0.0014
# timer:  0.0537 sec.
# -------------
# Epoch 151/600
# -------------
# -------------
# epoch 150 || Loss:0.0014
# timer:  0.0448 sec.
# -------------
# Epoch 152/600
# -------------
# -------------
# epoch 151 || Loss:0.0013
# timer:  0.0538 sec.
# -------------
# Epoch 153/600
# -------------
# -------------
# epoch 152 || Loss:0.0013
# timer:  0.0654 sec.
# -------------
# Epoch 154/600
# -------------
# -------------
# epoch 153 || Loss:0.0014
# timer:  0.0609 sec.
# -------------
# Epoch 155/600
# -------------
# -------------
# epoch 154 || Loss:0.0014
# timer:  0.0644 sec.
# -------------
# Epoch 156/600
# -------------
# -------------
# epoch 155 || Loss:0.0014
# timer:  0.0565 sec.
# -------------
# Epoch 157/600
# -------------
# -------------
# epoch 156 || Loss:0.0012
# timer:  0.0476 sec.
# -------------
# Epoch 158/600
# -------------
# -------------
# epoch 157 || Loss:0.0013
# timer:  0.0915 sec.
# -------------
# Epoch 159/600
# -------------
# -------------
# epoch 158 || Loss:0.0013
# timer:  0.0605 sec.
# -------------
# Epoch 160/600
# -------------
# -------------
# epoch 159 || Loss:0.0013
# timer:  0.0549 sec.
# -------------
# Epoch 161/600
# -------------
# -------------
# epoch 160 || Loss:0.0014
# timer:  0.0635 sec.
# -------------
# Epoch 162/600
# -------------
# -------------
# epoch 161 || Loss:0.0013
# timer:  0.0586 sec.
# -------------
# Epoch 163/600
# -------------
# -------------
# epoch 162 || Loss:0.0013
# timer:  0.0699 sec.
# -------------
# Epoch 164/600
# -------------
# -------------
# epoch 163 || Loss:0.0014
# timer:  0.0535 sec.
# -------------
# Epoch 165/600
# -------------
# -------------
# epoch 164 || Loss:0.0012
# timer:  0.0537 sec.
# -------------
# Epoch 166/600
# -------------
# -------------
# epoch 165 || Loss:0.0013
# timer:  0.0608 sec.
# -------------
# Epoch 167/600
# -------------
# -------------
# epoch 166 || Loss:0.0013
# timer:  0.0448 sec.
# -------------
# Epoch 168/600
# -------------
# -------------
# epoch 167 || Loss:0.0013
# timer:  0.0576 sec.
# -------------
# Epoch 169/600
# -------------
# -------------
# epoch 168 || Loss:0.0014
# timer:  0.1001 sec.
# -------------
# Epoch 170/600
# -------------
# -------------
# epoch 169 || Loss:0.0013
# timer:  0.0526 sec.
# -------------
# Epoch 171/600
# -------------
# -------------
# epoch 170 || Loss:0.0012
# timer:  0.0708 sec.
# -------------
# Epoch 172/600
# -------------
# -------------
# epoch 171 || Loss:0.0013
# timer:  0.0525 sec.
# -------------
# Epoch 173/600
# -------------
# -------------
# epoch 172 || Loss:0.0013
# timer:  0.0541 sec.
# -------------
# Epoch 174/600
# -------------
# -------------
# epoch 173 || Loss:0.0012
# timer:  0.0620 sec.
# -------------
# Epoch 175/600
# -------------
# -------------
# epoch 174 || Loss:0.0013
# timer:  0.0607 sec.
# -------------
# Epoch 176/600
# -------------
# -------------
# epoch 175 || Loss:0.0012
# timer:  0.0500 sec.
# -------------
# Epoch 177/600
# -------------
# -------------
# epoch 176 || Loss:0.0014
# timer:  0.0705 sec.
# -------------
# Epoch 178/600
# -------------
# -------------
# epoch 177 || Loss:0.0013
# timer:  0.0709 sec.
# -------------
# Epoch 179/600
# -------------
# -------------
# epoch 178 || Loss:0.0014
# timer:  0.0774 sec.
# -------------
# Epoch 180/600
# -------------
# -------------
# epoch 179 || Loss:0.0012
# timer:  0.0496 sec.
# -------------
# Epoch 181/600
# -------------
# -------------
# epoch 180 || Loss:0.0012
# timer:  0.0508 sec.
# -------------
# Epoch 182/600
# -------------
# -------------
# epoch 181 || Loss:0.0012
# timer:  0.0596 sec.
# -------------
# Epoch 183/600
# -------------
# -------------
# epoch 182 || Loss:0.0013
# timer:  0.0652 sec.
# -------------
# Epoch 184/600
# -------------
# -------------
# epoch 183 || Loss:0.0013
# timer:  0.0496 sec.
# -------------
# Epoch 185/600
# -------------
# -------------
# epoch 184 || Loss:0.0012
# timer:  0.0722 sec.
# -------------
# Epoch 186/600
# -------------
# -------------
# epoch 185 || Loss:0.0013
# timer:  0.0574 sec.
# -------------
# Epoch 187/600
# -------------
# -------------
# epoch 186 || Loss:0.0012
# timer:  0.0589 sec.
# -------------
# Epoch 188/600
# -------------
# -------------
# epoch 187 || Loss:0.0014
# timer:  0.0697 sec.
# -------------
# Epoch 189/600
# -------------
# -------------
# epoch 188 || Loss:0.0013
# timer:  0.0484 sec.
# -------------
# Epoch 190/600
# -------------
# -------------
# epoch 189 || Loss:0.0013
# timer:  0.0523 sec.
# -------------
# Epoch 191/600
# -------------
# -------------
# epoch 190 || Loss:0.0012
# timer:  0.0751 sec.
# -------------
# Epoch 192/600
# -------------
# -------------
# epoch 191 || Loss:0.0012
# timer:  0.0514 sec.
# -------------
# Epoch 193/600
# -------------
# -------------
# epoch 192 || Loss:0.0013
# timer:  0.0519 sec.
# -------------
# Epoch 194/600
# -------------
# -------------
# epoch 193 || Loss:0.0014
# timer:  0.0624 sec.
# -------------
# Epoch 195/600
# -------------
# -------------
# epoch 194 || Loss:0.0014
# timer:  0.0531 sec.
# -------------
# Epoch 196/600
# -------------
# -------------
# epoch 195 || Loss:0.0014
# timer:  0.0608 sec.
# -------------
# Epoch 197/600
# -------------
# -------------
# epoch 196 || Loss:0.0013
# timer:  0.0802 sec.
# -------------
# Epoch 198/600
# -------------
# -------------
# epoch 197 || Loss:0.0014
# timer:  0.0496 sec.
# -------------
# Epoch 199/600
# -------------
# -------------
# epoch 198 || Loss:0.0013
# timer:  0.0525 sec.
# -------------
# Epoch 200/600
# -------------
# -------------
# epoch 199 || Loss:0.0013
# timer:  0.0646 sec.
# -------------
# Epoch 201/600
# -------------
# -------------
# epoch 200 || Loss:0.0012
# timer:  0.0604 sec.
# -------------
# Epoch 202/600
# -------------
# -------------
# epoch 201 || Loss:0.0012
# timer:  0.0542 sec.
# -------------
# Epoch 203/600
# -------------
# -------------
# epoch 202 || Loss:0.0013
# timer:  0.0896 sec.
# -------------
# Epoch 204/600
# -------------
# -------------
# epoch 203 || Loss:0.0013
# timer:  0.0469 sec.
# -------------
# Epoch 205/600
# -------------
# -------------
# epoch 204 || Loss:0.0013
# timer:  0.0426 sec.
# -------------
# Epoch 206/600
# -------------
# -------------
# epoch 205 || Loss:0.0015
# timer:  0.0480 sec.
# -------------
# Epoch 207/600
# -------------
# -------------
# epoch 206 || Loss:0.0013
# timer:  0.0532 sec.
# -------------
# Epoch 208/600
# -------------
# -------------
# epoch 207 || Loss:0.0012
# timer:  0.0501 sec.
# -------------
# Epoch 209/600
# -------------
# -------------
# epoch 208 || Loss:0.0013
# timer:  0.0620 sec.
# -------------
# Epoch 210/600
# -------------
# -------------
# epoch 209 || Loss:0.0014
# timer:  0.0874 sec.
# -------------
# Epoch 211/600
# -------------
# -------------
# epoch 210 || Loss:0.0012
# timer:  0.0532 sec.
# -------------
# Epoch 212/600
# -------------
# -------------
# epoch 211 || Loss:0.0013
# timer:  0.0668 sec.
# -------------
# Epoch 213/600
# -------------
# -------------
# epoch 212 || Loss:0.0013
# timer:  0.0501 sec.
# -------------
# Epoch 214/600
# -------------
# -------------
# epoch 213 || Loss:0.0013
# timer:  0.0457 sec.
# -------------
# Epoch 215/600
# -------------
# -------------
# epoch 214 || Loss:0.0012
# timer:  0.1069 sec.
# -------------
# Epoch 216/600
# -------------
# -------------
# epoch 215 || Loss:0.0012
# timer:  0.0464 sec.
# -------------
# Epoch 217/600
# -------------
# -------------
# epoch 216 || Loss:0.0012
# timer:  0.0475 sec.
# -------------
# Epoch 218/600
# -------------
# -------------
# epoch 217 || Loss:0.0013
# timer:  0.0662 sec.
# -------------
# Epoch 219/600
# -------------
# -------------
# epoch 218 || Loss:0.0013
# timer:  0.0553 sec.
# -------------
# Epoch 220/600
# -------------
# -------------
# epoch 219 || Loss:0.0012
# timer:  0.0566 sec.
# -------------
# Epoch 221/600
# -------------
# -------------
# epoch 220 || Loss:0.0012
# timer:  0.0588 sec.
# -------------
# Epoch 222/600
# -------------
# -------------
# epoch 221 || Loss:0.0013
# timer:  0.0745 sec.
# -------------
# Epoch 223/600
# -------------
# -------------
# epoch 222 || Loss:0.0011
# timer:  0.0564 sec.
# -------------
# Epoch 224/600
# -------------
# -------------
# epoch 223 || Loss:0.0013
# timer:  0.0910 sec.
# -------------
# Epoch 225/600
# -------------
# -------------
# epoch 224 || Loss:0.0013
# timer:  0.0538 sec.
# -------------
# Epoch 226/600
# -------------
# -------------
# epoch 225 || Loss:0.0012
# timer:  0.0665 sec.
# -------------
# Epoch 227/600
# -------------
# -------------
# epoch 226 || Loss:0.0012
# timer:  0.0506 sec.
# -------------
# Epoch 228/600
# -------------
# -------------
# epoch 227 || Loss:0.0012
# timer:  0.0571 sec.
# -------------
# Epoch 229/600
# -------------
# -------------
# epoch 228 || Loss:0.0012
# timer:  0.0545 sec.
# -------------
# Epoch 230/600
# -------------
# -------------
# epoch 229 || Loss:0.0013
# timer:  0.0503 sec.
# -------------
# Epoch 231/600
# -------------
# -------------
# epoch 230 || Loss:0.0012
# timer:  0.0645 sec.
# -------------
# Epoch 232/600
# -------------
# -------------
# epoch 231 || Loss:0.0012
# timer:  0.0612 sec.
# -------------
# Epoch 233/600
# -------------
# -------------
# epoch 232 || Loss:0.0012
# timer:  0.0740 sec.
# -------------
# Epoch 234/600
# -------------
# -------------
# epoch 233 || Loss:0.0013
# timer:  0.0651 sec.
# -------------
# Epoch 235/600
# -------------
# -------------
# epoch 234 || Loss:0.0012
# timer:  0.0686 sec.
# -------------
# Epoch 236/600
# -------------
# -------------
# epoch 235 || Loss:0.0013
# timer:  0.0511 sec.
# -------------
# Epoch 237/600
# -------------
# -------------
# epoch 236 || Loss:0.0013
# timer:  0.0477 sec.
# -------------
# Epoch 238/600
# -------------
# -------------
# epoch 237 || Loss:0.0012
# timer:  0.0535 sec.
# -------------
# Epoch 239/600
# -------------
# -------------
# epoch 238 || Loss:0.0013
# timer:  0.0819 sec.
# -------------
# Epoch 240/600
# -------------
# -------------
# epoch 239 || Loss:0.0012
# timer:  0.0513 sec.
# -------------
# Epoch 241/600
# -------------
# -------------
# epoch 240 || Loss:0.0013
# timer:  0.0594 sec.
# -------------
# Epoch 242/600
# -------------
# -------------
# epoch 241 || Loss:0.0013
# timer:  0.0534 sec.
# -------------
# Epoch 243/600
# -------------
# -------------
# epoch 242 || Loss:0.0012
# timer:  0.0546 sec.
# -------------
# Epoch 244/600
# -------------
# -------------
# epoch 243 || Loss:0.0012
# timer:  0.0554 sec.
# -------------
# Epoch 245/600
# -------------
# -------------
# epoch 244 || Loss:0.0012
# timer:  0.0675 sec.
# -------------
# Epoch 246/600
# -------------
# -------------
# epoch 245 || Loss:0.0012
# timer:  0.0649 sec.
# -------------
# Epoch 247/600
# -------------
# -------------
# epoch 246 || Loss:0.0013
# timer:  0.0553 sec.
# -------------
# Epoch 248/600
# -------------
# -------------
# epoch 247 || Loss:0.0014
# timer:  0.0624 sec.
# -------------
# Epoch 249/600
# -------------
# -------------
# epoch 248 || Loss:0.0013
# timer:  0.0543 sec.
# -------------
# Epoch 250/600
# -------------
# -------------
# epoch 249 || Loss:0.0012
# timer:  0.0466 sec.
# -------------
# Epoch 251/600
# -------------
# -------------
# epoch 250 || Loss:0.0014
# timer:  0.0760 sec.
# -------------
# Epoch 252/600
# -------------
# -------------
# epoch 251 || Loss:0.0014
# timer:  0.0604 sec.
# -------------
# Epoch 253/600
# -------------
# -------------
# epoch 252 || Loss:0.0013
# timer:  0.0616 sec.
# -------------
# Epoch 254/600
# -------------
# -------------
# epoch 253 || Loss:0.0014
# timer:  0.0749 sec.
# -------------
# Epoch 255/600
# -------------
# -------------
# epoch 254 || Loss:0.0014
# timer:  0.0568 sec.
# -------------
# Epoch 256/600
# -------------
# -------------
# epoch 255 || Loss:0.0013
# timer:  0.0692 sec.
# -------------
# Epoch 257/600
# -------------
# -------------
# epoch 256 || Loss:0.0012
# timer:  0.0863 sec.
# -------------
# Epoch 258/600
# -------------
# -------------
# epoch 257 || Loss:0.0013
# timer:  0.0614 sec.
# -------------
# Epoch 259/600
# -------------
# -------------
# epoch 258 || Loss:0.0012
# timer:  0.0699 sec.
# -------------
# Epoch 260/600
# -------------
# -------------
# epoch 259 || Loss:0.0013
# timer:  0.0552 sec.
# -------------
# Epoch 261/600
# -------------
# -------------
# epoch 260 || Loss:0.0013
# timer:  0.0516 sec.
# -------------
# Epoch 262/600
# -------------
# -------------
# epoch 261 || Loss:0.0012
# timer:  0.0594 sec.
# -------------
# Epoch 263/600
# -------------
# -------------
# epoch 262 || Loss:0.0013
# timer:  0.0572 sec.
# -------------
# Epoch 264/600
# -------------
# -------------
# epoch 263 || Loss:0.0013
# timer:  0.0499 sec.
# -------------
# Epoch 265/600
# -------------
# -------------
# epoch 264 || Loss:0.0013
# timer:  0.0752 sec.
# -------------
# Epoch 266/600
# -------------
# -------------
# epoch 265 || Loss:0.0012
# timer:  0.0567 sec.
# -------------
# Epoch 267/600
# -------------
# -------------
# epoch 266 || Loss:0.0013
# timer:  0.0520 sec.
# -------------
# Epoch 268/600
# -------------
# -------------
# epoch 267 || Loss:0.0013
# timer:  0.0633 sec.
# -------------
# Epoch 269/600
# -------------
# -------------
# epoch 268 || Loss:0.0014
# timer:  0.0593 sec.
# -------------
# Epoch 270/600
# -------------
# -------------
# epoch 269 || Loss:0.0012
# timer:  0.0626 sec.
# -------------
# Epoch 271/600
# -------------
# -------------
# epoch 270 || Loss:0.0012
# timer:  0.1041 sec.
# -------------
# Epoch 272/600
# -------------
# -------------
# epoch 271 || Loss:0.0012
# timer:  0.0651 sec.
# -------------
# Epoch 273/600
# -------------
# -------------
# epoch 272 || Loss:0.0012
# timer:  0.0718 sec.
# -------------
# Epoch 274/600
# -------------
# -------------
# epoch 273 || Loss:0.0012
# timer:  0.0534 sec.
# -------------
# Epoch 275/600
# -------------
# -------------
# epoch 274 || Loss:0.0012
# timer:  0.0581 sec.
# -------------
# Epoch 276/600
# -------------
# -------------
# epoch 275 || Loss:0.0012
# timer:  0.0752 sec.
# -------------
# Epoch 277/600
# -------------
# -------------
# epoch 276 || Loss:0.0012
# timer:  0.0643 sec.
# -------------
# Epoch 278/600
# -------------
# -------------
# epoch 277 || Loss:0.0012
# timer:  0.0592 sec.
# -------------
# Epoch 279/600
# -------------
# -------------
# epoch 278 || Loss:0.0012
# timer:  0.0602 sec.
# -------------
# Epoch 280/600
# -------------
# -------------
# epoch 279 || Loss:0.0012
# timer:  0.0632 sec.
# -------------
# Epoch 281/600
# -------------
# -------------
# epoch 280 || Loss:0.0013
# timer:  0.0606 sec.
# -------------
# Epoch 282/600
# -------------
# -------------
# epoch 281 || Loss:0.0011
# timer:  0.0725 sec.
# -------------
# Epoch 283/600
# -------------
# -------------
# epoch 282 || Loss:0.0013
# timer:  0.0818 sec.
# -------------
# Epoch 284/600
# -------------
# -------------
# epoch 283 || Loss:0.0013
# timer:  0.0670 sec.
# -------------
# Epoch 285/600
# -------------
# -------------
# epoch 284 || Loss:0.0014
# timer:  0.0560 sec.
# -------------
# Epoch 286/600
# -------------
# -------------
# epoch 285 || Loss:0.0013
# timer:  0.0453 sec.
# -------------
# Epoch 287/600
# -------------
# -------------
# epoch 286 || Loss:0.0012
# timer:  0.0504 sec.
# -------------
# Epoch 288/600
# -------------
# -------------
# epoch 287 || Loss:0.0012
# timer:  0.0628 sec.
# -------------
# Epoch 289/600
# -------------
# -------------
# epoch 288 || Loss:0.0011
# timer:  0.0673 sec.
# -------------
# Epoch 290/600
# -------------
# -------------
# epoch 289 || Loss:0.0013
# timer:  0.0584 sec.
# -------------
# Epoch 291/600
# -------------
# -------------
# epoch 290 || Loss:0.0012
# timer:  0.0666 sec.
# -------------
# Epoch 292/600
# -------------
# -------------
# epoch 291 || Loss:0.0012
# timer:  0.0615 sec.
# -------------
# Epoch 293/600
# -------------
# -------------
# epoch 292 || Loss:0.0012
# timer:  0.0635 sec.
# -------------
# Epoch 294/600
# -------------
# -------------
# epoch 293 || Loss:0.0011
# timer:  0.1058 sec.
# -------------
# Epoch 295/600
# -------------
# -------------
# epoch 294 || Loss:0.0012
# timer:  0.0555 sec.
# -------------
# Epoch 296/600
# -------------
# -------------
# epoch 295 || Loss:0.0012
# timer:  0.0700 sec.
# -------------
# Epoch 297/600
# -------------
# -------------
# epoch 296 || Loss:0.0013
# timer:  0.0467 sec.
# -------------
# Epoch 298/600
# -------------
# -------------
# epoch 297 || Loss:0.0012
# timer:  0.0495 sec.
# -------------
# Epoch 299/600
# -------------
# -------------
# epoch 298 || Loss:0.0012
# timer:  0.0601 sec.
# -------------
# Epoch 300/600
# -------------
# -------------
# epoch 299 || Loss:0.0013
# timer:  0.0610 sec.
# -------------
# Epoch 301/600
# -------------
# -------------
# epoch 300 || Loss:0.0012
# timer:  0.0627 sec.
# -------------
# Epoch 302/600
# -------------
# -------------
# epoch 301 || Loss:0.0014
# timer:  0.0584 sec.
# -------------
# Epoch 303/600
# -------------
# -------------
# epoch 302 || Loss:0.0014
# timer:  0.0540 sec.
# -------------
# Epoch 304/600
# -------------
# -------------
# epoch 303 || Loss:0.0013
# timer:  0.0542 sec.
# -------------
# Epoch 305/600
# -------------
# -------------
# epoch 304 || Loss:0.0013
# timer:  0.0573 sec.
# -------------
# Epoch 306/600
# -------------
# -------------
# epoch 305 || Loss:0.0013
# timer:  0.0572 sec.
# -------------
# Epoch 307/600
# -------------
# -------------
# epoch 306 || Loss:0.0014
# timer:  0.0592 sec.
# -------------
# Epoch 308/600
# -------------
# -------------
# epoch 307 || Loss:0.0013
# timer:  0.0658 sec.
# -------------
# Epoch 309/600
# -------------
# -------------
# epoch 308 || Loss:0.0012
# timer:  0.0630 sec.
# -------------
# Epoch 310/600
# -------------
# -------------
# epoch 309 || Loss:0.0012
# timer:  0.0624 sec.
# -------------
# Epoch 311/600
# -------------
# -------------
# epoch 310 || Loss:0.0012
# timer:  0.0470 sec.
# -------------
# Epoch 312/600
# -------------
# -------------
# epoch 311 || Loss:0.0012
# timer:  0.0614 sec.
# -------------
# Epoch 313/600
# -------------
# -------------
# epoch 312 || Loss:0.0013
# timer:  0.0621 sec.
# -------------
# Epoch 314/600
# -------------
# -------------
# epoch 313 || Loss:0.0012
# timer:  0.0648 sec.
# -------------
# Epoch 315/600
# -------------
# -------------
# epoch 314 || Loss:0.0012
# timer:  0.0509 sec.
# -------------
# Epoch 316/600
# -------------
# -------------
# epoch 315 || Loss:0.0014
# timer:  0.0694 sec.
# -------------
# Epoch 317/600
# -------------
# -------------
# epoch 316 || Loss:0.0011
# timer:  0.0517 sec.
# -------------
# Epoch 318/600
# -------------
# -------------
# epoch 317 || Loss:0.0013
# timer:  0.0687 sec.
# -------------
# Epoch 319/600
# -------------
# -------------
# epoch 318 || Loss:0.0012
# timer:  0.0494 sec.
# -------------
# Epoch 320/600
# -------------
# -------------
# epoch 319 || Loss:0.0013
# timer:  0.0586 sec.
# -------------
# Epoch 321/600
# -------------
# -------------
# epoch 320 || Loss:0.0013
# timer:  0.0630 sec.
# -------------
# Epoch 322/600
# -------------
# -------------
# epoch 321 || Loss:0.0013
# timer:  0.0726 sec.
# -------------
# Epoch 323/600
# -------------
# -------------
# epoch 322 || Loss:0.0012
# timer:  0.0564 sec.
# -------------
# Epoch 324/600
# -------------
# -------------
# epoch 323 || Loss:0.0013
# timer:  0.0609 sec.
# -------------
# Epoch 325/600
# -------------
# -------------
# epoch 324 || Loss:0.0013
# timer:  0.0599 sec.
# -------------
# Epoch 326/600
# -------------
# -------------
# epoch 325 || Loss:0.0013
# timer:  0.0533 sec.
# -------------
# Epoch 327/600
# -------------
# -------------
# epoch 326 || Loss:0.0012
# timer:  0.0697 sec.
# -------------
# Epoch 328/600
# -------------
# -------------
# epoch 327 || Loss:0.0012
# timer:  0.0636 sec.
# -------------
# Epoch 329/600
# -------------
# -------------
# epoch 328 || Loss:0.0011
# timer:  0.0479 sec.
# -------------
# Epoch 330/600
# -------------
# -------------
# epoch 329 || Loss:0.0012
# timer:  0.0574 sec.
# -------------
# Epoch 331/600
# -------------
# -------------
# epoch 330 || Loss:0.0012
# timer:  0.0617 sec.
# -------------
# Epoch 332/600
# -------------
# -------------
# epoch 331 || Loss:0.0012
# timer:  0.0555 sec.
# -------------
# Epoch 333/600
# -------------
# -------------
# epoch 332 || Loss:0.0012
# timer:  0.0558 sec.
# -------------
# Epoch 334/600
# -------------
# -------------
# epoch 333 || Loss:0.0011
# timer:  0.0600 sec.
# -------------
# Epoch 335/600
# -------------
# -------------
# epoch 334 || Loss:0.0011
# timer:  0.0577 sec.
# -------------
# Epoch 336/600
# -------------
# -------------
# epoch 335 || Loss:0.0012
# timer:  0.0626 sec.
# -------------
# Epoch 337/600
# -------------
# -------------
# epoch 336 || Loss:0.0012
# timer:  0.0712 sec.
# -------------
# Epoch 338/600
# -------------
# -------------
# epoch 337 || Loss:0.0013
# timer:  0.0653 sec.
# -------------
# Epoch 339/600
# -------------
# -------------
# epoch 338 || Loss:0.0012
# timer:  0.0578 sec.
# -------------
# Epoch 340/600
# -------------
# -------------
# epoch 339 || Loss:0.0013
# timer:  0.0690 sec.
# -------------
# Epoch 341/600
# -------------
# -------------
# epoch 340 || Loss:0.0013
# timer:  0.0605 sec.
# -------------
# Epoch 342/600
# -------------
# -------------
# epoch 341 || Loss:0.0012
# timer:  0.0551 sec.
# -------------
# Epoch 343/600
# -------------
# -------------
# epoch 342 || Loss:0.0012
# timer:  0.0716 sec.
# -------------
# Epoch 344/600
# -------------
# -------------
# epoch 343 || Loss:0.0013
# timer:  0.0494 sec.
# -------------
# Epoch 345/600
# -------------
# -------------
# epoch 344 || Loss:0.0012
# timer:  0.0730 sec.
# -------------
# Epoch 346/600
# -------------
# -------------
# epoch 345 || Loss:0.0013
# timer:  0.0586 sec.
# -------------
# Epoch 347/600
# -------------
# -------------
# epoch 346 || Loss:0.0012
# timer:  0.0672 sec.
# -------------
# Epoch 348/600
# -------------
# -------------
# epoch 347 || Loss:0.0012
# timer:  0.0544 sec.
# -------------
# Epoch 349/600
# -------------
# -------------
# epoch 348 || Loss:0.0012
# timer:  0.0557 sec.
# -------------
# Epoch 350/600
# -------------
# -------------
# epoch 349 || Loss:0.0012
# timer:  0.0519 sec.
# -------------
# Epoch 351/600
# -------------
# -------------
# epoch 350 || Loss:0.0011
# timer:  0.0535 sec.
# -------------
# Epoch 352/600
# -------------
# -------------
# epoch 351 || Loss:0.0012
# timer:  0.0701 sec.
# -------------
# Epoch 353/600
# -------------
# -------------
# epoch 352 || Loss:0.0012
# timer:  0.0652 sec.
# -------------
# Epoch 354/600
# -------------
# -------------
# epoch 353 || Loss:0.0011
# timer:  0.0673 sec.
# -------------
# Epoch 355/600
# -------------
# -------------
# epoch 354 || Loss:0.0012
# timer:  0.0515 sec.
# -------------
# Epoch 356/600
# -------------
# -------------
# epoch 355 || Loss:0.0011
# timer:  0.0673 sec.
# -------------
# Epoch 357/600
# -------------
# -------------
# epoch 356 || Loss:0.0012
# timer:  0.0662 sec.
# -------------
# Epoch 358/600
# -------------
# -------------
# epoch 357 || Loss:0.0011
# timer:  0.0629 sec.
# -------------
# Epoch 359/600
# -------------
# -------------
# epoch 358 || Loss:0.0012
# timer:  0.0573 sec.
# -------------
# Epoch 360/600
# -------------
# -------------
# epoch 359 || Loss:0.0013
# timer:  0.0542 sec.
# -------------
# Epoch 361/600
# -------------
# -------------
# epoch 360 || Loss:0.0011
# timer:  0.0686 sec.
# -------------
# Epoch 362/600
# -------------
# -------------
# epoch 361 || Loss:0.0013
# timer:  0.0540 sec.
# -------------
# Epoch 363/600
# -------------
# -------------
# epoch 362 || Loss:0.0012
# timer:  0.0963 sec.
# -------------
# Epoch 364/600
# -------------
# -------------
# epoch 363 || Loss:0.0012
# timer:  0.0635 sec.
# -------------
# Epoch 365/600
# -------------
# -------------
# epoch 364 || Loss:0.0012
# timer:  0.0575 sec.
# -------------
# Epoch 366/600
# -------------
# -------------
# epoch 365 || Loss:0.0012
# timer:  0.0520 sec.
# -------------
# Epoch 367/600
# -------------
# -------------
# epoch 366 || Loss:0.0012
# timer:  0.0617 sec.
# -------------
# Epoch 368/600
# -------------
# -------------
# epoch 367 || Loss:0.0012
# timer:  0.0560 sec.
# -------------
# Epoch 369/600
# -------------
# -------------
# epoch 368 || Loss:0.0012
# timer:  0.0633 sec.
# -------------
# Epoch 370/600
# -------------
# -------------
# epoch 369 || Loss:0.0012
# timer:  0.0776 sec.
# -------------
# Epoch 371/600
# -------------
# -------------
# epoch 370 || Loss:0.0013
# timer:  0.0597 sec.
# -------------
# Epoch 372/600
# -------------
# -------------
# epoch 371 || Loss:0.0012
# timer:  0.0653 sec.
# -------------
# Epoch 373/600
# -------------
# -------------
# epoch 372 || Loss:0.0012
# timer:  0.0690 sec.
# -------------
# Epoch 374/600
# -------------
# -------------
# epoch 373 || Loss:0.0012
# timer:  0.0543 sec.
# -------------
# Epoch 375/600
# -------------
# -------------
# epoch 374 || Loss:0.0011
# timer:  0.0612 sec.
# -------------
# Epoch 376/600
# -------------
# -------------
# epoch 375 || Loss:0.0013
# timer:  0.0627 sec.
# -------------
# Epoch 377/600
# -------------
# -------------
# epoch 376 || Loss:0.0013
# timer:  0.0435 sec.
# -------------
# Epoch 378/600
# -------------
# -------------
# epoch 377 || Loss:0.0011
# timer:  0.0639 sec.
# -------------
# Epoch 379/600
# -------------
# -------------
# epoch 378 || Loss:0.0012
# timer:  0.0548 sec.
# -------------
# Epoch 380/600
# -------------
# -------------
# epoch 379 || Loss:0.0012
# timer:  0.0588 sec.
# -------------
# Epoch 381/600
# -------------
# -------------
# epoch 380 || Loss:0.0013
# timer:  0.0620 sec.
# -------------
# Epoch 382/600
# -------------
# -------------
# epoch 381 || Loss:0.0011
# timer:  0.0866 sec.
# -------------
# Epoch 383/600
# -------------
# -------------
# epoch 382 || Loss:0.0014
# timer:  0.0720 sec.
# -------------
# Epoch 384/600
# -------------
# -------------
# epoch 383 || Loss:0.0012
# timer:  0.0936 sec.
# -------------
# Epoch 385/600
# -------------
# -------------
# epoch 384 || Loss:0.0013
# timer:  0.0600 sec.
# -------------
# Epoch 386/600
# -------------
# -------------
# epoch 385 || Loss:0.0012
# timer:  0.0675 sec.
# -------------
# Epoch 387/600
# -------------
# -------------
# epoch 386 || Loss:0.0011
# timer:  0.0552 sec.
# -------------
# Epoch 388/600
# -------------
# -------------
# epoch 387 || Loss:0.0012
# timer:  0.0541 sec.
# -------------
# Epoch 389/600
# -------------
# -------------
# epoch 388 || Loss:0.0012
# timer:  0.0548 sec.
# -------------
# Epoch 390/600
# -------------
# -------------
# epoch 389 || Loss:0.0011
# timer:  0.0609 sec.
# -------------
# Epoch 391/600
# -------------
# -------------
# epoch 390 || Loss:0.0012
# timer:  0.0626 sec.
# -------------
# Epoch 392/600
# -------------
# -------------
# epoch 391 || Loss:0.0012
# timer:  0.0824 sec.
# -------------
# Epoch 393/600
# -------------
# -------------
# epoch 392 || Loss:0.0011
# timer:  0.0780 sec.
# -------------
# Epoch 394/600
# -------------
# -------------
# epoch 393 || Loss:0.0011
# timer:  0.0600 sec.
# -------------
# Epoch 395/600
# -------------
# -------------
# epoch 394 || Loss:0.0012
# timer:  0.0579 sec.
# -------------
# Epoch 396/600
# -------------
# -------------
# epoch 395 || Loss:0.0013
# timer:  0.0456 sec.
# -------------
# Epoch 397/600
# -------------
# -------------
# epoch 396 || Loss:0.0012
# timer:  0.0487 sec.
# -------------
# Epoch 398/600
# -------------
# -------------
# epoch 397 || Loss:0.0011
# timer:  0.0482 sec.
# -------------
# Epoch 399/600
# -------------
# -------------
# epoch 398 || Loss:0.0012
# timer:  0.0454 sec.
# -------------
# Epoch 400/600
# -------------
# -------------
# epoch 399 || Loss:0.0011
# timer:  0.0638 sec.
# -------------
# Epoch 401/600
# -------------
# -------------
# epoch 400 || Loss:0.0012
# timer:  0.0566 sec.
# -------------
# Epoch 402/600
# -------------
# -------------
# epoch 401 || Loss:0.0012
# timer:  0.0608 sec.
# -------------
# Epoch 403/600
# -------------
# -------------
# epoch 402 || Loss:0.0012
# timer:  0.0736 sec.
# -------------
# Epoch 404/600
# -------------
# -------------
# epoch 403 || Loss:0.0013
# timer:  0.0597 sec.
# -------------
# Epoch 405/600
# -------------
# -------------
# epoch 404 || Loss:0.0011
# timer:  0.0613 sec.
# -------------
# Epoch 406/600
# -------------
# -------------
# epoch 405 || Loss:0.0012
# timer:  0.0511 sec.
# -------------
# Epoch 407/600
# -------------
# -------------
# epoch 406 || Loss:0.0012
# timer:  0.0494 sec.
# -------------
# Epoch 408/600
# -------------
# -------------
# epoch 407 || Loss:0.0012
# timer:  0.0647 sec.
# -------------
# Epoch 409/600
# -------------
# -------------
# epoch 408 || Loss:0.0012
# timer:  0.0687 sec.
# -------------
# Epoch 410/600
# -------------
# -------------
# epoch 409 || Loss:0.0012
# timer:  0.0416 sec.
# -------------
# Epoch 411/600
# -------------
# -------------
# epoch 410 || Loss:0.0011
# timer:  0.0384 sec.
# -------------
# Epoch 412/600
# -------------
# -------------
# epoch 411 || Loss:0.0012
# timer:  0.0412 sec.
# -------------
# Epoch 413/600
# -------------
# -------------
# epoch 412 || Loss:0.0011
# timer:  0.0546 sec.
# -------------
# Epoch 414/600
# -------------
# -------------
# epoch 413 || Loss:0.0012
# timer:  0.0580 sec.
# -------------
# Epoch 415/600
# -------------
# -------------
# epoch 414 || Loss:0.0012
# timer:  0.0798 sec.
# -------------
# Epoch 416/600
# -------------
# -------------
# epoch 415 || Loss:0.0012
# timer:  0.0554 sec.
# -------------
# Epoch 417/600
# -------------
# -------------
# epoch 416 || Loss:0.0011
# timer:  0.0612 sec.
# -------------
# Epoch 418/600
# -------------
# -------------
# epoch 417 || Loss:0.0011
# timer:  0.0547 sec.
# -------------
# Epoch 419/600
# -------------
# -------------
# epoch 418 || Loss:0.0011
# timer:  0.0767 sec.
# -------------
# Epoch 420/600
# -------------
# -------------
# epoch 419 || Loss:0.0013
# timer:  0.0608 sec.
# -------------
# Epoch 421/600
# -------------
# -------------
# epoch 420 || Loss:0.0011
# timer:  0.0491 sec.
# -------------
# Epoch 422/600
# -------------
# -------------
# epoch 421 || Loss:0.0012
# timer:  0.0553 sec.
# -------------
# Epoch 423/600
# -------------
# -------------
# epoch 422 || Loss:0.0011
# timer:  0.0498 sec.
# -------------
# Epoch 424/600
# -------------
# -------------
# epoch 423 || Loss:0.0011
# timer:  0.0428 sec.
# -------------
# Epoch 425/600
# -------------
# -------------
# epoch 424 || Loss:0.0012
# timer:  0.0384 sec.
# -------------
# Epoch 426/600
# -------------
# -------------
# epoch 425 || Loss:0.0012
# timer:  0.0516 sec.
# -------------
# Epoch 427/600
# -------------
# -------------
# epoch 426 || Loss:0.0013
# timer:  0.0679 sec.
# -------------
# Epoch 428/600
# -------------
# -------------
# epoch 427 || Loss:0.0011
# timer:  0.0818 sec.
# -------------
# Epoch 429/600
# -------------
# -------------
# epoch 428 || Loss:0.0012
# timer:  0.0516 sec.
# -------------
# Epoch 430/600
# -------------
# -------------
# epoch 429 || Loss:0.0011
# timer:  0.0506 sec.
# -------------
# Epoch 431/600
# -------------
# -------------
# epoch 430 || Loss:0.0012
# timer:  0.0576 sec.
# -------------
# Epoch 432/600
# -------------
# -------------
# epoch 431 || Loss:0.0012
# timer:  0.0588 sec.
# -------------
# Epoch 433/600
# -------------
# -------------
# epoch 432 || Loss:0.0012
# timer:  0.0472 sec.
# -------------
# Epoch 434/600
# -------------
# -------------
# epoch 433 || Loss:0.0011
# timer:  0.0593 sec.
# -------------
# Epoch 435/600
# -------------
# -------------
# epoch 434 || Loss:0.0012
# timer:  0.0803 sec.
# -------------
# Epoch 436/600
# -------------
# -------------
# epoch 435 || Loss:0.0012
# timer:  0.0606 sec.
# -------------
# Epoch 437/600
# -------------
# -------------
# epoch 436 || Loss:0.0011
# timer:  0.0624 sec.
# -------------
# Epoch 438/600
# -------------
# -------------
# epoch 437 || Loss:0.0012
# timer:  0.0457 sec.
# -------------
# Epoch 439/600
# -------------
# -------------
# epoch 438 || Loss:0.0012
# timer:  0.0716 sec.
# -------------
# Epoch 440/600
# -------------
# -------------
# epoch 439 || Loss:0.0011
# timer:  0.0703 sec.
# -------------
# Epoch 441/600
# -------------
# -------------
# epoch 440 || Loss:0.0013
# timer:  0.0850 sec.
# -------------
# Epoch 442/600
# -------------
# -------------
# epoch 441 || Loss:0.0012
# timer:  0.0549 sec.
# -------------
# Epoch 443/600
# -------------
# -------------
# epoch 442 || Loss:0.0012
# timer:  0.0690 sec.
# -------------
# Epoch 444/600
# -------------
# -------------
# epoch 443 || Loss:0.0011
# timer:  0.0519 sec.
# -------------
# Epoch 445/600
# -------------
# -------------
# epoch 444 || Loss:0.0011
# timer:  0.0616 sec.
# -------------
# Epoch 446/600
# -------------
# -------------
# epoch 445 || Loss:0.0012
# timer:  0.0762 sec.
# -------------
# Epoch 447/600
# -------------
# -------------
# epoch 446 || Loss:0.0013
# timer:  0.0833 sec.
# -------------
# Epoch 448/600
# -------------
# -------------
# epoch 447 || Loss:0.0012
# timer:  0.0696 sec.
# -------------
# Epoch 449/600
# -------------
# -------------
# epoch 448 || Loss:0.0012
# timer:  0.0577 sec.
# -------------
# Epoch 450/600
# -------------
# -------------
# epoch 449 || Loss:0.0013
# timer:  0.0503 sec.
# -------------
# Epoch 451/600
# -------------
# -------------
# epoch 450 || Loss:0.0011
# timer:  0.0497 sec.
# -------------
# Epoch 452/600
# -------------
# -------------
# epoch 451 || Loss:0.0012
# timer:  0.0453 sec.
# -------------
# Epoch 453/600
# -------------
# -------------
# epoch 452 || Loss:0.0012
# timer:  0.0496 sec.
# -------------
# Epoch 454/600
# -------------
# -------------
# epoch 453 || Loss:0.0011
# timer:  0.0660 sec.
# -------------
# Epoch 455/600
# -------------
# -------------
# epoch 454 || Loss:0.0011
# timer:  0.0647 sec.
# -------------
# Epoch 456/600
# -------------
# -------------
# epoch 455 || Loss:0.0011
# timer:  0.0569 sec.
# -------------
# Epoch 457/600
# -------------
# -------------
# epoch 456 || Loss:0.0012
# timer:  0.0559 sec.
# -------------
# Epoch 458/600
# -------------
# -------------
# epoch 457 || Loss:0.0011
# timer:  0.0619 sec.
# -------------
# Epoch 459/600
# -------------
# -------------
# epoch 458 || Loss:0.0011
# timer:  0.0687 sec.
# -------------
# Epoch 460/600
# -------------
# -------------
# epoch 459 || Loss:0.0011
# timer:  0.0709 sec.
# -------------
# Epoch 461/600
# -------------
# -------------
# epoch 460 || Loss:0.0013
# timer:  0.1013 sec.
# -------------
# Epoch 462/600
# -------------
# -------------
# epoch 461 || Loss:0.0012
# timer:  0.0642 sec.
# -------------
# Epoch 463/600
# -------------
# -------------
# epoch 462 || Loss:0.0013
# timer:  0.0470 sec.
# -------------
# Epoch 464/600
# -------------
# -------------
# epoch 463 || Loss:0.0012
# timer:  0.0505 sec.
# -------------
# Epoch 465/600
# -------------
# -------------
# epoch 464 || Loss:0.0012
# timer:  0.0458 sec.
# -------------
# Epoch 466/600
# -------------
# -------------
# epoch 465 || Loss:0.0013
# timer:  0.0537 sec.
# -------------
# Epoch 467/600
# -------------
# -------------
# epoch 466 || Loss:0.0011
# timer:  0.0529 sec.
# -------------
# Epoch 468/600
# -------------
# -------------
# epoch 467 || Loss:0.0011
# timer:  0.0613 sec.
# -------------
# Epoch 469/600
# -------------
# -------------
# epoch 468 || Loss:0.0012
# timer:  0.0595 sec.
# -------------
# Epoch 470/600
# -------------
# -------------
# epoch 469 || Loss:0.0011
# timer:  0.0573 sec.
# -------------
# Epoch 471/600
# -------------
# -------------
# epoch 470 || Loss:0.0012
# timer:  0.0783 sec.
# -------------
# Epoch 472/600
# -------------
# -------------
# epoch 471 || Loss:0.0011
# timer:  0.0662 sec.
# -------------
# Epoch 473/600
# -------------
# -------------
# epoch 472 || Loss:0.0011
# timer:  0.0564 sec.
# -------------
# Epoch 474/600
# -------------
# -------------
# epoch 473 || Loss:0.0011
# timer:  0.0813 sec.
# -------------
# Epoch 475/600
# -------------
# -------------
# epoch 474 || Loss:0.0011
# timer:  0.0574 sec.
# -------------
# Epoch 476/600
# -------------
# -------------
# epoch 475 || Loss:0.0011
# timer:  0.0533 sec.
# -------------
# Epoch 477/600
# -------------
# -------------
# epoch 476 || Loss:0.0012
# timer:  0.0537 sec.
# -------------
# Epoch 478/600
# -------------
# -------------
# epoch 477 || Loss:0.0011
# timer:  0.0504 sec.
# -------------
# Epoch 479/600
# -------------
# -------------
# epoch 478 || Loss:0.0011
# timer:  0.0552 sec.
# -------------
# Epoch 480/600
# -------------
# -------------
# epoch 479 || Loss:0.0012
# timer:  0.0563 sec.
# -------------
# Epoch 481/600
# -------------
# -------------
# epoch 480 || Loss:0.0011
# timer:  0.0469 sec.
# -------------
# Epoch 482/600
# -------------
# -------------
# epoch 481 || Loss:0.0011
# timer:  0.0825 sec.
# -------------
# Epoch 483/600
# -------------
# -------------
# epoch 482 || Loss:0.0011
# timer:  0.0440 sec.
# -------------
# Epoch 484/600
# -------------
# -------------
# epoch 483 || Loss:0.0011
# timer:  0.0612 sec.
# -------------
# Epoch 485/600
# -------------
# -------------
# epoch 484 || Loss:0.0012
# timer:  0.0496 sec.
# -------------
# Epoch 486/600
# -------------
# -------------
# epoch 485 || Loss:0.0013
# timer:  0.0600 sec.
# -------------
# Epoch 487/600
# -------------
# -------------
# epoch 486 || Loss:0.0011
# timer:  0.0659 sec.
# -------------
# Epoch 488/600
# -------------
# -------------
# epoch 487 || Loss:0.0013
# timer:  0.0550 sec.
# -------------
# Epoch 489/600
# -------------
# -------------
# epoch 488 || Loss:0.0012
# timer:  0.0690 sec.
# -------------
# Epoch 490/600
# -------------
# -------------
# epoch 489 || Loss:0.0011
# timer:  0.0455 sec.
# -------------
# Epoch 491/600
# -------------
# -------------
# epoch 490 || Loss:0.0012
# timer:  0.0393 sec.
# -------------
# Epoch 492/600
# -------------
# -------------
# epoch 491 || Loss:0.0012
# timer:  0.0544 sec.
# -------------
# Epoch 493/600
# -------------
# -------------
# epoch 492 || Loss:0.0011
# timer:  0.0547 sec.
# -------------
# Epoch 494/600
# -------------
# -------------
# epoch 493 || Loss:0.0011
# timer:  0.0510 sec.
# -------------
# Epoch 495/600
# -------------
# -------------
# epoch 494 || Loss:0.0012
# timer:  0.0676 sec.
# -------------
# Epoch 496/600
# -------------
# -------------
# epoch 495 || Loss:0.0012
# timer:  0.0585 sec.
# -------------
# Epoch 497/600
# -------------
# -------------
# epoch 496 || Loss:0.0011
# timer:  0.0574 sec.
# -------------
# Epoch 498/600
# -------------
# -------------
# epoch 497 || Loss:0.0011
# timer:  0.0476 sec.
# -------------
# Epoch 499/600
# -------------
# -------------
# epoch 498 || Loss:0.0012
# timer:  0.0544 sec.
# -------------
# Epoch 500/600
# -------------
# -------------
# epoch 499 || Loss:0.0011
# timer:  0.0609 sec.
# -------------
# Epoch 501/600
# -------------
# -------------
# epoch 500 || Loss:0.0011
# timer:  0.0704 sec.
# -------------
# Epoch 502/600
# -------------
# -------------
# epoch 501 || Loss:0.0012
# timer:  0.0531 sec.
# -------------
# Epoch 503/600
# -------------
# -------------
# epoch 502 || Loss:0.0012
# timer:  0.0469 sec.
# -------------
# Epoch 504/600
# -------------
# -------------
# epoch 503 || Loss:0.0011
# timer:  0.0419 sec.
# -------------
# Epoch 505/600
# -------------
# -------------
# epoch 504 || Loss:0.0012
# timer:  0.0461 sec.
# -------------
# Epoch 506/600
# -------------
# -------------
# epoch 505 || Loss:0.0012
# timer:  0.0600 sec.
# -------------
# Epoch 507/600
# -------------
# -------------
# epoch 506 || Loss:0.0012
# timer:  0.0555 sec.
# -------------
# Epoch 508/600
# -------------
# -------------
# epoch 507 || Loss:0.0012
# timer:  0.0502 sec.
# -------------
# Epoch 509/600
# -------------
# -------------
# epoch 508 || Loss:0.0011
# timer:  0.0546 sec.
# -------------
# Epoch 510/600
# -------------
# -------------
# epoch 509 || Loss:0.0011
# timer:  0.0566 sec.
# -------------
# Epoch 511/600
# -------------
# -------------
# epoch 510 || Loss:0.0011
# timer:  0.0672 sec.
# -------------
# Epoch 512/600
# -------------
# -------------
# epoch 511 || Loss:0.0012
# timer:  0.0493 sec.
# -------------
# Epoch 513/600
# -------------
# -------------
# epoch 512 || Loss:0.0011
# timer:  0.0616 sec.
# -------------
# Epoch 514/600
# -------------
# -------------
# epoch 513 || Loss:0.0013
# timer:  0.0612 sec.
# -------------
# Epoch 515/600
# -------------
# -------------
# epoch 514 || Loss:0.0011
# timer:  0.0695 sec.
# -------------
# Epoch 516/600
# -------------
# -------------
# epoch 515 || Loss:0.0013
# timer:  0.0493 sec.
# -------------
# Epoch 517/600
# -------------
# -------------
# epoch 516 || Loss:0.0012
# timer:  0.0528 sec.
# -------------
# Epoch 518/600
# -------------
# -------------
# epoch 517 || Loss:0.0012
# timer:  0.0547 sec.
# -------------
# Epoch 519/600
# -------------
# -------------
# epoch 518 || Loss:0.0013
# timer:  0.0542 sec.
# -------------
# Epoch 520/600
# -------------
# -------------
# epoch 519 || Loss:0.0012
# timer:  0.0502 sec.
# -------------
# Epoch 521/600
# -------------
# -------------
# epoch 520 || Loss:0.0013
# timer:  0.0589 sec.
# -------------
# Epoch 522/600
# -------------
# -------------
# epoch 521 || Loss:0.0011
# timer:  0.0678 sec.
# -------------
# Epoch 523/600
# -------------
# -------------
# epoch 522 || Loss:0.0012
# timer:  0.0473 sec.
# -------------
# Epoch 524/600
# -------------
# -------------
# epoch 523 || Loss:0.0013
# timer:  0.0517 sec.
# -------------
# Epoch 525/600
# -------------
# -------------
# epoch 524 || Loss:0.0011
# timer:  0.0598 sec.
# -------------
# Epoch 526/600
# -------------
# -------------
# epoch 525 || Loss:0.0012
# timer:  0.0613 sec.
# -------------
# Epoch 527/600
# -------------
# -------------
# epoch 526 || Loss:0.0012
# timer:  0.0539 sec.
# -------------
# Epoch 528/600
# -------------
# -------------
# epoch 527 || Loss:0.0011
# timer:  0.0576 sec.
# -------------
# Epoch 529/600
# -------------
# -------------
# epoch 528 || Loss:0.0011
# timer:  0.0575 sec.
# -------------
# Epoch 530/600
# -------------
# -------------
# epoch 529 || Loss:0.0011
# timer:  0.0596 sec.
# -------------
# Epoch 531/600
# -------------
# -------------
# epoch 530 || Loss:0.0012
# timer:  0.0804 sec.
# -------------
# Epoch 532/600
# -------------
# -------------
# epoch 531 || Loss:0.0011
# timer:  0.0659 sec.
# -------------
# Epoch 533/600
# -------------
# -------------
# epoch 532 || Loss:0.0011
# timer:  0.0715 sec.
# -------------
# Epoch 534/600
# -------------
# -------------
# epoch 533 || Loss:0.0011
# timer:  0.0451 sec.
# -------------
# Epoch 535/600
# -------------
# -------------
# epoch 534 || Loss:0.0011
# timer:  0.0572 sec.
# -------------
# Epoch 536/600
# -------------
# -------------
# epoch 535 || Loss:0.0011
# timer:  0.0549 sec.
# -------------
# Epoch 537/600
# -------------
# -------------
# epoch 536 || Loss:0.0011
# timer:  0.0562 sec.
# -------------
# Epoch 538/600
# -------------
# -------------
# epoch 537 || Loss:0.0012
# timer:  0.0542 sec.
# -------------
# Epoch 539/600
# -------------
# -------------
# epoch 538 || Loss:0.0011
# timer:  0.0571 sec.
# -------------
# Epoch 540/600
# -------------
# -------------
# epoch 539 || Loss:0.0011
# timer:  0.0601 sec.
# -------------
# Epoch 541/600
# -------------
# -------------
# epoch 540 || Loss:0.0011
# timer:  0.0755 sec.
# -------------
# Epoch 542/600
# -------------
# -------------
# epoch 541 || Loss:0.0011
# timer:  0.0776 sec.
# -------------
# Epoch 543/600
# -------------
# -------------
# epoch 542 || Loss:0.0012
# timer:  0.0540 sec.
# -------------
# Epoch 544/600
# -------------
# -------------
# epoch 543 || Loss:0.0011
# timer:  0.0498 sec.
# -------------
# Epoch 545/600
# -------------
# -------------
# epoch 544 || Loss:0.0011
# timer:  0.0813 sec.
# -------------
# Epoch 546/600
# -------------
# -------------
# epoch 545 || Loss:0.0012
# timer:  0.0806 sec.
# -------------
# Epoch 547/600
# -------------
# -------------
# epoch 546 || Loss:0.0011
# timer:  0.0421 sec.
# -------------
# Epoch 548/600
# -------------
# -------------
# epoch 547 || Loss:0.0011
# timer:  0.0514 sec.
# -------------
# Epoch 549/600
# -------------
# -------------
# epoch 548 || Loss:0.0011
# timer:  0.0558 sec.
# -------------
# Epoch 550/600
# -------------
# -------------
# epoch 549 || Loss:0.0012
# timer:  0.0573 sec.
# -------------
# Epoch 551/600
# -------------
# -------------
# epoch 550 || Loss:0.0011
# timer:  0.0664 sec.
# -------------
# Epoch 552/600
# -------------
# -------------
# epoch 551 || Loss:0.0011
# timer:  0.0639 sec.
# -------------
# Epoch 553/600
# -------------
# -------------
# epoch 552 || Loss:0.0011
# timer:  0.0792 sec.
# -------------
# Epoch 554/600
# -------------
# -------------
# epoch 553 || Loss:0.0012
# timer:  0.0746 sec.
# -------------
# Epoch 555/600
# -------------
# -------------
# epoch 554 || Loss:0.0012
# timer:  0.0696 sec.
# -------------
# Epoch 556/600
# -------------
# -------------
# epoch 555 || Loss:0.0011
# timer:  0.0667 sec.
# -------------
# Epoch 557/600
# -------------
# -------------
# epoch 556 || Loss:0.0012
# timer:  0.0822 sec.
# -------------
# Epoch 558/600
# -------------
# -------------
# epoch 557 || Loss:0.0011
# timer:  0.0507 sec.
# -------------
# Epoch 559/600
# -------------
# -------------
# epoch 558 || Loss:0.0012
# timer:  0.0563 sec.
# -------------
# Epoch 560/600
# -------------
# -------------
# epoch 559 || Loss:0.0011
# timer:  0.0537 sec.
# -------------
# Epoch 561/600
# -------------
# -------------
# epoch 560 || Loss:0.0011
# timer:  0.0500 sec.
# -------------
# Epoch 562/600
# -------------
# -------------
# epoch 561 || Loss:0.0011
# timer:  0.0672 sec.
# -------------
# Epoch 563/600
# -------------
# -------------
# epoch 562 || Loss:0.0012
# timer:  0.0766 sec.
# -------------
# Epoch 564/600
# -------------
# -------------
# epoch 563 || Loss:0.0012
# timer:  0.0499 sec.
# -------------
# Epoch 565/600
# -------------
# -------------
# epoch 564 || Loss:0.0011
# timer:  0.0578 sec.
# -------------
# Epoch 566/600
# -------------
# -------------
# epoch 565 || Loss:0.0012
# timer:  0.0497 sec.
# -------------
# Epoch 567/600
# -------------
# -------------
# epoch 566 || Loss:0.0012
# timer:  0.0529 sec.
# -------------
# Epoch 568/600
# -------------
# -------------
# epoch 567 || Loss:0.0011
# timer:  0.0737 sec.
# -------------
# Epoch 569/600
# -------------
# -------------
# epoch 568 || Loss:0.0012
# timer:  0.0695 sec.
# -------------
# Epoch 570/600
# -------------
# -------------
# epoch 569 || Loss:0.0011
# timer:  0.0645 sec.
# -------------
# Epoch 571/600
# -------------
# -------------
# epoch 570 || Loss:0.0011
# timer:  0.0493 sec.
# -------------
# Epoch 572/600
# -------------
# -------------
# epoch 571 || Loss:0.0011
# timer:  0.0600 sec.
# -------------
# Epoch 573/600
# -------------
# -------------
# epoch 572 || Loss:0.0011
# timer:  0.0744 sec.
# -------------
# Epoch 574/600
# -------------
# -------------
# epoch 573 || Loss:0.0012
# timer:  0.0692 sec.
# -------------
# Epoch 575/600
# -------------
# -------------
# epoch 574 || Loss:0.0011
# timer:  0.0659 sec.
# -------------
# Epoch 576/600
# -------------
# -------------
# epoch 575 || Loss:0.0011
# timer:  0.0752 sec.
# -------------
# Epoch 577/600
# -------------
# -------------
# epoch 576 || Loss:0.0011
# timer:  0.0529 sec.
# -------------
# Epoch 578/600
# -------------
# -------------
# epoch 577 || Loss:0.0011
# timer:  0.0728 sec.
# -------------
# Epoch 579/600
# -------------
# -------------
# epoch 578 || Loss:0.0011
# timer:  0.0514 sec.
# -------------
# Epoch 580/600
# -------------
# -------------
# epoch 579 || Loss:0.0012
# timer:  0.0412 sec.
# -------------
# Epoch 581/600
# -------------
# -------------
# epoch 580 || Loss:0.0012
# timer:  0.0408 sec.
# -------------
# Epoch 582/600
# -------------
# -------------
# epoch 581 || Loss:0.0011
# timer:  0.0492 sec.
# -------------
# Epoch 583/600
# -------------
# -------------
# epoch 582 || Loss:0.0012
# timer:  0.0434 sec.
# -------------
# Epoch 584/600
# -------------
# -------------
# epoch 583 || Loss:0.0011
# timer:  0.0484 sec.
# -------------
# Epoch 585/600
# -------------
# -------------
# epoch 584 || Loss:0.0011
# timer:  0.0593 sec.
# -------------
# Epoch 586/600
# -------------
# -------------
# epoch 585 || Loss:0.0011
# timer:  0.0677 sec.
# -------------
# Epoch 587/600
# -------------
# -------------
# epoch 586 || Loss:0.0011
# timer:  0.0597 sec.
# -------------
# Epoch 588/600
# -------------
# -------------
# epoch 587 || Loss:0.0011
# timer:  0.0522 sec.
# -------------
# Epoch 589/600
# -------------
# -------------
# epoch 588 || Loss:0.0012
# timer:  0.0577 sec.
# -------------
# Epoch 590/600
# -------------
# -------------
# epoch 589 || Loss:0.0011
# timer:  0.0601 sec.
# -------------
# Epoch 591/600
# -------------
# -------------
# epoch 590 || Loss:0.0012
# timer:  0.0582 sec.
# -------------
# Epoch 592/600
# -------------
# -------------
# epoch 591 || Loss:0.0011
# timer:  0.0620 sec.
# -------------
# Epoch 593/600
# -------------
# -------------
# epoch 592 || Loss:0.0011
# timer:  0.0444 sec.
# -------------
# Epoch 594/600
# -------------
# -------------
# epoch 593 || Loss:0.0012
# timer:  0.0414 sec.
# -------------
# Epoch 595/600
# -------------
# -------------
# epoch 594 || Loss:0.0012
# timer:  0.0484 sec.
# -------------
# Epoch 596/600
# -------------
# -------------
# epoch 595 || Loss:0.0011
# timer:  0.0593 sec.
# -------------
# Epoch 597/600
# -------------
# -------------
# epoch 596 || Loss:0.0012
# timer:  0.0568 sec.
# -------------
# Epoch 598/600
# -------------
# -------------
# epoch 597 || Loss:0.0013
# timer:  0.0688 sec.
# -------------
# Epoch 599/600
# -------------
# -------------
# epoch 598 || Loss:0.0011
# timer:  0.0526 sec.
# -------------
# Epoch 600/600
# -------------
# -------------
# epoch 599 || Loss:0.0012
# timer:  0.0580 sec.

# %%
length = 100
start = -5
end = 5
waith = end - start
val_x = torch.tensor([[i] for i in np.arange(start,end,waith/length)])
val_y = 0.5*val_x
pred_y = model_mean_l(val_x).detach().cpu()
pred_std = model_error_l(val_x).detach().cpu()


fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(2,1,1)
ax.errorbar(val_x, pred_y, pred_std, label="NN (F(x), x_sd=0)")
ax.plot(val_x, val_y, label="true (y=0.5x)",c="g")

dataset = LinearDataset(length=300)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=300,shuffle=True)
x, y = next(iter(dataloader))
ax.scatter(x, y,c="r",label="sample")

ax.grid()
ax.legend(loc='upper left')
plt.xlim(-6, 6)
plt.ylim(-3, 3)



dataset = LinearDataset(length=300, model_mean=model_mean_l)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=300,shuffle=True)
dataloader = iter(dataloader)
x,y = next(dataloader)
y = y.detach().cpu()

ax = fig.add_subplot(2,1,2)
ax.scatter(x,y,c="r",label="sample (f_abs(y-F(x)))")
ax.plot(val_x,pred_std,label="NN (Delta F(x))")

ax.grid()
ax.legend(loc='upper left')
plt.xlim(-6, 6)
plt.ylim(-0.3, 2)


fig.show()
# Out:
# /home/yashima/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   del sys.path[0]

# %% [markdown]
# Fig. 4. Learning $y=0.5x$ with output noise depending on $x$.
